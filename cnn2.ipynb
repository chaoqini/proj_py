# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=3)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
# cnn.show(params,g)
with open('cnn_p2.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p2.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (2, 1, 3, 3)
# params gama0.shape= (2, 1, 1)
# params beta0.shape= (2, 1, 1)
# params k1.shape= (3, 2, 3, 3)
# params gama1.shape= (3, 1, 1)
# params beta1.shape= (3, 1, 1)
# params w2.shape= (10, 3, 28, 28)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 2.49e-01
# Hyperparams_test: L2_normalize_gama0 = 7.07e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 1.39e-01
# Hyperparams_test: L2_normalize_gama1 = 5.77e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.46e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 79.19%
# Valid_train percent is : 77.68%
# ============================================================
# hyperparams_test runing iteration = 2/18
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 2.43e-01
# Hyperparams_test: L2_normalize_gama0 = 7.15e-01
# Hyperparams_test: L2_normalize_beta0 = 2.59e-02
# Hyperparams_test: L2_normalize_k1 = 1.43e-01
# Hyperparams_test: L2_normalize_gama1 = 4.33e-01
# Hyperparams_test: L2_normalize_beta1 = 1.16e-01
# Hyperparams_test: L2_normalize_w2 = 6.44e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 87.80%
# Valid_train percent is : 86.57%
# ============================================================
# hyperparams_test runing iteration = 3/18
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 2.40e-01
# Hyperparams_test: L2_normalize_gama0 = 7.02e-01
# Hyperparams_test: L2_normalize_beta0 = 5.33e-02
# Hyperparams_test: L2_normalize_k1 = 1.47e-01
# Hyperparams_test: L2_normalize_gama1 = 4.10e-01
# Hyperparams_test: L2_normalize_beta1 = 1.15e-01
# Hyperparams_test: L2_normalize_w2 = 6.44e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 90.10%
# Valid_train percent is : 89.36%
# ============================================================
# hyperparams_test runing iteration = 4/18
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 2.40e-01
# Hyperparams_test: L2_normalize_gama0 = 7.00e-01
# Hyperparams_test: L2_normalize_beta0 = 7.10e-02
# Hyperparams_test: L2_normalize_k1 = 1.49e-01
# Hyperparams_test: L2_normalize_gama1 = 4.03e-01
# Hyperparams_test: L2_normalize_beta1 = 1.13e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 91.11%
# Valid_train percent is : 90.40%
# ============================================================
# hyperparams_test runing iteration = 5/18
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 2.39e-01
# Hyperparams_test: L2_normalize_gama0 = 6.98e-01
# Hyperparams_test: L2_normalize_beta0 = 8.01e-02
# Hyperparams_test: L2_normalize_k1 = 1.50e-01
# Hyperparams_test: L2_normalize_gama1 = 4.00e-01
# Hyperparams_test: L2_normalize_beta1 = 1.11e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 91.41%
# Valid_train percent is : 90.94%
# ============================================================
# hyperparams_test runing iteration = 6/18
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 2.39e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 8.49e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.99e-01
# Hyperparams_test: L2_normalize_beta1 = 1.09e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 91.67%
# Valid_train percent is : 91.27%
# ============================================================
# hyperparams_test runing iteration = 7/18
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 2.39e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 8.69e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.98e-01
# Hyperparams_test: L2_normalize_beta1 = 1.08e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 91.90%
# Valid_train percent is : 91.52%
# ============================================================
# hyperparams_test runing iteration = 8/18
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 2.38e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 8.86e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.98e-01
# Hyperparams_test: L2_normalize_beta1 = 1.08e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 92.04%
# Valid_train percent is : 91.64%
# ============================================================
# hyperparams_test runing iteration = 9/18
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 2.38e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 9.00e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.97e-01
# Hyperparams_test: L2_normalize_beta1 = 1.07e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 92.13%
# Valid_train percent is : 91.77%
# ============================================================
# hyperparams_test runing iteration = 10/18
# hyperparams_test runing: lri = 5.974e-05
# Hyperparams_test: L2_normalize_k0 = 2.38e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 9.07e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.97e-01
# Hyperparams_test: L2_normalize_beta1 = 1.07e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 92.20%
# Valid_train percent is : 91.85%
# ============================================================
# hyperparams_test runing iteration = 11/18
# hyperparams_test runing: lri = 4.044e-05
# Hyperparams_test: L2_normalize_k0 = 2.38e-01
# Hyperparams_test: L2_normalize_gama0 = 6.97e-01
# Hyperparams_test: L2_normalize_beta0 = 9.12e-02
# Hyperparams_test: L2_normalize_k1 = 1.51e-01
# Hyperparams_test: L2_normalize_gama1 = 3.97e-01
# Hyperparams_test: L2_normalize_beta1 = 1.07e-01
# Hyperparams_test: L2_normalize_w2 = 6.45e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781

# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=3)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
cnn.show(params,g)
with open('cnn_p1.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p1.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.key():  print('%s.shape='%k,v.shape)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (2, 1, 3, 3)
# params gama0.shape= (2, 1, 1)
# params beta0.shape= (2, 1, 1)
# params k1.shape= (3, 2, 3, 3)
# params gama1.shape= (3, 1, 1)
# params beta1.shape= (3, 1, 1)
# params w2.shape= (10, 3, 28, 28)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 2.49e-01
# Hyperparams_test: L2_normalize_gama0 = 7.07e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 1.39e-01
# Hyperparams_test: L2_normalize_gama1 = 5.77e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.46e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
