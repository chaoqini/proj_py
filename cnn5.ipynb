# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=12,imchin=12,dimch=8)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,batch=64,isl2grad=1)
with open('cnn_p5.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p5.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 12, 20, 28, 36, 44, 52, 60, 68, 76, 84, 92, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 12
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 0
# params k0.shape= (12, 1, 3, 3)
# params gama0.shape= (12, 1, 1)
# params beta0.shape= (12, 1, 1)
# params k1.shape= (20, 12, 3, 3)
# params gama1.shape= (20, 1, 1)
# params beta1.shape= (20, 1, 1)
# params k2.shape= (28, 20, 3, 3)
# params gama2.shape= (28, 1, 1)
# params beta2.shape= (28, 1, 1)
# params k3.shape= (36, 28, 3, 3)
# params gama3.shape= (36, 1, 1)
# params beta3.shape= (36, 1, 1)
# params k4.shape= (44, 36, 3, 3)
# params gama4.shape= (44, 1, 1)
# params beta4.shape= (44, 1, 1)
# params k5.shape= (52, 44, 3, 3)
# params gama5.shape= (52, 1, 1)
# params beta5.shape= (52, 1, 1)
# ...

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=16,imchin=12,dimch=8)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,batch=64,isl2grad=1)
with open('cnn_p1.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p1.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 12, 20, 28, 36, 44, 52, 60, 68, 76, 84, 92, 100, 108, 116, 124, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 16
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 0
# params k0.shape= (12, 1, 3, 3)
# params gama0.shape= (12, 1, 1)
# params beta0.shape= (12, 1, 1)
# params k1.shape= (20, 12, 3, 3)
# params gama1.shape= (20, 1, 1)
# params beta1.shape= (20, 1, 1)
# params k2.shape= (28, 20, 3, 3)
# params gama2.shape= (28, 1, 1)
# params beta2.shape= (28, 1, 1)
# params k3.shape= (36, 28, 3, 3)
# params gama3.shape= (36, 1, 1)
# params beta3.shape= (36, 1, 1)
# params k4.shape= (44, 36, 3, 3)
# params gama4.shape= (44, 1, 1)
# params beta4.shape= (44, 1, 1)
# params k5.shape= (52, 44, 3, 3)
# params gama5.shape= (52, 1, 1)
# params beta5.shape= (52, 1, 1)
# params k6.shape= (60, 52, 3, 3)
# ...
