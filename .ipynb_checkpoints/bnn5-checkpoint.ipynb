# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d)=bnn.bnn.init_params(lays=2,nnode=1000)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (300, 1)
# params w0.shape= (300, 784)
# params beta0.shape= (300, 1)
# params gama0.shape= (300, 1)
# params b1.shape= (300, 1)
# params w1.shape= (300, 300)
# params beta1.shape= (300, 1)
# params gama1.shape= (300, 1)
# params b2.shape= (300, 1)
# params w2.shape= (300, 300)
# params beta2.shape= (300, 1)
# params gama2.shape= (300, 1)
# params b3.shape= (300, 1)
# params w3.shape= (300, 300)
# params beta3.shape= (300, 1)
# params gama3.shape= (300, 1)
# params b4.shape= (10, 1)
# params w4.shape= (10, 300)
# params beta4.shape= (10, 1)
# params gama4.shape= (10, 1)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.06e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 5.42e-05
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 3.34e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 5.88e-05
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 3.33e-06
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 5.60e-05
# Hyperparams_test: L2_normalize_b3 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 3.34e-06
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_gama3 = 5.52e-05
# Hyperparams_test: L2_normalize_b4 = 0.00e+00
# Hyperparams_test: L2_normalize_w4 = 1.83e-05
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_gama4 = 5.21e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 91.43%
# Valid_train percent is : 90.75%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 2.21e-03
# Hyperparams_test: L2_normalize_w0 = 1.52e-04
# Hyperparams_test: L2_normalize_beta0 = 1.37e-03
# Hyperparams_test: L2_normalize_gama0 = 3.79e-03
# Hyperparams_test: L2_normalize_b1 = 1.44e-03
# Hyperparams_test: L2_normalize_w1 = 1.18e-04
# Hyperparams_test: L2_normalize_beta1 = 1.15e-03
# Hyperparams_test: L2_normalize_gama1 = 3.95e-03
# Hyperparams_test: L2_normalize_b2 = 2.46e-03
# Hyperparams_test: L2_normalize_w2 = 1.27e-04
# Hyperparams_test: L2_normalize_beta2 = 1.38e-03
# Hyperparams_test: L2_normalize_gama2 = 2.92e-03
# Hyperparams_test: L2_normalize_b3 = 2.24e-03
# Hyperparams_test: L2_normalize_w3 = 1.00e-04
# Hyperparams_test: L2_normalize_beta3 = 1.10e-03
# Hyperparams_test: L2_normalize_gama3 = 3.26e-03
# Hyperparams_test: L2_normalize_b4 = 1.21e-02
# Hyperparams_test: L2_normalize_w4 = 7.60e-04
# Hyperparams_test: L2_normalize_beta4 = 2.79e-02
# Hyperparams_test: L2_normalize_gama4 = 4.15e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 95.70%
# Valid_train percent is : 95.89%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 2.31e-03
# Hyperparams_test: L2_normalize_w0 = 1.58e-04
# Hyperparams_test: L2_normalize_beta0 = 1.44e-03
# Hyperparams_test: L2_normalize_gama0 = 4.22e-03
# Hyperparams_test: L2_normalize_b1 = 1.48e-03
# Hyperparams_test: L2_normalize_w1 = 1.25e-04
# Hyperparams_test: L2_normalize_beta1 = 1.20e-03
# Hyperparams_test: L2_normalize_gama1 = 4.13e-03
# Hyperparams_test: L2_normalize_b2 = 2.43e-03
# Hyperparams_test: L2_normalize_w2 = 1.29e-04
# Hyperparams_test: L2_normalize_beta2 = 1.48e-03
# Hyperparams_test: L2_normalize_gama2 = 3.07e-03
# Hyperparams_test: L2_normalize_b3 = 2.12e-03
# Hyperparams_test: L2_normalize_w3 = 9.86e-05
# Hyperparams_test: L2_normalize_beta3 = 1.21e-03
# Hyperparams_test: L2_normalize_gama3 = 3.37e-03
# Hyperparams_test: L2_normalize_b4 = 1.41e-02
# Hyperparams_test: L2_normalize_w4 = 8.06e-04
# Hyperparams_test: L2_normalize_beta4 = 3.06e-02
# Hyperparams_test: L2_normalize_gama4 = 5.46e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.64%
# Valid_train percent is : 97.24%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 2.67e-03
# Hyperparams_test: L2_normalize_w0 = 1.62e-04
# Hyperparams_test: L2_normalize_beta0 = 1.44e-03
# Hyperparams_test: L2_normalize_gama0 = 4.38e-03
# Hyperparams_test: L2_normalize_b1 = 1.55e-03
# Hyperparams_test: L2_normalize_w1 = 1.28e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.22e-03
# Hyperparams_test: L2_normalize_b2 = 2.48e-03
# Hyperparams_test: L2_normalize_w2 = 1.33e-04
# Hyperparams_test: L2_normalize_beta2 = 1.50e-03
# Hyperparams_test: L2_normalize_gama2 = 3.15e-03
# Hyperparams_test: L2_normalize_b3 = 2.06e-03
# Hyperparams_test: L2_normalize_w3 = 1.02e-04
# Hyperparams_test: L2_normalize_beta3 = 1.26e-03
# Hyperparams_test: L2_normalize_gama3 = 3.40e-03
# Hyperparams_test: L2_normalize_b4 = 1.46e-02
# Hyperparams_test: L2_normalize_w4 = 8.22e-04
# Hyperparams_test: L2_normalize_beta4 = 3.17e-02
# Hyperparams_test: L2_normalize_gama4 = 5.97e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.77%
# Valid_train percent is : 97.76%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 2.77e-03
# Hyperparams_test: L2_normalize_w0 = 1.63e-04
# Hyperparams_test: L2_normalize_beta0 = 1.45e-03
# Hyperparams_test: L2_normalize_gama0 = 4.46e-03
# Hyperparams_test: L2_normalize_b1 = 1.53e-03
# Hyperparams_test: L2_normalize_w1 = 1.31e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.28e-03
# Hyperparams_test: L2_normalize_b2 = 2.42e-03
# Hyperparams_test: L2_normalize_w2 = 1.34e-04
# Hyperparams_test: L2_normalize_beta2 = 1.51e-03
# Hyperparams_test: L2_normalize_gama2 = 3.20e-03
# Hyperparams_test: L2_normalize_b3 = 2.03e-03
# Hyperparams_test: L2_normalize_w3 = 1.04e-04
# Hyperparams_test: L2_normalize_beta3 = 1.26e-03
# Hyperparams_test: L2_normalize_gama3 = 3.42e-03
# Hyperparams_test: L2_normalize_b4 = 1.49e-02
# Hyperparams_test: L2_normalize_w4 = 8.29e-04
# Hyperparams_test: L2_normalize_beta4 = 3.21e-02
# Hyperparams_test: L2_normalize_gama4 = 6.22e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.94%
# Valid_train percent is : 98.03%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 2.75e-03
# Hyperparams_test: L2_normalize_w0 = 1.64e-04
# Hyperparams_test: L2_normalize_beta0 = 1.45e-03
# Hyperparams_test: L2_normalize_gama0 = 4.51e-03
# Hyperparams_test: L2_normalize_b1 = 1.52e-03
# Hyperparams_test: L2_normalize_w1 = 1.32e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.32e-03
# Hyperparams_test: L2_normalize_b2 = 2.37e-03
# Hyperparams_test: L2_normalize_w2 = 1.35e-04
# Hyperparams_test: L2_normalize_beta2 = 1.51e-03
# Hyperparams_test: L2_normalize_gama2 = 3.21e-03
# Hyperparams_test: L2_normalize_b3 = 2.01e-03
# Hyperparams_test: L2_normalize_w3 = 1.05e-04
# Hyperparams_test: L2_normalize_beta3 = 1.27e-03
# Hyperparams_test: L2_normalize_gama3 = 3.42e-03
# Hyperparams_test: L2_normalize_b4 = 1.51e-02
# Hyperparams_test: L2_normalize_w4 = 8.33e-04
# Hyperparams_test: L2_normalize_beta4 = 3.22e-02
# Hyperparams_test: L2_normalize_gama4 = 6.35e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.11%
# Valid_train percent is : 98.20%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 2.76e-03
# Hyperparams_test: L2_normalize_w0 = 1.65e-04
# Hyperparams_test: L2_normalize_beta0 = 1.45e-03
# Hyperparams_test: L2_normalize_gama0 = 4.53e-03
# Hyperparams_test: L2_normalize_b1 = 1.51e-03
# Hyperparams_test: L2_normalize_w1 = 1.32e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.33e-03
# Hyperparams_test: L2_normalize_b2 = 2.34e-03
# Hyperparams_test: L2_normalize_w2 = 1.36e-04
# Hyperparams_test: L2_normalize_beta2 = 1.51e-03
# Hyperparams_test: L2_normalize_gama2 = 3.22e-03
# Hyperparams_test: L2_normalize_b3 = 2.00e-03
# Hyperparams_test: L2_normalize_w3 = 1.05e-04
# Hyperparams_test: L2_normalize_beta3 = 1.27e-03
# Hyperparams_test: L2_normalize_gama3 = 3.43e-03
# Hyperparams_test: L2_normalize_b4 = 1.51e-02
# Hyperparams_test: L2_normalize_w4 = 8.35e-04
# Hyperparams_test: L2_normalize_beta4 = 3.23e-02
# Hyperparams_test: L2_normalize_gama4 = 6.42e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.13%
# Valid_train percent is : 98.31%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 2.77e-03
# Hyperparams_test: L2_normalize_w0 = 1.65e-04
# Hyperparams_test: L2_normalize_beta0 = 1.45e-03
# Hyperparams_test: L2_normalize_gama0 = 4.54e-03
# Hyperparams_test: L2_normalize_b1 = 1.51e-03
# Hyperparams_test: L2_normalize_w1 = 1.33e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.34e-03
# Hyperparams_test: L2_normalize_b2 = 2.32e-03
# Hyperparams_test: L2_normalize_w2 = 1.36e-04
# Hyperparams_test: L2_normalize_beta2 = 1.50e-03
# Hyperparams_test: L2_normalize_gama2 = 3.22e-03
# Hyperparams_test: L2_normalize_b3 = 2.00e-03
# Hyperparams_test: L2_normalize_w3 = 1.05e-04
# Hyperparams_test: L2_normalize_beta3 = 1.26e-03
# Hyperparams_test: L2_normalize_gama3 = 3.44e-03
# Hyperparams_test: L2_normalize_b4 = 1.51e-02
# Hyperparams_test: L2_normalize_w4 = 8.36e-04
# Hyperparams_test: L2_normalize_beta4 = 3.23e-02
# Hyperparams_test: L2_normalize_gama4 = 6.46e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.14%
# Valid_train percent is : 98.37%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 2.78e-03
# Hyperparams_test: L2_normalize_w0 = 1.65e-04
# Hyperparams_test: L2_normalize_beta0 = 1.45e-03
# Hyperparams_test: L2_normalize_gama0 = 4.54e-03
# Hyperparams_test: L2_normalize_b1 = 1.51e-03
# Hyperparams_test: L2_normalize_w1 = 1.33e-04
# Hyperparams_test: L2_normalize_beta1 = 1.24e-03
# Hyperparams_test: L2_normalize_gama1 = 4.35e-03
# Hyperparams_test: L2_normalize_b2 = 2.31e-03
# Hyperparams_test: L2_normalize_w2 = 1.36e-04
# Hyperparams_test: L2_normalize_beta2 = 1.50e-03
# Hyperparams_test: L2_normalize_gama2 = 3.23e-03
# Hyperparams_test: L2_normalize_b3 = 2.00e-03
# Hyperparams_test: L2_normalize_w3 = 1.05e-04
# Hyperparams_test: L2_normalize_beta3 = 1.26e-03
# Hyperparams_test: L2_normalize_gama3 = 3.44e-03
# Hyperparams_test: L2_normalize_b4 = 1.51e-02
# Hyperparams_test: L2_normalize_w4 = 8.37e-04
# Hyperparams_test: L2_normalize_beta4 = 3.23e-02
# Hyperparams_test: L2_normalize_gama4 = 6.48e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.12%
# No handles with labels found to put in legend.
# Valid_train percent is : 98.40%

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d)=bnn.bnn.init_params(lays=5,nnode=600)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (600, 1)
# params w0.shape= (600, 784)
# params beta0.shape= (600, 1)
# params gama0.shape= (600, 1)
# params b1.shape= (600, 1)
# params w1.shape= (600, 600)
# params beta1.shape= (600, 1)
# params gama1.shape= (600, 1)
# params b2.shape= (600, 1)
# params w2.shape= (600, 600)
# params beta2.shape= (600, 1)
# params gama2.shape= (600, 1)
# params b3.shape= (600, 1)
# params w3.shape= (600, 600)
# params beta3.shape= (600, 1)
# params gama3.shape= (600, 1)
# params b4.shape= (10, 1)
# params w4.shape= (10, 600)
# params beta4.shape= (10, 1)
# params gama4.shape= (10, 1)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.46e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 4.01e-05
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.67e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 3.90e-05
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 1.67e-06
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 4.21e-05
# Hyperparams_test: L2_normalize_b3 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 1.66e-06
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_gama3 = 4.00e-05
# Hyperparams_test: L2_normalize_b4 = 0.00e+00
# Hyperparams_test: L2_normalize_w4 = 1.31e-05
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_gama4 = 2.19e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 93.28%
# Valid_train percent is : 92.67%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 8.71e-05
# Hyperparams_test: L2_normalize_beta0 = 8.87e-04
# Hyperparams_test: L2_normalize_gama0 = 1.74e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 4.15e-05
# Hyperparams_test: L2_normalize_beta1 = 7.29e-04
# Hyperparams_test: L2_normalize_gama1 = 1.37e-03
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 3.25e-05
# Hyperparams_test: L2_normalize_beta2 = 8.23e-04
# Hyperparams_test: L2_normalize_gama2 = 1.63e-03
# Hyperparams_test: L2_normalize_b3 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 3.30e-05
# Hyperparams_test: L2_normalize_beta3 = 7.73e-04
# Hyperparams_test: L2_normalize_gama3 = 1.67e-03
# Hyperparams_test: L2_normalize_b4 = 0.00e+00
# Hyperparams_test: L2_normalize_w4 = 3.76e-04
# Hyperparams_test: L2_normalize_beta4 = 1.99e-02
# Hyperparams_test: L2_normalize_gama4 = 4.11e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
