# %%
import grad_test
import numpy as np
import imp
imp.reload(grad_test)
# Out:
# u= [[[0.0035]]
#
#  [[0.0115]]]
# v= [[[5.25e-06]]
#
#  [[5.25e-06]]]
# z=
#  [[[0.    0.001]
#   [0.002 0.003]
#   [0.004 0.005]
#   [0.006 0.007]]
#
#  [[0.008 0.009]
#   [0.01  0.011]
#   [0.012 0.013]
#   [0.014 0.015]]]
# x=
#  [[[-1.52607252 -1.0900518 ]
#   [-0.65403108 -0.21801036]
#   [ 0.21801036  0.65403108]
#   [ 1.0900518   1.52607252]]
#
#  [[-1.52607252 -1.0900518 ]
#   [-0.65403108 -0.21801036]
#   [ 0.21801036  0.65403108]
#   [ 1.0900518   1.52607252]]]
# xx=
#  [[[[ 2.32889734  1.6634981 ]
#    [ 0.99809886  0.33269962]
#    [-0.33269962 -0.99809886]
#    [-1.6634981  -2.32889734]]
#
#   [[ 1.6634981   1.18821293]
#    [ 0.71292776  0.23764259]
#    [-0.23764259 -0.71292776]
#    [-1.18821293 -1.6634981 ]]]
#
#
#  [[[ 0.99809886  0.71292776]
#    [ 0.42775665  0.14258555]
#    [-0.14258555 -0.42775665]
#    [-0.71292776 -0.99809886]]
#
#   [[ 0.33269962  0.23764259]
#    [ 0.14258555  0.04752852]
#    [-0.04752852 -0.14258555]
#    [-0.23764259 -0.33269962]]]
#
#
# ...
