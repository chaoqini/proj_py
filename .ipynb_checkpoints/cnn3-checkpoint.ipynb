# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=12,imchin=8,dimch=2)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18)
with open('cnn_p3.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p3.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [2, 4, 6, 8, 10, 10]
# init_params: ch= [1, 9, 17, 25, 33, 41, 49, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 7
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (9, 1, 3, 3)
# params gama0.shape= (9, 1, 1)
# params beta0.shape= (9, 1, 1)
# params k1.shape= (17, 9, 3, 3)
# params gama1.shape= (17, 1, 1)
# params beta1.shape= (17, 1, 1)
# params k2.shape= (25, 17, 3, 3)
# params gama2.shape= (25, 1, 1)
# params beta2.shape= (25, 1, 1)
# params k3.shape= (33, 25, 3, 3)
# params gama3.shape= (33, 1, 1)
# params beta3.shape= (33, 1, 1)
# params k4.shape= (41, 33, 3, 3)
# params gama4.shape= (41, 1, 1)
# params beta4.shape= (41, 1, 1)
# params k5.shape= (49, 41, 3, 3)
# params gama5.shape= (49, 1, 1)
# params beta5.shape= (49, 1, 1)
# params w6.shape= (10, 49, 7, 7)
# active function g[0] is: relu
# ...

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=7,imchin=1,dimch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
with open('cnn_p3.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p3.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [2, 4, 6, 8, 10, 10]
# init_params: ch= [1, 5, 9, 13, 17, 21, 25, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 7
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (5, 1, 3, 3)
# params gama0.shape= (5, 1, 1)
# params beta0.shape= (5, 1, 1)
# params k1.shape= (9, 5, 3, 3)
# params gama1.shape= (9, 1, 1)
# params beta1.shape= (9, 1, 1)
# params k2.shape= (13, 9, 3, 3)
# params gama2.shape= (13, 1, 1)
# params beta2.shape= (13, 1, 1)
# params k3.shape= (17, 13, 3, 3)
# params gama3.shape= (17, 1, 1)
# params beta3.shape= (17, 1, 1)
# params k4.shape= (21, 17, 3, 3)
# params gama4.shape= (21, 1, 1)
# params beta4.shape= (21, 1, 1)
# params k5.shape= (25, 21, 3, 3)
# params gama5.shape= (25, 1, 1)
# params beta5.shape= (25, 1, 1)
# params w6.shape= (10, 25, 7, 7)
# active function g[0] is: relu
# active function g[1] is: relu
# ...
