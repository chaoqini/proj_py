# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=5,imch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
with open('cnn_p3.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p3.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 4
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 128
# heyperparams_test: isupdate = 1
# params k0.shape= (11, 1, 3, 3)
# params gama0.shape= (11, 1, 1)
# params beta0.shape= (11, 1, 1)
# params k1.shape= (21, 11, 3, 3)
# params gama1.shape= (21, 1, 1)
# params beta1.shape= (21, 1, 1)
# params k2.shape= (31, 21, 3, 3)
# params gama2.shape= (31, 1, 1)
# params beta2.shape= (31, 1, 1)
# params w3.shape= (10, 31, 3, 3)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: softmax
# active function g[4] is: cross_entropy
# ...
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 8.62e-02
# Hyperparams_test: L2_normalize_gama0 = 3.02e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# ...

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=4,imch=8)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=128,isupdate=1,isl2grad=1)
with open('cnn_p3.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p3.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 4
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 128
# heyperparams_test: isupdate = 1
# params k0.shape= (9, 1, 3, 3)
# params gama0.shape= (9, 1, 1)
# params beta0.shape= (9, 1, 1)
# params k1.shape= (17, 9, 3, 3)
# params gama1.shape= (17, 1, 1)
# params beta1.shape= (17, 1, 1)
# params k2.shape= (25, 17, 3, 3)
# params gama2.shape= (25, 1, 1)
# params beta2.shape= (25, 1, 1)
# params w3.shape= (10, 25, 3, 3)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: softmax
# active function g[4] is: cross_entropy
# ...
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 9.52e-02
# Hyperparams_test: L2_normalize_gama0 = 3.33e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 2.61e-02
# ...
