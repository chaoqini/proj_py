# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
(params,params_init,g,g_d)=dnn.dnn.init_params(lays=9,nnode=100)
dnn.hyperparams_test(params,g,g_d,nloop=5,lr0=0.01,klr=0.997,batch=20)
# Out:
# heyperparams_test:
# hyperparams_test runing iteration=1/5
# Training running ...
# Train layers = 10
# Train learning rate lr0 = 0.002
# Train learning rate klr = 0.997
# Train batch = 20
# Train input X.shape=(2500, 20, 784, 1), LAB.shape=(2500, 20, 1, 1)
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# params b2.shape= (100, 1)
# params w2.shape= (100, 100)
# params b3.shape= (100, 1)
# params w3.shape= (100, 100)
# params b4.shape= (100, 1)
# params w4.shape= (100, 100)
# params b5.shape= (100, 1)
# params w5.shape= (100, 100)
# params b6.shape= (100, 1)
# params w6.shape= (100, 100)
# params b7.shape= (100, 1)
# params w7.shape= (100, 100)
# params b8.shape= (100, 1)
# params w8.shape= (100, 100)
# params b9.shape= (10, 1)
# params w9.shape= (10, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: relu
# ...
