# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
(params,params_init,g,g_d)=dnn.dnn.init_params(lays=2,nnode=400)
dnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (400, 1)
# params w0.shape= (400, 784)
# params b1.shape= (10, 1)
# params w1.shape= (10, 400)
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: log_loss
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.78e-06
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.55e-05
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 94.41%
# Valid_train percent is : 94.24%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 8.20e-04
# Hyperparams_test: L2_normalize_w0 = 7.28e-05
# Hyperparams_test: L2_normalize_b1 = 9.33e-03
# Hyperparams_test: L2_normalize_w1 = 7.52e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.61%
# Valid_train percent is : 97.05%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 9.45e-04
# Hyperparams_test: L2_normalize_w0 = 8.30e-05
# Hyperparams_test: L2_normalize_b1 = 1.42e-02
# Hyperparams_test: L2_normalize_w1 = 1.02e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.81%
# Valid_train percent is : 97.49%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 9.29e-04
# Hyperparams_test: L2_normalize_w0 = 8.68e-05
# Hyperparams_test: L2_normalize_b1 = 1.59e-02
# Hyperparams_test: L2_normalize_w1 = 1.19e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.59%
# Valid_train percent is : 97.34%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 9.13e-04
# Hyperparams_test: L2_normalize_w0 = 8.84e-05
# Hyperparams_test: L2_normalize_b1 = 1.66e-02
# Hyperparams_test: L2_normalize_w1 = 1.29e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.51%
# Valid_train percent is : 97.17%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 8.98e-04
# Hyperparams_test: L2_normalize_w0 = 8.92e-05
# Hyperparams_test: L2_normalize_b1 = 1.69e-02
# Hyperparams_test: L2_normalize_w1 = 1.35e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.36%
# Valid_train percent is : 97.05%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 8.87e-04
# Hyperparams_test: L2_normalize_w0 = 8.96e-05
# Hyperparams_test: L2_normalize_b1 = 1.70e-02
# Hyperparams_test: L2_normalize_w1 = 1.38e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.36%
# Valid_train percent is : 97.03%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 8.81e-04
# Hyperparams_test: L2_normalize_w0 = 8.98e-05
# Hyperparams_test: L2_normalize_b1 = 1.71e-02
# Hyperparams_test: L2_normalize_w1 = 1.39e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 96.39%
# Valid_train percent is : 97.06%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 8.78e-04
# Hyperparams_test: L2_normalize_w0 = 8.99e-05
# Hyperparams_test: L2_normalize_b1 = 1.71e-02
# Hyperparams_test: L2_normalize_w1 = 1.40e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250

# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
(params,params_init,g,g_d)=dnn.dnn.init_params(lays=3,nnode=400)
dnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (400, 1)
# params w0.shape= (400, 784)
# params b1.shape= (400, 1)
# params w1.shape= (400, 400)
# params b2.shape= (400, 1)
# params w2.shape= (400, 400)
# params b3.shape= (400, 1)
# params w3.shape= (400, 400)
# params b4.shape= (10, 1)
# params w4.shape= (10, 400)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: log_loss
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.78e-06
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 2.50e-06
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 2.50e-06
# Hyperparams_test: L2_normalize_b3 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 2.50e-06
# Hyperparams_test: L2_normalize_b4 = 0.00e+00
# Hyperparams_test: L2_normalize_w4 = 1.57e-05
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 90.26%
# Valid_train percent is : 89.37%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 1.09e-03
# Hyperparams_test: L2_normalize_w0 = 5.76e-05
# Hyperparams_test: L2_normalize_b1 = 2.03e-03
# Hyperparams_test: L2_normalize_w1 = 6.60e-05
# Hyperparams_test: L2_normalize_b2 = 2.28e-03
# Hyperparams_test: L2_normalize_w2 = 7.45e-05
# Hyperparams_test: L2_normalize_b3 = 2.45e-03
# Hyperparams_test: L2_normalize_w3 = 5.77e-05
# Hyperparams_test: L2_normalize_b4 = 4.14e-02
# Hyperparams_test: L2_normalize_w4 = 5.69e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 93.79%
# Valid_train percent is : 93.33%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 1.16e-03
# Hyperparams_test: L2_normalize_w0 = 6.37e-05
# Hyperparams_test: L2_normalize_b1 = 2.37e-03
# Hyperparams_test: L2_normalize_w1 = 7.59e-05
# Hyperparams_test: L2_normalize_b2 = 2.60e-03
# Hyperparams_test: L2_normalize_w2 = 8.46e-05
# Hyperparams_test: L2_normalize_b3 = 2.50e-03
# Hyperparams_test: L2_normalize_w3 = 6.23e-05
# Hyperparams_test: L2_normalize_b4 = 4.19e-02
# Hyperparams_test: L2_normalize_w4 = 8.01e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 91.97%
# Valid_train percent is : 91.82%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 1.14e-03
# Hyperparams_test: L2_normalize_w0 = 6.54e-05
# Hyperparams_test: L2_normalize_b1 = 2.49e-03
# Hyperparams_test: L2_normalize_w1 = 8.05e-05
# Hyperparams_test: L2_normalize_b2 = 2.70e-03
# Hyperparams_test: L2_normalize_w2 = 8.85e-05
# Hyperparams_test: L2_normalize_b3 = 2.53e-03
# Hyperparams_test: L2_normalize_w3 = 6.33e-05
# Hyperparams_test: L2_normalize_b4 = 4.19e-02
# Hyperparams_test: L2_normalize_w4 = 9.59e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 90.60%
# Valid_train percent is : 90.26%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 1.13e-03
# Hyperparams_test: L2_normalize_w0 = 6.60e-05
# Hyperparams_test: L2_normalize_b1 = 2.52e-03
# Hyperparams_test: L2_normalize_w1 = 8.28e-05
# Hyperparams_test: L2_normalize_b2 = 2.74e-03
# Hyperparams_test: L2_normalize_w2 = 9.05e-05
# Hyperparams_test: L2_normalize_b3 = 2.55e-03
# Hyperparams_test: L2_normalize_w3 = 6.40e-05
# Hyperparams_test: L2_normalize_b4 = 4.17e-02
# Hyperparams_test: L2_normalize_w4 = 1.07e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 89.93%
# Valid_train percent is : 89.57%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 1.12e-03
# Hyperparams_test: L2_normalize_w0 = 6.62e-05
# Hyperparams_test: L2_normalize_b1 = 2.52e-03
# Hyperparams_test: L2_normalize_w1 = 8.40e-05
# Hyperparams_test: L2_normalize_b2 = 2.76e-03
# Hyperparams_test: L2_normalize_w2 = 9.17e-05
# Hyperparams_test: L2_normalize_b3 = 2.56e-03
# Hyperparams_test: L2_normalize_w3 = 6.46e-05
# Hyperparams_test: L2_normalize_b4 = 4.17e-02
# Hyperparams_test: L2_normalize_w4 = 1.13e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 89.58%
# Valid_train percent is : 89.15%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 1.12e-03
# Hyperparams_test: L2_normalize_w0 = 6.63e-05
# Hyperparams_test: L2_normalize_b1 = 2.52e-03
# Hyperparams_test: L2_normalize_w1 = 8.46e-05
# Hyperparams_test: L2_normalize_b2 = 2.77e-03
# Hyperparams_test: L2_normalize_w2 = 9.24e-05
# Hyperparams_test: L2_normalize_b3 = 2.56e-03
# Hyperparams_test: L2_normalize_w3 = 6.50e-05
# Hyperparams_test: L2_normalize_b4 = 4.15e-02
# Hyperparams_test: L2_normalize_w4 = 1.16e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 89.17%
# Valid_train percent is : 88.65%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 1.11e-03
# Hyperparams_test: L2_normalize_w0 = 6.63e-05
# Hyperparams_test: L2_normalize_b1 = 2.51e-03
# Hyperparams_test: L2_normalize_w1 = 8.50e-05
# Hyperparams_test: L2_normalize_b2 = 2.77e-03
# Hyperparams_test: L2_normalize_w2 = 9.28e-05
# Hyperparams_test: L2_normalize_b3 = 2.57e-03
# Hyperparams_test: L2_normalize_w3 = 6.53e-05
# Hyperparams_test: L2_normalize_b4 = 4.15e-02
# Hyperparams_test: L2_normalize_w4 = 1.18e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 89.07%
# Valid_train percent is : 88.60%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 1.11e-03
# Hyperparams_test: L2_normalize_w0 = 6.63e-05
# Hyperparams_test: L2_normalize_b1 = 2.51e-03
# Hyperparams_test: L2_normalize_w1 = 8.51e-05
# Hyperparams_test: L2_normalize_b2 = 2.77e-03
# Hyperparams_test: L2_normalize_w2 = 9.30e-05
# Hyperparams_test: L2_normalize_b3 = 2.57e-03
# Hyperparams_test: L2_normalize_w3 = 6.54e-05
# Hyperparams_test: L2_normalize_b4 = 4.14e-02
# Hyperparams_test: L2_normalize_w4 = 1.19e-03
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# Valid percent is : 89.11%
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Valid_train percent is : 88.56%
