# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
# def hyperparams_test(nloop=0,lr0=0,klr=0,batch=0,batches=0,lays=0):
dnn.hyperparams_test(nloop=6,lays=5,nnode=200,lr0=0.003,klr=0.999,batch=30)
# Out:
# hyperparams_test runing iteration=1/3
# Training running ...
# Train layers = 2
# Train learning rate lr0 = 0.01
# Train learning rate klr = 0.998
# Train batch = 20
# Train input X.shape=(2500, 20, 784, 1), LAB.shape=(2500, 20, 1, 1)
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: log_loss
# Training bath running ...
# Training iteration number = 0/2500
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:53: RuntimeWarning: invalid value encountered in true_divide
#   Y=np.trunc(Y/y1d_max)
# Training iteration number = 250/2500
# Training iteration number = 500/2500
# Training iteration number = 750/2500
# Training iteration number = 1000/2500
# Training iteration number = 1250/2500
# Training iteration number = 1500/2500
# Training iteration number = 1750/2500
# Training iteration number = 2000/2500
# Training iteration number = 2250/2500
# Training iteration number = 2499/2500
# Valid running ...
# Valid Input X.shape=(100, 100, 784, 1), LAB.shape=(100, 100, 1, 1)
# Valid batch running ...
# Valid iteration number = 0/100
# Valid iteration number = 10/100
# Valid iteration number = 20/100
# Valid iteration number = 30/100
# Valid iteration number = 40/100
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:53: RuntimeWarning: invalid value encountered in true_divide
#   Y=np.trunc(Y/y1d_max)
# Valid iteration number = 50/100
# Valid iteration number = 60/100
# Valid iteration number = 70/100
# Valid iteration number = 80/100
# Valid iteration number = 90/100
# Valid iteration number = 99/100
# Valid L2 norm:
# Valid L2_normalize_b0 = 0.006302641622069589
# Valid L2_normalize_w0 = 0.00023165086761408246
# Valid L2_normalize_b1 = 0.007806052173356808
# Valid L2_normalize_w1 = 0.000511475970442798
# Valid percent is : 55.27%
# Valid_train Input X.shape=(500, 100, 784, 1), LAB.shape=(500, 100, 1, 1)
# Valid_train batch running ...
# Valid_train iteration number = 0/500
# Valid_train iteration number = 50/500
# Valid_train iteration number = 100/500
# Valid_train iteration number = 150/500
# Valid_train iteration number = 200/500
# Valid_train iteration number = 250/500
# Valid_train iteration number = 300/500
# Valid_train iteration number = 350/500
# Valid_train iteration number = 400/500
# Valid_train iteration number = 450/500
# Valid_train iteration number = 499/500
# Valid_train L2_normalize_b0 = 0.006302641622069589
# Valid_train L2_normalize_w0 = 0.00023165086761408246
# Valid_train L2_normalize_b1 = 0.007806052173356808
# Valid_train L2_normalize_w1 = 0.000511475970442798
# Valid_train percent is : 54.80%
# hyperparams_test runing iteration=2/3
# Training running ...
# Train layers = 2
# Train learning rate lr0 = 0.006666666666666668
# Train learning rate klr = 0.998
# Train batch = 20
# Train input X.shape=(2500, 20, 784, 1), LAB.shape=(2500, 20, 1, 1)
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: log_loss
# Training bath running ...
# Training iteration number = 0/2500
# Training iteration number = 250/2500
# Training iteration number = 500/2500
# Training iteration number = 750/2500
# Training iteration number = 1000/2500
# Training iteration number = 1250/2500
# Training iteration number = 1500/2500
# Training iteration number = 1750/2500
# Training iteration number = 2000/2500
# Training iteration number = 2250/2500
# Training iteration number = 2499/2500
# Valid running ...
# Valid Input X.shape=(100, 100, 784, 1), LAB.shape=(100, 100, 1, 1)
# Valid batch running ...
# Valid iteration number = 0/100
# Valid iteration number = 10/100
# Valid iteration number = 20/100
# Valid iteration number = 30/100
# Valid iteration number = 40/100
# Valid iteration number = 50/100
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:53: RuntimeWarning: invalid value encountered in true_divide
#   Y=np.trunc(Y/y1d_max)
# Valid iteration number = 60/100
# Valid iteration number = 70/100
# Valid iteration number = 80/100
# Valid iteration number = 90/100
# Valid iteration number = 99/100
# Valid L2 norm:
# Valid L2_normalize_b0 = 0.0065917525195250395
# Valid L2_normalize_w0 = 0.00024681698541716683
# Valid L2_normalize_b1 = 0.008798191785120278
# Valid L2_normalize_w1 = 0.000513107820249145
# Valid percent is : 65.19%
# Valid_train Input X.shape=(500, 100, 784, 1), LAB.shape=(500, 100, 1, 1)
# Valid_train batch running ...
# Valid_train iteration number = 0/500
# Valid_train iteration number = 50/500
# Valid_train iteration number = 100/500
# Valid_train iteration number = 150/500
# Valid_train iteration number = 200/500
# Valid_train iteration number = 250/500
# Valid_train iteration number = 300/500
# Valid_train iteration number = 350/500
# Valid_train iteration number = 400/500
# Valid_train iteration number = 450/500
# Valid_train iteration number = 499/500
# Valid_train L2_normalize_b0 = 0.0065917525195250395
# Valid_train L2_normalize_w0 = 0.00024681698541716683
# Valid_train L2_normalize_b1 = 0.008798191785120278
# Valid_train L2_normalize_w1 = 0.000513107820249145
# Valid_train percent is : 64.32%
# hyperparams_test runing iteration=3/3
# Training running ...
# Train layers = 2
# Train learning rate lr0 = 0.003333333333333334
# Train learning rate klr = 0.998
# Train batch = 20
# Train input X.shape=(2500, 20, 784, 1), LAB.shape=(2500, 20, 1, 1)
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: log_loss
# Training bath running ...
# Training iteration number = 0/2500
# Training iteration number = 250/2500
# Training iteration number = 500/2500
# Training iteration number = 750/2500
# Training iteration number = 1000/2500
# Training iteration number = 1250/2500
# Training iteration number = 1500/2500
# Training iteration number = 1750/2500
# Training iteration number = 2000/2500
# Training iteration number = 2250/2500
# Training iteration number = 2499/2500
# Valid running ...
# Valid Input X.shape=(100, 100, 784, 1), LAB.shape=(100, 100, 1, 1)
# Valid batch running ...
# Valid iteration number = 0/100
# Valid iteration number = 10/100
# Valid iteration number = 20/100
# Valid iteration number = 30/100
# Valid iteration number = 40/100
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: divide by zero encountered in log
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:47: RuntimeWarning: invalid value encountered in multiply
#   LOSS=-np.sum(YL*np.log(Y),axis=1)
# /home/qc/proj_py/dnn.py:53: RuntimeWarning: invalid value encountered in true_divide
#   Y=np.trunc(Y/y1d_max)
# Valid iteration number = 50/100
# Valid iteration number = 60/100
# Valid iteration number = 70/100
# Valid iteration number = 80/100
# Valid iteration number = 90/100
# Valid iteration number = 99/100
# Valid L2 norm:
# Valid L2_normalize_b0 = 0.006559510293477987
# Valid L2_normalize_w0 = 0.0002508765743504194
# Valid L2_normalize_b1 = 0.009213959948826504
# Valid L2_normalize_w1 = 0.0005132746961417549
# Valid percent is : 66.36%
# Valid_train Input X.shape=(500, 100, 784, 1), LAB.shape=(500, 100, 1, 1)
# Valid_train batch running ...
# Valid_train iteration number = 0/500
# Valid_train iteration number = 50/500
# Valid_train iteration number = 100/500
# Valid_train iteration number = 150/500
# Valid_train iteration number = 200/500
# Valid_train iteration number = 250/500
# Valid_train iteration number = 300/500
# Valid_train iteration number = 350/500
# Valid_train iteration number = 400/500
# Valid_train iteration number = 450/500
# Valid_train iteration number = 499/500
# Valid_train L2_normalize_b0 = 0.006559510293477987
# Valid_train L2_normalize_w0 = 0.0002508765743504194
# Valid_train L2_normalize_b1 = 0.009213959948826504
# Valid_train L2_normalize_w1 = 0.0005132746961417549
# Valid_train percent is : 65.95%
