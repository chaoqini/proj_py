# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
# dnn.dnn_train(dnn.params,0,0,0,0,1,1)
(v1a,v2a)=([],[])
for i in range(10):
#     j=10**(-i/10*3)
#     dnn.dnn_train(dnn.params_init,1-0.1*i,0.998,20,0,1)
    (v1,v2)=dnn.dnn_train(dnn.params_init,0.8,1-0.001*i,20,0,1)
    v1a.append(v1)
    v2a.append(v2)
    v1a=np.array(v1a)
    v2a=np.array(v2a)

plt.figure()
plt.subplot(211)
plt.plot(v1a)
plt.ylabel('v1a')
plt.subplot(212)
plt.plot(v2a)
plt.ylabel('v2a')
plt.show()
# Out:
# params[b0] iseq=1
# params[b1] iseq=1
# params[b2] iseq=1
# params[b3] iseq=1
# params[w0] iseq=1
# params[w1] iseq=1
# params[w2] iseq=1
# params[w3] iseq=1
# Training running ...
# Train learning rate lr0 = 0.8
# Train learning rate klr = 1.0
# Train batch = 20
# Train input X.shape=(2500, 20, 784, 1), LAB.shape=(2500, 20, 1, 1)
# params b0.shape= (100, 1)
# params b1.shape= (100, 1)
# params b2.shape= (100, 1)
# params b3.shape= (10, 1)
# params w0.shape= (100, 784)
# params w1.shape= (100, 100)
# params w2.shape= (100, 100)
# params w3.shape= (10, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: softmax
# active function g[4] is: log_loss
# Training bath running ...
# Training iteration number = 0/2500
# Training iteration number = 250/2500
# Training iteration number = 500/2500
# Training iteration number = 750/2500
# Training iteration number = 1000/2500
# Training iteration number = 1250/2500
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [9], in <module>
#       1 for i in range(2):
# ----> 2     dnn.dnn_train(dnn.params_init,1-0.1*i,0.998,20,0,1)
#
# File ~/proj_py/dnn.py:371, in dnn_train(params, lr0, klr, batch, batches, isplot, istime, ischeck)
#     369 #    print('params==params_init is:',params==params_init)
#     370     for k in params.keys():
# --> 371         iseq=iseq&(np.all(params[k]==params_init[k]))
#     372         print('iseq=',iseq)
#     373     if lr0==0: lr0=dnn.lr0
#
# UnboundLocalError: local variable 'iseq' referenced before assignment

# %%
for (k,v) in dnn.params_init.items():
    L2=np.linalg.norm(v)/v.size
    print('Valid_train L2_normalize_%s = %s'%(k,L2))
