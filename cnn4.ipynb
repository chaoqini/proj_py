# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=6,imch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
with open('cnn_p4.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p4.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 6
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (5, 1, 3, 3)
# params gama0.shape= (5, 1, 1)
# params beta0.shape= (5, 1, 1)
# params k1.shape= (9, 5, 3, 3)
# params gama1.shape= (9, 1, 1)
# params beta1.shape= (9, 1, 1)
# params k2.shape= (13, 9, 3, 3)
# params gama2.shape= (13, 1, 1)
# params beta2.shape= (13, 1, 1)
# params k3.shape= (17, 13, 3, 3)
# params gama3.shape= (17, 1, 1)
# params beta3.shape= (17, 1, 1)
# params k4.shape= (21, 17, 3, 3)
# params gama4.shape= (21, 1, 1)
# params beta4.shape= (21, 1, 1)
# params w5.shape= (10, 21, 7, 7)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: relu
# active function g[5] is: softmax
# active function g[6] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 1.42e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.33e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.43e-01
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_k4 = 1.74e-02
# Hyperparams_test: L2_normalize_gama4 = 2.18e-01
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_w5 = 9.78e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 87.46%
# Valid_train percent is : 87.08%
# ============================================================
# hyperparams_test runing iteration = 2/18
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 1.43e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 3.93e-02
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 3.65e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.75e-01
# Hyperparams_test: L2_normalize_beta2 = 3.57e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.42e-01
# Hyperparams_test: L2_normalize_beta3 = 3.04e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.64e-01
# Hyperparams_test: L2_normalize_beta4 = 3.08e-02
# Hyperparams_test: L2_normalize_w5 = 9.67e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 93.21%
# Valid_train percent is : 92.74%
# ============================================================
# hyperparams_test runing iteration = 3/18
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 1.45e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 5.46e-02
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 5.16e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.74e-01
# Hyperparams_test: L2_normalize_beta2 = 4.91e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.01e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.45e-01
# Hyperparams_test: L2_normalize_beta4 = 3.64e-02
# Hyperparams_test: L2_normalize_w5 = 9.63e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.64%
# Valid_train percent is : 94.59%
# ============================================================
# hyperparams_test runing iteration = 4/18
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 1.45e-01
# Hyperparams_test: L2_normalize_gama0 = 4.48e-01
# Hyperparams_test: L2_normalize_beta0 = 6.04e-02
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 5.68e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.34e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.35e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.38e-01
# Hyperparams_test: L2_normalize_beta4 = 3.77e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.29%
# Valid_train percent is : 95.44%
# ============================================================
# hyperparams_test runing iteration = 5/18
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 6.26e-02
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 5.93e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.56e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.49e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.35e-01
# Hyperparams_test: L2_normalize_beta4 = 3.79e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.65%
# Valid_train percent is : 95.91%
# ============================================================
# hyperparams_test runing iteration = 6/18
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 6.34e-02
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.09e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.65e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.56e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.33e-01
# Hyperparams_test: L2_normalize_beta4 = 3.79e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.87%
# Valid_train percent is : 96.18%
# ============================================================
# hyperparams_test runing iteration = 7/18
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.39e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.19e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.70e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.60e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.32e-01
# Hyperparams_test: L2_normalize_beta4 = 3.78e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.01%
# Valid_train percent is : 96.33%
# ============================================================
# hyperparams_test runing iteration = 8/18
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.45e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.27e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.74e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.62e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.32e-01
# Hyperparams_test: L2_normalize_beta4 = 3.77e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.13%
# Valid_train percent is : 96.46%
# ============================================================
# hyperparams_test runing iteration = 9/18
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.49e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.31e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.77e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.64e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.76e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.17%
# Valid_train percent is : 96.54%
# ============================================================
# hyperparams_test runing iteration = 10/18
# hyperparams_test runing: lri = 5.974e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.52e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.33e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.78e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.65e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.75e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.17%
# Valid_train percent is : 96.60%
# ============================================================
# hyperparams_test runing iteration = 11/18
# hyperparams_test runing: lri = 4.044e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.54e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.35e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.79e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.65e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.75e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.19%
# Valid_train percent is : 96.64%
# ============================================================
# hyperparams_test runing iteration = 12/18
# hyperparams_test runing: lri = 2.738e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.55e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.36e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.80e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.75e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.20%
# Valid_train percent is : 96.66%
# ============================================================
# hyperparams_test runing iteration = 13/18
# hyperparams_test runing: lri = 1.854e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.56e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.36e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.80e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.75e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.22%
# Valid_train percent is : 96.68%
# ============================================================
# hyperparams_test runing iteration = 14/18
# hyperparams_test runing: lri = 1.255e-05
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.56e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.37e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.80e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.22%
# Valid_train percent is : 96.67%
# ============================================================
# hyperparams_test runing iteration = 15/18
# hyperparams_test runing: lri = 8.496e-06
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.57e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.37e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.81e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.20%
# Valid_train percent is : 96.69%
# ============================================================
# hyperparams_test runing iteration = 16/18
# hyperparams_test runing: lri = 5.751e-06
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.57e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.37e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.81e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.20%
# Valid_train percent is : 96.69%
# ============================================================
# hyperparams_test runing iteration = 17/18
# hyperparams_test runing: lri = 3.894e-06
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.57e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.37e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.81e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.20%
# Valid_train percent is : 96.69%
# ============================================================
# hyperparams_test runing iteration = 18/18
# hyperparams_test runing: lri = 2.636e-06
# Hyperparams_test: L2_normalize_k0 = 1.47e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 6.57e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.31e-01
# Hyperparams_test: L2_normalize_beta1 = 6.37e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.73e-01
# Hyperparams_test: L2_normalize_beta2 = 5.81e-02
# Hyperparams_test: L2_normalize_k3 = 2.22e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 4.66e-02
# Hyperparams_test: L2_normalize_k4 = 1.75e-02
# Hyperparams_test: L2_normalize_gama4 = 1.31e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_w5 = 9.62e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.20%
# No handles with labels found to put in legend.
# Valid_train percent is : 96.69%
# k0.shape= (5, 1, 3, 3)
# gama0.shape= (5, 1, 1)
# beta0.shape= (5, 1, 1)
# k1.shape= (9, 5, 3, 3)
# gama1.shape= (9, 1, 1)
# beta1.shape= (9, 1, 1)
# k2.shape= (13, 9, 3, 3)
# gama2.shape= (13, 1, 1)
# beta2.shape= (13, 1, 1)
# k3.shape= (17, 13, 3, 3)
# gama3.shape= (17, 1, 1)
# beta3.shape= (17, 1, 1)
# k4.shape= (21, 17, 3, 3)
# gama4.shape= (21, 1, 1)
# beta4.shape= (21, 1, 1)
# w5.shape= (10, 21, 7, 7)
# Real lab number is :	4
# Precdict number is :	4

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=9,imchin=1,dimch=2)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
with open('cnn_p4.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p4.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [2, 4, 6, 8, 10, 10]
# init_params: ch= [1, 3, 5, 7, 9, 11, 13, 15, 17, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 9
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (3, 1, 3, 3)
# params gama0.shape= (3, 1, 1)
# params beta0.shape= (3, 1, 1)
# params k1.shape= (5, 3, 3, 3)
# params gama1.shape= (5, 1, 1)
# params beta1.shape= (5, 1, 1)
# params k2.shape= (7, 5, 3, 3)
# params gama2.shape= (7, 1, 1)
# params beta2.shape= (7, 1, 1)
# params k3.shape= (9, 7, 3, 3)
# params gama3.shape= (9, 1, 1)
# params beta3.shape= (9, 1, 1)
# params k4.shape= (11, 9, 3, 3)
# params gama4.shape= (11, 1, 1)
# params beta4.shape= (11, 1, 1)
# params k5.shape= (13, 11, 3, 3)
# params gama5.shape= (13, 1, 1)
# params beta5.shape= (13, 1, 1)
# params k6.shape= (15, 13, 3, 3)
# params gama6.shape= (15, 1, 1)
# params beta6.shape= (15, 1, 1)
# params k7.shape= (17, 15, 3, 3)
# params gama7.shape= (17, 1, 1)
# params beta7.shape= (17, 1, 1)
# params w8.shape= (10, 17, 7, 7)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: relu
# active function g[5] is: relu
# active function g[6] is: relu
# active function g[7] is: relu
# active function g[8] is: softmax
# active function g[9] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 1.90e-01
# Hyperparams_test: L2_normalize_gama0 = 5.77e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 8.98e-02
# Hyperparams_test: L2_normalize_gama1 = 4.47e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 5.91e-02
# Hyperparams_test: L2_normalize_gama2 = 3.78e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.33e-01
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 3.02e-01
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.77e-01
# Hyperparams_test: L2_normalize_beta5 = 0.00e+00
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.58e-01
# Hyperparams_test: L2_normalize_beta6 = 0.00e+00
# Hyperparams_test: L2_normalize_k7 = 2.09e-02
# Hyperparams_test: L2_normalize_gama7 = 2.43e-01
# Hyperparams_test: L2_normalize_beta7 = 0.00e+00
# Hyperparams_test: L2_normalize_w8 = 1.08e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 79.99%
# Valid_train percent is : 78.57%
# ============================================================
# hyperparams_test runing iteration = 2/18
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 1.89e-01
# Hyperparams_test: L2_normalize_gama0 = 5.74e-01
# Hyperparams_test: L2_normalize_beta0 = 7.08e-02
# Hyperparams_test: L2_normalize_k1 = 9.00e-02
# Hyperparams_test: L2_normalize_gama1 = 4.48e-01
# Hyperparams_test: L2_normalize_beta1 = 3.81e-02
# Hyperparams_test: L2_normalize_k2 = 5.91e-02
# Hyperparams_test: L2_normalize_gama2 = 3.79e-01
# Hyperparams_test: L2_normalize_beta2 = 3.75e-02
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.29e-01
# Hyperparams_test: L2_normalize_beta3 = 2.95e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 3.01e-01
# Hyperparams_test: L2_normalize_beta4 = 3.74e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.77e-01
# Hyperparams_test: L2_normalize_beta5 = 3.04e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.56e-01
# Hyperparams_test: L2_normalize_beta6 = 3.75e-02
# Hyperparams_test: L2_normalize_k7 = 2.10e-02
# Hyperparams_test: L2_normalize_gama7 = 1.55e-01
# Hyperparams_test: L2_normalize_beta7 = 4.22e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 90.06%
# Valid_train percent is : 89.63%
# ============================================================
# hyperparams_test runing iteration = 3/18
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 1.90e-01
# Hyperparams_test: L2_normalize_gama0 = 5.75e-01
# Hyperparams_test: L2_normalize_beta0 = 9.43e-02
# Hyperparams_test: L2_normalize_k1 = 9.01e-02
# Hyperparams_test: L2_normalize_gama1 = 4.44e-01
# Hyperparams_test: L2_normalize_beta1 = 7.47e-02
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.77e-01
# Hyperparams_test: L2_normalize_beta2 = 6.23e-02
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.25e-01
# Hyperparams_test: L2_normalize_beta3 = 5.56e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.99e-01
# Hyperparams_test: L2_normalize_beta4 = 5.71e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.76e-01
# Hyperparams_test: L2_normalize_beta5 = 4.17e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.55e-01
# Hyperparams_test: L2_normalize_beta6 = 5.00e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.34e-01
# Hyperparams_test: L2_normalize_beta7 = 4.69e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 92.96%
# Valid_train percent is : 92.75%
# ============================================================
# hyperparams_test runing iteration = 4/18
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 1.90e-01
# Hyperparams_test: L2_normalize_gama0 = 5.74e-01
# Hyperparams_test: L2_normalize_beta0 = 1.11e-01
# Hyperparams_test: L2_normalize_k1 = 9.01e-02
# Hyperparams_test: L2_normalize_gama1 = 4.42e-01
# Hyperparams_test: L2_normalize_beta1 = 9.69e-02
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.74e-01
# Hyperparams_test: L2_normalize_beta2 = 8.24e-02
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.23e-01
# Hyperparams_test: L2_normalize_beta3 = 6.71e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.97e-01
# Hyperparams_test: L2_normalize_beta4 = 6.76e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.75e-01
# Hyperparams_test: L2_normalize_beta5 = 4.47e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.54e-01
# Hyperparams_test: L2_normalize_beta6 = 5.61e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.29e-01
# Hyperparams_test: L2_normalize_beta7 = 4.55e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.11%
# Valid_train percent is : 93.95%
# ============================================================
# hyperparams_test runing iteration = 5/18
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.74e-01
# Hyperparams_test: L2_normalize_beta0 = 1.22e-01
# Hyperparams_test: L2_normalize_k1 = 9.01e-02
# Hyperparams_test: L2_normalize_gama1 = 4.41e-01
# Hyperparams_test: L2_normalize_beta1 = 1.09e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.73e-01
# Hyperparams_test: L2_normalize_beta2 = 9.21e-02
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.22e-01
# Hyperparams_test: L2_normalize_beta3 = 7.29e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.96e-01
# Hyperparams_test: L2_normalize_beta4 = 7.16e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.75e-01
# Hyperparams_test: L2_normalize_beta5 = 4.67e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 5.85e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.45e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.59%
# Valid_train percent is : 94.63%
# ============================================================
# hyperparams_test runing iteration = 6/18
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.74e-01
# Hyperparams_test: L2_normalize_beta0 = 1.30e-01
# Hyperparams_test: L2_normalize_k1 = 9.02e-02
# Hyperparams_test: L2_normalize_gama1 = 4.39e-01
# Hyperparams_test: L2_normalize_beta1 = 1.17e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.72e-01
# Hyperparams_test: L2_normalize_beta2 = 9.73e-02
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.21e-01
# Hyperparams_test: L2_normalize_beta3 = 7.57e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.96e-01
# Hyperparams_test: L2_normalize_beta4 = 7.34e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.78e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 5.95e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.38e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.92%
# Valid_train percent is : 95.05%
# ============================================================
# hyperparams_test runing iteration = 7/18
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.73e-01
# Hyperparams_test: L2_normalize_beta0 = 1.36e-01
# Hyperparams_test: L2_normalize_k1 = 9.02e-02
# Hyperparams_test: L2_normalize_gama1 = 4.39e-01
# Hyperparams_test: L2_normalize_beta1 = 1.21e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.71e-01
# Hyperparams_test: L2_normalize_beta2 = 1.01e-01
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.21e-01
# Hyperparams_test: L2_normalize_beta3 = 7.74e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.96e-01
# Hyperparams_test: L2_normalize_beta4 = 7.44e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.86e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 6.00e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.31e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.04%
# Valid_train percent is : 95.32%
# ============================================================
# hyperparams_test runing iteration = 8/18
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.73e-01
# Hyperparams_test: L2_normalize_beta0 = 1.40e-01
# Hyperparams_test: L2_normalize_k1 = 9.02e-02
# Hyperparams_test: L2_normalize_gama1 = 4.38e-01
# Hyperparams_test: L2_normalize_beta1 = 1.23e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.71e-01
# Hyperparams_test: L2_normalize_beta2 = 1.03e-01
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.21e-01
# Hyperparams_test: L2_normalize_beta3 = 7.85e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.95e-01
# Hyperparams_test: L2_normalize_beta4 = 7.49e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.89e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 6.04e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.27e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.04%
# Valid_train percent is : 95.49%
# ============================================================
# hyperparams_test runing iteration = 9/18
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.73e-01
# Hyperparams_test: L2_normalize_beta0 = 1.42e-01
# Hyperparams_test: L2_normalize_k1 = 9.03e-02
# Hyperparams_test: L2_normalize_gama1 = 4.38e-01
# Hyperparams_test: L2_normalize_beta1 = 1.25e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.70e-01
# Hyperparams_test: L2_normalize_beta2 = 1.04e-01
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.21e-01
# Hyperparams_test: L2_normalize_beta3 = 7.91e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.95e-01
# Hyperparams_test: L2_normalize_beta4 = 7.52e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.91e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 6.07e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.24e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.04%
# Valid_train percent is : 95.60%
# ============================================================
# hyperparams_test runing iteration = 10/18
# hyperparams_test runing: lri = 5.974e-05
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.73e-01
# Hyperparams_test: L2_normalize_beta0 = 1.44e-01
# Hyperparams_test: L2_normalize_k1 = 9.03e-02
# Hyperparams_test: L2_normalize_gama1 = 4.38e-01
# Hyperparams_test: L2_normalize_beta1 = 1.26e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.70e-01
# Hyperparams_test: L2_normalize_beta2 = 1.04e-01
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.20e-01
# Hyperparams_test: L2_normalize_beta3 = 7.96e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.95e-01
# Hyperparams_test: L2_normalize_beta4 = 7.54e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.92e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 6.08e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.22e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.08%
# Valid_train percent is : 95.64%
# ============================================================
# hyperparams_test runing iteration = 11/18
# hyperparams_test runing: lri = 4.044e-05
# Hyperparams_test: L2_normalize_k0 = 1.91e-01
# Hyperparams_test: L2_normalize_gama0 = 5.73e-01
# Hyperparams_test: L2_normalize_beta0 = 1.45e-01
# Hyperparams_test: L2_normalize_k1 = 9.03e-02
# Hyperparams_test: L2_normalize_gama1 = 4.38e-01
# Hyperparams_test: L2_normalize_beta1 = 1.26e-01
# Hyperparams_test: L2_normalize_k2 = 5.92e-02
# Hyperparams_test: L2_normalize_gama2 = 3.70e-01
# Hyperparams_test: L2_normalize_beta2 = 1.05e-01
# Hyperparams_test: L2_normalize_k3 = 3.90e-02
# Hyperparams_test: L2_normalize_gama3 = 3.20e-01
# Hyperparams_test: L2_normalize_beta3 = 7.98e-02
# Hyperparams_test: L2_normalize_k4 = 3.27e-02
# Hyperparams_test: L2_normalize_gama4 = 2.95e-01
# Hyperparams_test: L2_normalize_beta4 = 7.56e-02
# Hyperparams_test: L2_normalize_k5 = 2.78e-02
# Hyperparams_test: L2_normalize_gama5 = 2.74e-01
# Hyperparams_test: L2_normalize_beta5 = 4.92e-02
# Hyperparams_test: L2_normalize_k6 = 2.39e-02
# Hyperparams_test: L2_normalize_gama6 = 2.53e-01
# Hyperparams_test: L2_normalize_beta6 = 6.09e-02
# Hyperparams_test: L2_normalize_k7 = 2.11e-02
# Hyperparams_test: L2_normalize_gama7 = 1.28e-01
# Hyperparams_test: L2_normalize_beta7 = 4.21e-02
# Hyperparams_test: L2_normalize_w8 = 1.06e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.15%
