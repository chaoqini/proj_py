# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=3,nnode=512)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 3
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 32
# heyperparams_test: isupdate = 1
# params b0.shape= (512, 1)
# params w0.shape= (512, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params b1.shape= (512, 1)
# params w1.shape= (512, 512)
# params beta1.shape= ()
# params gama1.shape= ()
# params b2.shape= (10, 1)
# params w2.shape= (10, 512)
# params beta2.shape= ()
# params gama2.shape= ()
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.58e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.95e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 1.38e-05
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 1.00e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 96.63%
# Valid_train percent is : 96.80%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 9.162e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 6.40e-05
# Hyperparams_test: L2_normalize_beta0 = 4.18e-01
# Hyperparams_test: L2_normalize_gama0 = 4.34e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 5.69e-05
# Hyperparams_test: L2_normalize_beta1 = 3.04e-01
# Hyperparams_test: L2_normalize_gama1 = 5.46e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 3.85e-04
# Hyperparams_test: L2_normalize_beta2 = 2.42e-09
# Hyperparams_test: L2_normalize_gama2 = 1.90e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.45%
# Valid_train percent is : 98.37%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 4.197e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.41e-05
# Hyperparams_test: L2_normalize_beta0 = 4.74e-01
# Hyperparams_test: L2_normalize_gama0 = 3.76e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 7.39e-05
# Hyperparams_test: L2_normalize_beta1 = 3.82e-01
# Hyperparams_test: L2_normalize_gama1 = 4.62e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 5.47e-04
# Hyperparams_test: L2_normalize_beta2 = 1.10e-09
# Hyperparams_test: L2_normalize_gama2 = 2.30e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.92%
# Valid_train percent is : 99.26%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 1.923e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.72e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.72e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 7.94e-05
# Hyperparams_test: L2_normalize_beta1 = 3.99e-01
# Hyperparams_test: L2_normalize_gama1 = 4.44e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.24e-04
# Hyperparams_test: L2_normalize_beta2 = 1.65e-09
# Hyperparams_test: L2_normalize_gama2 = 2.47e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.14%
# Valid_train percent is : 99.60%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 8.807e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.84e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.72e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 8.13e-05
# Hyperparams_test: L2_normalize_beta1 = 4.07e-01
# Hyperparams_test: L2_normalize_gama1 = 4.36e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.52e-04
# Hyperparams_test: L2_normalize_beta2 = 1.00e-09
# Hyperparams_test: L2_normalize_gama2 = 2.56e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.12%
# Valid_train percent is : 99.78%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 4.034e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.88e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.71e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 8.21e-05
# Hyperparams_test: L2_normalize_beta1 = 4.11e-01
# Hyperparams_test: L2_normalize_gama1 = 4.32e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.62e-04
# Hyperparams_test: L2_normalize_beta2 = 9.43e-10
# Hyperparams_test: L2_normalize_gama2 = 2.61e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.20%
# Valid_train percent is : 99.84%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 1.848e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.90e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.71e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 8.24e-05
# Hyperparams_test: L2_normalize_beta1 = 4.13e-01
# Hyperparams_test: L2_normalize_gama1 = 4.31e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.66e-04
# Hyperparams_test: L2_normalize_beta2 = 8.38e-10
# Hyperparams_test: L2_normalize_gama2 = 2.63e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.22%
# Valid_train percent is : 99.86%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 8.466e-06
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.91e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.71e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 8.26e-05
# Hyperparams_test: L2_normalize_beta1 = 4.14e-01
# Hyperparams_test: L2_normalize_gama1 = 4.30e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.67e-04
# Hyperparams_test: L2_normalize_beta2 = 8.34e-10
# Hyperparams_test: L2_normalize_gama2 = 2.64e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.21%
# Valid_train percent is : 99.86%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 3.878e-06
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.91e-05
# Hyperparams_test: L2_normalize_beta0 = 4.79e-01
# Hyperparams_test: L2_normalize_gama0 = 3.71e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 8.26e-05
# Hyperparams_test: L2_normalize_beta1 = 4.14e-01
# Hyperparams_test: L2_normalize_gama1 = 4.29e-01
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 6.68e-04
# Hyperparams_test: L2_normalize_beta2 = 8.51e-10
# Hyperparams_test: L2_normalize_gama2 = 2.65e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.21%
# No handles with labels found to put in legend.
# Valid_train percent is : 99.86%

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d)=bnn.bnn.init_params(lays=3,nnode=200)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 3
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (200, 1)
# params w0.shape= (200, 784)
# params beta0.shape= (200, 1)
# params gama0.shape= (200, 1)
# params b1.shape= (200, 1)
# params w1.shape= (200, 200)
# params beta1.shape= (200, 1)
# params gama1.shape= (200, 1)
# params b2.shape= (10, 1)
# params w2.shape= (10, 200)
# params beta2.shape= (10, 1)
# params gama2.shape= (10, 1)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.52e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 6.81e-05
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 5.00e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 7.29e-05
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 2.23e-05
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 3.32e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 95.08%
# Valid_train percent is : 94.61%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 2.16e-03
# Hyperparams_test: L2_normalize_w0 = 1.44e-04
# Hyperparams_test: L2_normalize_beta0 = 1.41e-03
# Hyperparams_test: L2_normalize_gama0 = 6.28e-03
# Hyperparams_test: L2_normalize_b1 = 1.34e-03
# Hyperparams_test: L2_normalize_w1 = 2.12e-04
# Hyperparams_test: L2_normalize_beta1 = 1.54e-03
# Hyperparams_test: L2_normalize_gama1 = 5.34e-03
# Hyperparams_test: L2_normalize_b2 = 4.63e-03
# Hyperparams_test: L2_normalize_w2 = 1.06e-03
# Hyperparams_test: L2_normalize_beta2 = 2.13e-02
# Hyperparams_test: L2_normalize_gama2 = 3.93e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.94%
# Valid_train percent is : 97.44%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 2.42e-03
# Hyperparams_test: L2_normalize_w0 = 1.60e-04
# Hyperparams_test: L2_normalize_beta0 = 1.46e-03
# Hyperparams_test: L2_normalize_gama0 = 6.86e-03
# Hyperparams_test: L2_normalize_b1 = 1.69e-03
# Hyperparams_test: L2_normalize_w1 = 2.32e-04
# Hyperparams_test: L2_normalize_beta1 = 1.61e-03
# Hyperparams_test: L2_normalize_gama1 = 5.79e-03
# Hyperparams_test: L2_normalize_b2 = 6.67e-03
# Hyperparams_test: L2_normalize_w2 = 1.19e-03
# Hyperparams_test: L2_normalize_beta2 = 2.38e-02
# Hyperparams_test: L2_normalize_gama2 = 5.51e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.10%
# Valid_train percent is : 98.16%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 2.59e-03
# Hyperparams_test: L2_normalize_w0 = 1.67e-04
# Hyperparams_test: L2_normalize_beta0 = 1.47e-03
# Hyperparams_test: L2_normalize_gama0 = 7.12e-03
# Hyperparams_test: L2_normalize_b1 = 1.99e-03
# Hyperparams_test: L2_normalize_w1 = 2.41e-04
# Hyperparams_test: L2_normalize_beta1 = 1.64e-03
# Hyperparams_test: L2_normalize_gama1 = 6.00e-03
# Hyperparams_test: L2_normalize_b2 = 6.63e-03
# Hyperparams_test: L2_normalize_w2 = 1.25e-03
# Hyperparams_test: L2_normalize_beta2 = 2.27e-02
# Hyperparams_test: L2_normalize_gama2 = 6.12e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.42%
# Valid_train percent is : 98.67%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 2.73e-03
# Hyperparams_test: L2_normalize_w0 = 1.70e-04
# Hyperparams_test: L2_normalize_beta0 = 1.47e-03
# Hyperparams_test: L2_normalize_gama0 = 7.22e-03
# Hyperparams_test: L2_normalize_b1 = 2.07e-03
# Hyperparams_test: L2_normalize_w1 = 2.45e-04
# Hyperparams_test: L2_normalize_beta1 = 1.65e-03
# Hyperparams_test: L2_normalize_gama1 = 6.10e-03
# Hyperparams_test: L2_normalize_b2 = 6.22e-03
# Hyperparams_test: L2_normalize_w2 = 1.28e-03
# Hyperparams_test: L2_normalize_beta2 = 2.21e-02
# Hyperparams_test: L2_normalize_gama2 = 6.40e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.42%
# Valid_train percent is : 98.92%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 2.79e-03
# Hyperparams_test: L2_normalize_w0 = 1.71e-04
# Hyperparams_test: L2_normalize_beta0 = 1.48e-03
# Hyperparams_test: L2_normalize_gama0 = 7.27e-03
# Hyperparams_test: L2_normalize_b1 = 2.09e-03
# Hyperparams_test: L2_normalize_w1 = 2.46e-04
# Hyperparams_test: L2_normalize_beta1 = 1.65e-03
# Hyperparams_test: L2_normalize_gama1 = 6.16e-03
# Hyperparams_test: L2_normalize_b2 = 5.75e-03
# Hyperparams_test: L2_normalize_w2 = 1.30e-03
# Hyperparams_test: L2_normalize_beta2 = 2.19e-02
# Hyperparams_test: L2_normalize_gama2 = 6.56e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.50%
# Valid_train percent is : 99.07%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 2.81e-03
# Hyperparams_test: L2_normalize_w0 = 1.72e-04
# Hyperparams_test: L2_normalize_beta0 = 1.47e-03
# Hyperparams_test: L2_normalize_gama0 = 7.30e-03
# Hyperparams_test: L2_normalize_b1 = 2.09e-03
# Hyperparams_test: L2_normalize_w1 = 2.47e-04
# Hyperparams_test: L2_normalize_beta1 = 1.65e-03
# Hyperparams_test: L2_normalize_gama1 = 6.18e-03
# Hyperparams_test: L2_normalize_b2 = 5.50e-03
# Hyperparams_test: L2_normalize_w2 = 1.31e-03
# Hyperparams_test: L2_normalize_beta2 = 2.19e-02
# Hyperparams_test: L2_normalize_gama2 = 6.64e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.49%
# Valid_train percent is : 99.13%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 2.82e-03
# Hyperparams_test: L2_normalize_w0 = 1.72e-04
# Hyperparams_test: L2_normalize_beta0 = 1.47e-03
# Hyperparams_test: L2_normalize_gama0 = 7.31e-03
# Hyperparams_test: L2_normalize_b1 = 2.05e-03
# Hyperparams_test: L2_normalize_w1 = 2.48e-04
# Hyperparams_test: L2_normalize_beta1 = 1.65e-03
# Hyperparams_test: L2_normalize_gama1 = 6.20e-03
# Hyperparams_test: L2_normalize_b2 = 5.38e-03
# Hyperparams_test: L2_normalize_w2 = 1.32e-03
# Hyperparams_test: L2_normalize_beta2 = 2.19e-02
# Hyperparams_test: L2_normalize_gama2 = 6.68e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.51%
# Valid_train percent is : 99.20%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 2.82e-03
# Hyperparams_test: L2_normalize_w0 = 1.72e-04
# Hyperparams_test: L2_normalize_beta0 = 1.47e-03
# Hyperparams_test: L2_normalize_gama0 = 7.32e-03
# Hyperparams_test: L2_normalize_b1 = 2.01e-03
# Hyperparams_test: L2_normalize_w1 = 2.48e-04
# Hyperparams_test: L2_normalize_beta1 = 1.65e-03
# Hyperparams_test: L2_normalize_gama1 = 6.20e-03
# Hyperparams_test: L2_normalize_b2 = 5.33e-03
# Hyperparams_test: L2_normalize_w2 = 1.32e-03
# Hyperparams_test: L2_normalize_beta2 = 2.19e-02
# Hyperparams_test: L2_normalize_gama2 = 6.71e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 97.51%
# Valid_train percent is : 99.22%
# No handles with labels found to put in legend.
