# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d)=bnn.bnn.init_params(lays=3,nnode=500)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params beta0.shape= (100, 1)
# params gama0.shape= (100, 1)
# params b1.shape= (10, 1)
# params w1.shape= (10, 100)
# params beta1.shape= (10, 1)
# params gama1.shape= (10, 1)
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 3.56e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 9.21e-05
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 3.12e-05
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 2.84e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 94.20%
# Valid_train percent is : 94.19%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.98e-04
# Hyperparams_test: L2_normalize_beta0 = 1.66e-03
# Hyperparams_test: L2_normalize_gama0 = 7.84e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.36e-03
# Hyperparams_test: L2_normalize_beta1 = 1.85e-02
# Hyperparams_test: L2_normalize_gama1 = 3.86e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 95.72%
# Valid_train percent is : 95.83%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.28e-04
# Hyperparams_test: L2_normalize_beta0 = 1.78e-03
# Hyperparams_test: L2_normalize_gama0 = 8.57e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.50e-03
# Hyperparams_test: L2_normalize_beta1 = 1.78e-02
# Hyperparams_test: L2_normalize_gama1 = 5.47e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 95.96%
# Valid_train percent is : 96.59%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.42e-04
# Hyperparams_test: L2_normalize_beta0 = 1.80e-03
# Hyperparams_test: L2_normalize_gama0 = 8.83e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.56e-03
# Hyperparams_test: L2_normalize_beta1 = 1.91e-02
# Hyperparams_test: L2_normalize_gama1 = 6.07e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.02%
# Valid_train percent is : 96.88%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.49e-04
# Hyperparams_test: L2_normalize_beta0 = 1.80e-03
# Hyperparams_test: L2_normalize_gama0 = 8.93e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.57e-03
# Hyperparams_test: L2_normalize_beta1 = 2.03e-02
# Hyperparams_test: L2_normalize_gama1 = 6.34e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.09%
# Valid_train percent is : 97.04%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.53e-04
# Hyperparams_test: L2_normalize_beta0 = 1.78e-03
# Hyperparams_test: L2_normalize_gama0 = 8.99e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.59e-03
# Hyperparams_test: L2_normalize_beta1 = 2.10e-02
# Hyperparams_test: L2_normalize_gama1 = 6.47e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.11%
# Valid_train percent is : 97.12%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.55e-04
# Hyperparams_test: L2_normalize_beta0 = 1.77e-03
# Hyperparams_test: L2_normalize_gama0 = 9.01e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.59e-03
# Hyperparams_test: L2_normalize_beta1 = 2.14e-02
# Hyperparams_test: L2_normalize_gama1 = 6.54e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.11%
# Valid_train percent is : 97.18%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.56e-04
# Hyperparams_test: L2_normalize_beta0 = 1.76e-03
# Hyperparams_test: L2_normalize_gama0 = 9.03e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.60e-03
# Hyperparams_test: L2_normalize_beta1 = 2.16e-02
# Hyperparams_test: L2_normalize_gama1 = 6.58e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.14%
# Valid_train percent is : 97.22%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.56e-04
# Hyperparams_test: L2_normalize_beta0 = 1.76e-03
# Hyperparams_test: L2_normalize_gama0 = 9.03e-03
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.60e-03
# Hyperparams_test: L2_normalize_beta1 = 2.17e-02
# Hyperparams_test: L2_normalize_gama1 = 6.60e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.13%
# Valid_train percent is : 97.24%
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-55e8a226e936> in <module>
#       3 import imp
#       4 imp.reload(bnn)
# ----> 5 (params,params_init,g,g_d)=bnn.bnn.init_params(lays=3,nnode=500)
#       6 bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
#
# ValueError: too many values to unpack (expected 4)

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d)=bnn.bnn.init_params(lays=5,nnode=200)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (200, 1)
# params w0.shape= (200, 784)
# params beta0.shape= (200, 1)
# params gama0.shape= (200, 1)
# params b1.shape= (200, 1)
# params w1.shape= (200, 200)
# params beta1.shape= (200, 1)
# params gama1.shape= (200, 1)
# params b2.shape= (200, 1)
# params w2.shape= (200, 200)
# params beta2.shape= (200, 1)
# params gama2.shape= (200, 1)
# params b3.shape= (200, 1)
# params w3.shape= (200, 200)
# params beta3.shape= (200, 1)
# params gama3.shape= (200, 1)
# params b4.shape= (10, 1)
# params w4.shape= (10, 200)
# params beta4.shape= (10, 1)
# params gama4.shape= (10, 1)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 2.52e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 6.81e-05
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 5.00e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 7.29e-05
# Hyperparams_test: L2_normalize_b2 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 4.98e-06
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 7.75e-05
# Hyperparams_test: L2_normalize_b3 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 5.00e-06
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_gama3 = 7.23e-05
# Hyperparams_test: L2_normalize_b4 = 0.00e+00
# Hyperparams_test: L2_normalize_w4 = 2.22e-05
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_gama4 = 3.30e-04
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 92.56%
# Valid_train percent is : 92.19%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.071e-03
# Hyperparams_test: L2_normalize_b0 = 3.21e-03
# Hyperparams_test: L2_normalize_w0 = 1.65e-04
# Hyperparams_test: L2_normalize_beta0 = 1.95e-03
# Hyperparams_test: L2_normalize_gama0 = 3.85e-03
# Hyperparams_test: L2_normalize_b1 = 2.09e-03
# Hyperparams_test: L2_normalize_w1 = 1.54e-04
# Hyperparams_test: L2_normalize_beta1 = 1.57e-03
# Hyperparams_test: L2_normalize_gama1 = 4.98e-03
# Hyperparams_test: L2_normalize_b2 = 4.47e-03
# Hyperparams_test: L2_normalize_w2 = 1.86e-04
# Hyperparams_test: L2_normalize_beta2 = 1.61e-03
# Hyperparams_test: L2_normalize_gama2 = 4.34e-03
# Hyperparams_test: L2_normalize_b3 = 1.74e-03
# Hyperparams_test: L2_normalize_w3 = 1.78e-04
# Hyperparams_test: L2_normalize_beta3 = 1.52e-03
# Hyperparams_test: L2_normalize_gama3 = 5.72e-03
# Hyperparams_test: L2_normalize_b4 = 1.01e-02
# Hyperparams_test: L2_normalize_w4 = 1.02e-03
# Hyperparams_test: L2_normalize_beta4 = 2.71e-02
# Hyperparams_test: L2_normalize_gama4 = 4.08e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 94.99%
# Valid_train percent is : 95.16%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 5.734e-04
# Hyperparams_test: L2_normalize_b0 = 3.02e-03
# Hyperparams_test: L2_normalize_w0 = 1.81e-04
# Hyperparams_test: L2_normalize_beta0 = 2.13e-03
# Hyperparams_test: L2_normalize_gama0 = 4.32e-03
# Hyperparams_test: L2_normalize_b1 = 2.24e-03
# Hyperparams_test: L2_normalize_w1 = 1.72e-04
# Hyperparams_test: L2_normalize_beta1 = 1.69e-03
# Hyperparams_test: L2_normalize_gama1 = 5.38e-03
# Hyperparams_test: L2_normalize_b2 = 4.59e-03
# Hyperparams_test: L2_normalize_w2 = 1.94e-04
# Hyperparams_test: L2_normalize_beta2 = 1.84e-03
# Hyperparams_test: L2_normalize_gama2 = 4.74e-03
# Hyperparams_test: L2_normalize_b3 = 2.05e-03
# Hyperparams_test: L2_normalize_w3 = 1.90e-04
# Hyperparams_test: L2_normalize_beta3 = 1.64e-03
# Hyperparams_test: L2_normalize_gama3 = 5.95e-03
# Hyperparams_test: L2_normalize_b4 = 1.17e-02
# Hyperparams_test: L2_normalize_w4 = 1.10e-03
# Hyperparams_test: L2_normalize_beta4 = 3.42e-02
# Hyperparams_test: L2_normalize_gama4 = 5.40e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 95.70%
# Valid_train percent is : 96.13%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 3.070e-04
# Hyperparams_test: L2_normalize_b0 = 3.31e-03
# Hyperparams_test: L2_normalize_w0 = 1.88e-04
# Hyperparams_test: L2_normalize_beta0 = 2.21e-03
# Hyperparams_test: L2_normalize_gama0 = 4.48e-03
# Hyperparams_test: L2_normalize_b1 = 2.16e-03
# Hyperparams_test: L2_normalize_w1 = 1.79e-04
# Hyperparams_test: L2_normalize_beta1 = 1.72e-03
# Hyperparams_test: L2_normalize_gama1 = 5.61e-03
# Hyperparams_test: L2_normalize_b2 = 4.61e-03
# Hyperparams_test: L2_normalize_w2 = 2.00e-04
# Hyperparams_test: L2_normalize_beta2 = 1.88e-03
# Hyperparams_test: L2_normalize_gama2 = 4.85e-03
# Hyperparams_test: L2_normalize_b3 = 1.97e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.70e-03
# Hyperparams_test: L2_normalize_gama3 = 6.06e-03
# Hyperparams_test: L2_normalize_b4 = 1.24e-02
# Hyperparams_test: L2_normalize_w4 = 1.12e-03
# Hyperparams_test: L2_normalize_beta4 = 3.75e-02
# Hyperparams_test: L2_normalize_gama4 = 5.91e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.15%
# Valid_train percent is : 96.69%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 1.644e-04
# Hyperparams_test: L2_normalize_b0 = 3.57e-03
# Hyperparams_test: L2_normalize_w0 = 1.92e-04
# Hyperparams_test: L2_normalize_beta0 = 2.24e-03
# Hyperparams_test: L2_normalize_gama0 = 4.54e-03
# Hyperparams_test: L2_normalize_b1 = 2.24e-03
# Hyperparams_test: L2_normalize_w1 = 1.82e-04
# Hyperparams_test: L2_normalize_beta1 = 1.73e-03
# Hyperparams_test: L2_normalize_gama1 = 5.72e-03
# Hyperparams_test: L2_normalize_b2 = 4.58e-03
# Hyperparams_test: L2_normalize_w2 = 2.04e-04
# Hyperparams_test: L2_normalize_beta2 = 1.88e-03
# Hyperparams_test: L2_normalize_gama2 = 4.90e-03
# Hyperparams_test: L2_normalize_b3 = 2.00e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.70e-03
# Hyperparams_test: L2_normalize_gama3 = 6.12e-03
# Hyperparams_test: L2_normalize_b4 = 1.25e-02
# Hyperparams_test: L2_normalize_w4 = 1.14e-03
# Hyperparams_test: L2_normalize_beta4 = 4.00e-02
# Hyperparams_test: L2_normalize_gama4 = 6.15e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.28%
# Valid_train percent is : 97.03%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 8.803e-05
# Hyperparams_test: L2_normalize_b0 = 3.67e-03
# Hyperparams_test: L2_normalize_w0 = 1.94e-04
# Hyperparams_test: L2_normalize_beta0 = 2.26e-03
# Hyperparams_test: L2_normalize_gama0 = 4.58e-03
# Hyperparams_test: L2_normalize_b1 = 2.26e-03
# Hyperparams_test: L2_normalize_w1 = 1.83e-04
# Hyperparams_test: L2_normalize_beta1 = 1.74e-03
# Hyperparams_test: L2_normalize_gama1 = 5.79e-03
# Hyperparams_test: L2_normalize_b2 = 4.60e-03
# Hyperparams_test: L2_normalize_w2 = 2.06e-04
# Hyperparams_test: L2_normalize_beta2 = 1.88e-03
# Hyperparams_test: L2_normalize_gama2 = 4.92e-03
# Hyperparams_test: L2_normalize_b3 = 1.99e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.70e-03
# Hyperparams_test: L2_normalize_gama3 = 6.13e-03
# Hyperparams_test: L2_normalize_b4 = 1.26e-02
# Hyperparams_test: L2_normalize_w4 = 1.15e-03
# Hyperparams_test: L2_normalize_beta4 = 4.15e-02
# Hyperparams_test: L2_normalize_gama4 = 6.27e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.39%
# Valid_train percent is : 97.25%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 4.713e-05
# Hyperparams_test: L2_normalize_b0 = 3.69e-03
# Hyperparams_test: L2_normalize_w0 = 1.95e-04
# Hyperparams_test: L2_normalize_beta0 = 2.27e-03
# Hyperparams_test: L2_normalize_gama0 = 4.60e-03
# Hyperparams_test: L2_normalize_b1 = 2.26e-03
# Hyperparams_test: L2_normalize_w1 = 1.84e-04
# Hyperparams_test: L2_normalize_beta1 = 1.74e-03
# Hyperparams_test: L2_normalize_gama1 = 5.83e-03
# Hyperparams_test: L2_normalize_b2 = 4.59e-03
# Hyperparams_test: L2_normalize_w2 = 2.07e-04
# Hyperparams_test: L2_normalize_beta2 = 1.88e-03
# Hyperparams_test: L2_normalize_gama2 = 4.94e-03
# Hyperparams_test: L2_normalize_b3 = 1.99e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.69e-03
# Hyperparams_test: L2_normalize_gama3 = 6.14e-03
# Hyperparams_test: L2_normalize_b4 = 1.27e-02
# Hyperparams_test: L2_normalize_w4 = 1.15e-03
# Hyperparams_test: L2_normalize_beta4 = 4.23e-02
# Hyperparams_test: L2_normalize_gama4 = 6.34e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.46%
# Valid_train percent is : 97.42%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 2.524e-05
# Hyperparams_test: L2_normalize_b0 = 3.71e-03
# Hyperparams_test: L2_normalize_w0 = 1.95e-04
# Hyperparams_test: L2_normalize_beta0 = 2.28e-03
# Hyperparams_test: L2_normalize_gama0 = 4.61e-03
# Hyperparams_test: L2_normalize_b1 = 2.25e-03
# Hyperparams_test: L2_normalize_w1 = 1.85e-04
# Hyperparams_test: L2_normalize_beta1 = 1.74e-03
# Hyperparams_test: L2_normalize_gama1 = 5.85e-03
# Hyperparams_test: L2_normalize_b2 = 4.60e-03
# Hyperparams_test: L2_normalize_w2 = 2.07e-04
# Hyperparams_test: L2_normalize_beta2 = 1.88e-03
# Hyperparams_test: L2_normalize_gama2 = 4.94e-03
# Hyperparams_test: L2_normalize_b3 = 1.97e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.69e-03
# Hyperparams_test: L2_normalize_gama3 = 6.15e-03
# Hyperparams_test: L2_normalize_b4 = 1.27e-02
# Hyperparams_test: L2_normalize_w4 = 1.15e-03
# Hyperparams_test: L2_normalize_beta4 = 4.27e-02
# Hyperparams_test: L2_normalize_gama4 = 6.38e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.47%
# Valid_train percent is : 97.49%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 1.351e-05
# Hyperparams_test: L2_normalize_b0 = 3.71e-03
# Hyperparams_test: L2_normalize_w0 = 1.96e-04
# Hyperparams_test: L2_normalize_beta0 = 2.28e-03
# Hyperparams_test: L2_normalize_gama0 = 4.62e-03
# Hyperparams_test: L2_normalize_b1 = 2.25e-03
# Hyperparams_test: L2_normalize_w1 = 1.85e-04
# Hyperparams_test: L2_normalize_beta1 = 1.75e-03
# Hyperparams_test: L2_normalize_gama1 = 5.86e-03
# Hyperparams_test: L2_normalize_b2 = 4.60e-03
# Hyperparams_test: L2_normalize_w2 = 2.08e-04
# Hyperparams_test: L2_normalize_beta2 = 1.87e-03
# Hyperparams_test: L2_normalize_gama2 = 4.95e-03
# Hyperparams_test: L2_normalize_b3 = 1.97e-03
# Hyperparams_test: L2_normalize_w3 = 1.91e-04
# Hyperparams_test: L2_normalize_beta3 = 1.69e-03
# Hyperparams_test: L2_normalize_gama3 = 6.16e-03
# Hyperparams_test: L2_normalize_b4 = 1.27e-02
# Hyperparams_test: L2_normalize_w4 = 1.15e-03
# Hyperparams_test: L2_normalize_beta4 = 4.29e-02
# Hyperparams_test: L2_normalize_gama4 = 6.40e-01
# Train input X.shape=(1250, 40, 784, 1), LAB.shape=(1250, 40, 1, 1)
# Training bath running ...
# Training iteration number = 0/1250
# Training iteration number = 125/1250
# Training iteration number = 250/1250
# Training iteration number = 375/1250
# Training iteration number = 500/1250
# Training iteration number = 625/1250
# Training iteration number = 750/1250
# Training iteration number = 875/1250
# Training iteration number = 1000/1250
# Training iteration number = 1125/1250
# Training iteration number = 1249/1250
# Valid percent is : 96.47%
# No handles with labels found to put in legend.
# Valid_train percent is : 97.54%
