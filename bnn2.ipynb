# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=3,nnode=256)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 32
# heyperparams_test: isupdate = 1
# params w0.shape= (256, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params w1.shape= (256, 256)
# params beta1.shape= ()
# params gama1.shape= ()
# params w2.shape= (10, 256)
# params beta2.shape= ()
# params gama2.shape= ()
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_w0 = 2.23e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_w1 = 3.90e-06
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Hyperparams_test: L2_normalize_w2 = 1.99e-05
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_gama2 = 1.00e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 96.02%
# Valid_train percent is : 96.06%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 9.162e-04
# Hyperparams_test: L2_normalize_w0 = 8.77e-05
# Hyperparams_test: L2_normalize_beta0 = 3.89e-01
# Hyperparams_test: L2_normalize_gama0 = 4.78e-01
# Hyperparams_test: L2_normalize_w1 = 1.16e-04
# Hyperparams_test: L2_normalize_beta1 = 3.02e-01
# Hyperparams_test: L2_normalize_gama1 = 5.02e-01
# Hyperparams_test: L2_normalize_w2 = 5.40e-04
# Hyperparams_test: L2_normalize_beta2 = 1.13e-09
# Hyperparams_test: L2_normalize_gama2 = 1.92e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.31%
# Valid_train percent is : 98.14%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 4.197e-04
# Hyperparams_test: L2_normalize_w0 = 1.05e-04
# Hyperparams_test: L2_normalize_beta0 = 4.35e-01
# Hyperparams_test: L2_normalize_gama0 = 4.32e-01
# Hyperparams_test: L2_normalize_w1 = 1.53e-04
# Hyperparams_test: L2_normalize_beta1 = 3.74e-01
# Hyperparams_test: L2_normalize_gama1 = 4.27e-01
# Hyperparams_test: L2_normalize_w2 = 7.94e-04
# Hyperparams_test: L2_normalize_beta2 = 1.55e-09
# Hyperparams_test: L2_normalize_gama2 = 2.30e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.84%
# Valid_train percent is : 99.17%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 1.923e-04
# Hyperparams_test: L2_normalize_w0 = 1.10e-04
# Hyperparams_test: L2_normalize_beta0 = 4.36e-01
# Hyperparams_test: L2_normalize_gama0 = 4.31e-01
# Hyperparams_test: L2_normalize_w1 = 1.65e-04
# Hyperparams_test: L2_normalize_beta1 = 3.91e-01
# Hyperparams_test: L2_normalize_gama1 = 4.10e-01
# Hyperparams_test: L2_normalize_w2 = 8.86e-04
# Hyperparams_test: L2_normalize_beta2 = 4.38e-10
# Hyperparams_test: L2_normalize_gama2 = 2.48e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.87%
# Valid_train percent is : 99.55%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 8.807e-05
# Hyperparams_test: L2_normalize_w0 = 1.11e-04
# Hyperparams_test: L2_normalize_beta0 = 4.32e-01
# Hyperparams_test: L2_normalize_gama0 = 4.34e-01
# Hyperparams_test: L2_normalize_w1 = 1.69e-04
# Hyperparams_test: L2_normalize_beta1 = 3.96e-01
# Hyperparams_test: L2_normalize_gama1 = 4.05e-01
# Hyperparams_test: L2_normalize_w2 = 9.17e-04
# Hyperparams_test: L2_normalize_beta2 = 1.10e-09
# Hyperparams_test: L2_normalize_gama2 = 2.57e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.84%
# Valid_train percent is : 99.75%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 4.034e-05
# Hyperparams_test: L2_normalize_w0 = 1.12e-04
# Hyperparams_test: L2_normalize_beta0 = 4.31e-01
# Hyperparams_test: L2_normalize_gama0 = 4.35e-01
# Hyperparams_test: L2_normalize_w1 = 1.70e-04
# Hyperparams_test: L2_normalize_beta1 = 4.00e-01
# Hyperparams_test: L2_normalize_gama1 = 4.00e-01
# Hyperparams_test: L2_normalize_w2 = 9.26e-04
# Hyperparams_test: L2_normalize_beta2 = 9.69e-10
# Hyperparams_test: L2_normalize_gama2 = 2.62e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.85%
# Valid_train percent is : 99.83%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 1.848e-05
# Hyperparams_test: L2_normalize_w0 = 1.12e-04
# Hyperparams_test: L2_normalize_beta0 = 4.31e-01
# Hyperparams_test: L2_normalize_gama0 = 4.35e-01
# Hyperparams_test: L2_normalize_w1 = 1.71e-04
# Hyperparams_test: L2_normalize_beta1 = 4.02e-01
# Hyperparams_test: L2_normalize_gama1 = 3.98e-01
# Hyperparams_test: L2_normalize_w2 = 9.29e-04
# Hyperparams_test: L2_normalize_beta2 = 9.20e-10
# Hyperparams_test: L2_normalize_gama2 = 2.65e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.92%
# Valid_train percent is : 99.85%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 8.466e-06
# Hyperparams_test: L2_normalize_w0 = 1.12e-04
# Hyperparams_test: L2_normalize_beta0 = 4.31e-01
# Hyperparams_test: L2_normalize_gama0 = 4.35e-01
# Hyperparams_test: L2_normalize_w1 = 1.71e-04
# Hyperparams_test: L2_normalize_beta1 = 4.03e-01
# Hyperparams_test: L2_normalize_gama1 = 3.97e-01
# Hyperparams_test: L2_normalize_w2 = 9.30e-04
# Hyperparams_test: L2_normalize_beta2 = 8.77e-10
# Hyperparams_test: L2_normalize_gama2 = 2.66e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.91%
# Valid_train percent is : 99.86%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 3.878e-06
# Hyperparams_test: L2_normalize_w0 = 1.12e-04
# Hyperparams_test: L2_normalize_beta0 = 4.31e-01
# Hyperparams_test: L2_normalize_gama0 = 4.35e-01
# Hyperparams_test: L2_normalize_w1 = 1.71e-04
# Hyperparams_test: L2_normalize_beta1 = 4.04e-01
# Hyperparams_test: L2_normalize_gama1 = 3.97e-01
# Hyperparams_test: L2_normalize_w2 = 9.31e-04
# Hyperparams_test: L2_normalize_beta2 = 9.17e-10
# Hyperparams_test: L2_normalize_gama2 = 2.67e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.93%
# No handles with labels found to put in legend.
# Valid_train percent is : 99.86%

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=2,nnode=512)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 32
# heyperparams_test: isupdate = 1
# params b0.shape= (512, 1)
# params w0.shape= (512, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params b1.shape= (10, 1)
# params w1.shape= (10, 512)
# params beta1.shape= ()
# params gama1.shape= ()
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 1.58e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.39e-05
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 96.51%
# Valid_train percent is : 96.65%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 9.162e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 6.01e-05
# Hyperparams_test: L2_normalize_beta0 = 4.00e-01
# Hyperparams_test: L2_normalize_gama0 = 3.61e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 4.35e-04
# Hyperparams_test: L2_normalize_beta1 = 3.57e-09
# Hyperparams_test: L2_normalize_gama1 = 2.01e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.37%
# Valid_train percent is : 98.49%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 4.197e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.19e-05
# Hyperparams_test: L2_normalize_beta0 = 4.42e-01
# Hyperparams_test: L2_normalize_gama0 = 3.19e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.03e-04
# Hyperparams_test: L2_normalize_beta1 = 5.60e-09
# Hyperparams_test: L2_normalize_gama1 = 2.53e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.68%
# Valid_train percent is : 99.23%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 1.923e-04
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.56e-05
# Hyperparams_test: L2_normalize_beta0 = 4.47e-01
# Hyperparams_test: L2_normalize_gama0 = 3.14e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.64e-04
# Hyperparams_test: L2_normalize_beta1 = 6.02e-09
# Hyperparams_test: L2_normalize_gama1 = 2.75e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.86%
# Valid_train percent is : 99.56%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 8.807e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.71e-05
# Hyperparams_test: L2_normalize_beta0 = 4.50e-01
# Hyperparams_test: L2_normalize_gama0 = 3.11e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.83e-04
# Hyperparams_test: L2_normalize_beta1 = 6.42e-09
# Hyperparams_test: L2_normalize_gama1 = 2.87e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 97.98%
# Valid_train percent is : 99.76%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 4.034e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.76e-05
# Hyperparams_test: L2_normalize_beta0 = 4.51e-01
# Hyperparams_test: L2_normalize_gama0 = 3.10e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.91e-04
# Hyperparams_test: L2_normalize_beta1 = 5.99e-09
# Hyperparams_test: L2_normalize_gama1 = 2.92e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.00%
# Valid_train percent is : 99.83%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 1.848e-05
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.78e-05
# Hyperparams_test: L2_normalize_beta0 = 4.51e-01
# Hyperparams_test: L2_normalize_gama0 = 3.10e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.94e-04
# Hyperparams_test: L2_normalize_beta1 = 6.10e-09
# Hyperparams_test: L2_normalize_gama1 = 2.95e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.07%
# Valid_train percent is : 99.84%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 8.466e-06
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.79e-05
# Hyperparams_test: L2_normalize_beta0 = 4.51e-01
# Hyperparams_test: L2_normalize_gama0 = 3.10e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.95e-04
# Hyperparams_test: L2_normalize_beta1 = 6.11e-09
# Hyperparams_test: L2_normalize_gama1 = 2.97e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.03%
# Valid_train percent is : 99.85%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 3.878e-06
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 7.79e-05
# Hyperparams_test: L2_normalize_beta0 = 4.51e-01
# Hyperparams_test: L2_normalize_gama0 = 3.10e-01
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 6.95e-04
# Hyperparams_test: L2_normalize_beta1 = 6.08e-09
# Hyperparams_test: L2_normalize_gama1 = 2.97e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# Training iteration number = 156/1562
# Training iteration number = 312/1562
# Training iteration number = 468/1562
# Training iteration number = 624/1562
# Training iteration number = 780/1562
# Training iteration number = 936/1562
# Training iteration number = 1092/1562
# Training iteration number = 1248/1562
# Training iteration number = 1404/1562
# Training iteration number = 1560/1562
# Training iteration number = 1561/1562
# Valid percent is : 98.03%
# No handles with labels found to put in legend.
# Valid_train percent is : 99.85%
