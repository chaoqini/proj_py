# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
(params,params_init,g,g_d)=dnn.dnn.init_params(lays=5,nnode=100)
dnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=20,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 20
# heyperparams_test: isupdate = 1
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# params b2.shape= (100, 1)
# params w2.shape= (100, 100)
# params b3.shape= (100, 1)
# params w3.shape= (100, 100)
# params b4.shape= (10, 1)
# params w4.shape= (10, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: log_loss
# ...
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 3.56e-06
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.00e-05
# ...

# %%
import dnn
import numpy as np
import imp
imp.reload(dnn)
(params,params_init,g,g_d)=dnn.dnn.init_params(lays=5,nnode=100)
dnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=40,isupdate=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 5
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 40
# heyperparams_test: isupdate = 1
# params b0.shape= (100, 1)
# params w0.shape= (100, 784)
# params b1.shape= (100, 1)
# params w1.shape= (100, 100)
# params b2.shape= (100, 1)
# params w2.shape= (100, 100)
# params b3.shape= (100, 1)
# params w3.shape= (100, 100)
# params b4.shape= (10, 1)
# params w4.shape= (10, 100)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: softmax
# active function g[5] is: log_loss
# ...
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 3.56e-06
# Hyperparams_test: L2_normalize_b1 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.00e-05
# ...
