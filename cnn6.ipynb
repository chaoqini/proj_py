# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=4,imch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
with open('cnn_p6.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p6.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 4
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (5, 1, 3, 3)
# params gama0.shape= (5, 1, 1)
# params beta0.shape= (5, 1, 1)
# params k1.shape= (9, 5, 3, 3)
# params gama1.shape= (9, 1, 1)
# params beta1.shape= (9, 1, 1)
# params k2.shape= (13, 9, 3, 3)
# params gama2.shape= (13, 1, 1)
# params beta2.shape= (13, 1, 1)
# params w3.shape= (10, 13, 7, 7)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: softmax
# active function g[4] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 1.42e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.33e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 1.24e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 85.05%
# Valid_train percent is : 83.97%
# ============================================================
# hyperparams_test runing iteration = 2/18
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 1.43e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 9.31e-02
# Hyperparams_test: L2_normalize_k1 = 5.05e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 5.32e-02
# Hyperparams_test: L2_normalize_k2 = 3.11e-02
# Hyperparams_test: L2_normalize_gama2 = 1.84e-01
# Hyperparams_test: L2_normalize_beta2 = 3.64e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 91.69%
# Valid_train percent is : 91.01%
# ============================================================
# hyperparams_test runing iteration = 3/18
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 1.44e-01
# Hyperparams_test: L2_normalize_gama0 = 4.49e-01
# Hyperparams_test: L2_normalize_beta0 = 1.23e-01
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.39e-01
# Hyperparams_test: L2_normalize_beta1 = 6.85e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.51e-01
# Hyperparams_test: L2_normalize_beta2 = 3.62e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 93.28%
# Valid_train percent is : 93.05%
# ============================================================
# hyperparams_test runing iteration = 4/18
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 1.45e-01
# Hyperparams_test: L2_normalize_gama0 = 4.51e-01
# Hyperparams_test: L2_normalize_beta0 = 1.36e-01
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.39e-01
# Hyperparams_test: L2_normalize_beta1 = 7.29e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.37e-01
# Hyperparams_test: L2_normalize_beta2 = 3.41e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.12%
# Valid_train percent is : 94.12%
# ============================================================
# hyperparams_test runing iteration = 5/18
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 1.45e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 1.43e-01
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.46e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.30e-01
# Hyperparams_test: L2_normalize_beta2 = 3.26e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.57%
# Valid_train percent is : 94.60%
# ============================================================
# hyperparams_test runing iteration = 6/18
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 1.45e-01
# Hyperparams_test: L2_normalize_gama0 = 4.54e-01
# Hyperparams_test: L2_normalize_beta0 = 1.47e-01
# Hyperparams_test: L2_normalize_k1 = 5.06e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.53e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.27e-01
# Hyperparams_test: L2_normalize_beta2 = 3.17e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.90%
# Valid_train percent is : 94.90%
# ============================================================
# hyperparams_test runing iteration = 7/18
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.55e-01
# Hyperparams_test: L2_normalize_beta0 = 1.49e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.57e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.25e-01
# Hyperparams_test: L2_normalize_beta2 = 3.10e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.06%
# Valid_train percent is : 95.03%
# ============================================================
# hyperparams_test runing iteration = 8/18
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.55e-01
# Hyperparams_test: L2_normalize_beta0 = 1.51e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.60e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.24e-01
# Hyperparams_test: L2_normalize_beta2 = 3.06e-02
# Hyperparams_test: L2_normalize_w3 = 1.22e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.17%
# Valid_train percent is : 95.13%
# ============================================================
# hyperparams_test runing iteration = 9/18
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.56e-01
# Hyperparams_test: L2_normalize_beta0 = 1.52e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.62e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.23e-01
# Hyperparams_test: L2_normalize_beta2 = 3.03e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.22%
# Valid_train percent is : 95.21%
# ============================================================
# hyperparams_test runing iteration = 10/18
# hyperparams_test runing: lri = 5.974e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.56e-01
# Hyperparams_test: L2_normalize_beta0 = 1.52e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.64e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.23e-01
# Hyperparams_test: L2_normalize_beta2 = 3.01e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.25%
# Valid_train percent is : 95.24%
# ============================================================
# hyperparams_test runing iteration = 11/18
# hyperparams_test runing: lri = 4.044e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.53e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.65e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.23e-01
# Hyperparams_test: L2_normalize_beta2 = 2.99e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.29%
# Valid_train percent is : 95.26%
# ============================================================
# hyperparams_test runing iteration = 12/18
# hyperparams_test runing: lri = 2.738e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.53e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.66e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.98e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.30%
# Valid_train percent is : 95.28%
# ============================================================
# hyperparams_test runing iteration = 13/18
# hyperparams_test runing: lri = 1.854e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.53e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.66e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.98e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.31%
# Valid_train percent is : 95.29%
# ============================================================
# hyperparams_test runing iteration = 14/18
# hyperparams_test runing: lri = 1.255e-05
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.53e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.66e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.97e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.32%
# Valid_train percent is : 95.30%
# ============================================================
# hyperparams_test runing iteration = 15/18
# hyperparams_test runing: lri = 8.496e-06
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.54e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.67e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.97e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.32%
# Valid_train percent is : 95.31%
# ============================================================
# hyperparams_test runing iteration = 16/18
# hyperparams_test runing: lri = 5.751e-06
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.54e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.67e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.97e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.32%
# Valid_train percent is : 95.31%
# ============================================================
# hyperparams_test runing iteration = 17/18
# hyperparams_test runing: lri = 3.894e-06
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.54e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.67e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.97e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.32%
# Valid_train percent is : 95.31%
# ============================================================
# hyperparams_test runing iteration = 18/18
# hyperparams_test runing: lri = 2.636e-06
# Hyperparams_test: L2_normalize_k0 = 1.46e-01
# Hyperparams_test: L2_normalize_gama0 = 4.57e-01
# Hyperparams_test: L2_normalize_beta0 = 1.54e-01
# Hyperparams_test: L2_normalize_k1 = 5.07e-02
# Hyperparams_test: L2_normalize_gama1 = 3.40e-01
# Hyperparams_test: L2_normalize_beta1 = 7.67e-02
# Hyperparams_test: L2_normalize_k2 = 3.12e-02
# Hyperparams_test: L2_normalize_gama2 = 1.22e-01
# Hyperparams_test: L2_normalize_beta2 = 2.97e-02
# Hyperparams_test: L2_normalize_w3 = 1.23e-02
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.32%
# No handles with labels found to put in legend.
# Valid_train percent is : 95.31%
# k0.shape= (5, 1, 3, 3)
# gama0.shape= (5, 1, 1)
# beta0.shape= (5, 1, 1)
# k1.shape= (9, 5, 3, 3)
# gama1.shape= (9, 1, 1)
# beta1.shape= (9, 1, 1)
# k2.shape= (13, 9, 3, 3)
# gama2.shape= (13, 1, 1)
# beta2.shape= (13, 1, 1)
# w3.shape= (10, 13, 7, 7)
# Real lab number is :	0
# Precdict number is :	0

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=8,imchin=1,dimch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
with open('cnn_p6.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p6.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [2, 4, 6, 8, 10, 10]
# init_params: ch= [1, 5, 9, 13, 17, 21, 25, 29, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 8
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (5, 1, 3, 3)
# params gama0.shape= (5, 1, 1)
# params beta0.shape= (5, 1, 1)
# params k1.shape= (9, 5, 3, 3)
# params gama1.shape= (9, 1, 1)
# params beta1.shape= (9, 1, 1)
# params k2.shape= (13, 9, 3, 3)
# params gama2.shape= (13, 1, 1)
# params beta2.shape= (13, 1, 1)
# params k3.shape= (17, 13, 3, 3)
# params gama3.shape= (17, 1, 1)
# params beta3.shape= (17, 1, 1)
# params k4.shape= (21, 17, 3, 3)
# params gama4.shape= (21, 1, 1)
# params beta4.shape= (21, 1, 1)
# params k5.shape= (25, 21, 3, 3)
# params gama5.shape= (25, 1, 1)
# params beta5.shape= (25, 1, 1)
# params k6.shape= (29, 25, 3, 3)
# params gama6.shape= (29, 1, 1)
# params beta6.shape= (29, 1, 1)
# params w7.shape= (10, 29, 7, 7)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: relu
# active function g[3] is: relu
# active function g[4] is: relu
# active function g[5] is: relu
# active function g[6] is: relu
# active function g[7] is: softmax
# active function g[8] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/18
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 1.50e-01
# Hyperparams_test: L2_normalize_gama0 = 4.47e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.33e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 2.96e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.43e-01
# Hyperparams_test: L2_normalize_beta3 = 0.00e+00
# Hyperparams_test: L2_normalize_k4 = 1.78e-02
# Hyperparams_test: L2_normalize_gama4 = 2.18e-01
# Hyperparams_test: L2_normalize_beta4 = 0.00e+00
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 2.00e-01
# Hyperparams_test: L2_normalize_beta5 = 0.00e+00
# Hyperparams_test: L2_normalize_k6 = 1.23e-02
# Hyperparams_test: L2_normalize_gama6 = 1.86e-01
# Hyperparams_test: L2_normalize_beta6 = 0.00e+00
# Hyperparams_test: L2_normalize_w7 = 8.42e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 87.72%
# Valid_train percent is : 87.01%
# ============================================================
# hyperparams_test runing iteration = 2/18
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 1.50e-01
# Hyperparams_test: L2_normalize_gama0 = 4.45e-01
# Hyperparams_test: L2_normalize_beta0 = 4.65e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.33e-01
# Hyperparams_test: L2_normalize_beta1 = 4.72e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 3.02e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.42e-01
# Hyperparams_test: L2_normalize_beta3 = 2.00e-02
# Hyperparams_test: L2_normalize_k4 = 1.78e-02
# Hyperparams_test: L2_normalize_gama4 = 2.18e-01
# Hyperparams_test: L2_normalize_beta4 = 2.33e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.99e-01
# Hyperparams_test: L2_normalize_beta5 = 2.37e-02
# Hyperparams_test: L2_normalize_k6 = 1.23e-02
# Hyperparams_test: L2_normalize_gama6 = 1.39e-01
# Hyperparams_test: L2_normalize_beta6 = 2.29e-02
# Hyperparams_test: L2_normalize_w7 = 8.33e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 92.92%
# Valid_train percent is : 92.81%
# ============================================================
# hyperparams_test runing iteration = 3/18
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 1.52e-01
# Hyperparams_test: L2_normalize_gama0 = 4.45e-01
# Hyperparams_test: L2_normalize_beta0 = 7.27e-02
# Hyperparams_test: L2_normalize_k1 = 5.27e-02
# Hyperparams_test: L2_normalize_gama1 = 3.30e-01
# Hyperparams_test: L2_normalize_beta1 = 7.12e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 4.34e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.41e-01
# Hyperparams_test: L2_normalize_beta3 = 2.64e-02
# Hyperparams_test: L2_normalize_k4 = 1.78e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 2.99e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 2.89e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.26e-01
# Hyperparams_test: L2_normalize_beta6 = 2.62e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 94.20%
# Valid_train percent is : 94.68%
# ============================================================
# hyperparams_test runing iteration = 4/18
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 1.52e-01
# Hyperparams_test: L2_normalize_gama0 = 4.46e-01
# Hyperparams_test: L2_normalize_beta0 = 7.96e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.29e-01
# Hyperparams_test: L2_normalize_beta1 = 8.08e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.77e-01
# Hyperparams_test: L2_normalize_beta2 = 4.98e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 2.93e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.26e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.06e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.21e-01
# Hyperparams_test: L2_normalize_beta6 = 2.72e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.09%
# Valid_train percent is : 95.73%
# ============================================================
# hyperparams_test runing iteration = 5/18
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 1.53e-01
# Hyperparams_test: L2_normalize_gama0 = 4.48e-01
# Hyperparams_test: L2_normalize_beta0 = 8.36e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.28e-01
# Hyperparams_test: L2_normalize_beta1 = 8.54e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.23e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.04e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.40e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.12e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.19e-01
# Hyperparams_test: L2_normalize_beta6 = 2.76e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.57%
# Valid_train percent is : 96.35%
# ============================================================
# hyperparams_test runing iteration = 6/18
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 1.53e-01
# Hyperparams_test: L2_normalize_gama0 = 4.49e-01
# Hyperparams_test: L2_normalize_beta0 = 8.59e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.28e-01
# Hyperparams_test: L2_normalize_beta1 = 8.81e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.39e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.08e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.47e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.15e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.18e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 95.89%
# Valid_train percent is : 96.75%
# ============================================================
# hyperparams_test runing iteration = 7/18
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 1.53e-01
# Hyperparams_test: L2_normalize_gama0 = 4.50e-01
# Hyperparams_test: L2_normalize_beta0 = 8.72e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.28e-01
# Hyperparams_test: L2_normalize_beta1 = 8.96e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.50e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.11e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.51e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.12%
# Valid_train percent is : 96.96%
# ============================================================
# hyperparams_test runing iteration = 8/18
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 1.53e-01
# Hyperparams_test: L2_normalize_gama0 = 4.51e-01
# Hyperparams_test: L2_normalize_beta0 = 8.79e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.28e-01
# Hyperparams_test: L2_normalize_beta1 = 9.06e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.56e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.12e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.54e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.26%
# Valid_train percent is : 97.13%
# ============================================================
# hyperparams_test runing iteration = 9/18
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.83e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.13e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.59e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.13e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.55e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.32%
# Valid_train percent is : 97.19%
# ============================================================
# hyperparams_test runing iteration = 10/18
# hyperparams_test runing: lri = 5.974e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.86e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.17e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.62e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.14e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.56e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.29e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.39%
# Valid_train percent is : 97.24%
# ============================================================
# hyperparams_test runing iteration = 11/18
# hyperparams_test runing: lri = 4.044e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.89e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.20e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.63e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.14e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.57e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.41%
# Valid_train percent is : 97.27%
# ============================================================
# hyperparams_test runing iteration = 12/18
# hyperparams_test runing: lri = 2.738e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.90e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.21e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.64e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.14e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.57e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.17e-01
# Hyperparams_test: L2_normalize_beta6 = 2.78e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.42%
# Valid_train percent is : 97.33%
# ============================================================
# hyperparams_test runing iteration = 13/18
# hyperparams_test runing: lri = 1.854e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.91e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.23e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.64e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.14e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.58e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.16e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.44%
# Valid_train percent is : 97.36%
# ============================================================
# hyperparams_test runing iteration = 14/18
# hyperparams_test runing: lri = 1.255e-05
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.91e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.24e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.65e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.15e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.58e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.16e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.45%
# Valid_train percent is : 97.39%
# ============================================================
# hyperparams_test runing iteration = 15/18
# hyperparams_test runing: lri = 8.496e-06
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.92e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.24e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.65e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.15e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.58e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.16e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.50%
# Valid_train percent is : 97.40%
# ============================================================
# hyperparams_test runing iteration = 16/18
# hyperparams_test runing: lri = 5.751e-06
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.92e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.24e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.65e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.15e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.58e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.16e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 96.53%
# Valid_train percent is : 97.42%
# ============================================================
# hyperparams_test runing iteration = 17/18
# hyperparams_test runing: lri = 3.894e-06
# Hyperparams_test: L2_normalize_k0 = 1.54e-01
# Hyperparams_test: L2_normalize_gama0 = 4.52e-01
# Hyperparams_test: L2_normalize_beta0 = 8.92e-02
# Hyperparams_test: L2_normalize_k1 = 5.28e-02
# Hyperparams_test: L2_normalize_gama1 = 3.27e-01
# Hyperparams_test: L2_normalize_beta1 = 9.25e-02
# Hyperparams_test: L2_normalize_k2 = 2.97e-02
# Hyperparams_test: L2_normalize_gama2 = 2.76e-01
# Hyperparams_test: L2_normalize_beta2 = 5.65e-02
# Hyperparams_test: L2_normalize_k3 = 2.20e-02
# Hyperparams_test: L2_normalize_gama3 = 2.40e-01
# Hyperparams_test: L2_normalize_beta3 = 3.15e-02
# Hyperparams_test: L2_normalize_k4 = 1.79e-02
# Hyperparams_test: L2_normalize_gama4 = 2.17e-01
# Hyperparams_test: L2_normalize_beta4 = 3.58e-02
# Hyperparams_test: L2_normalize_k5 = 1.43e-02
# Hyperparams_test: L2_normalize_gama5 = 1.98e-01
# Hyperparams_test: L2_normalize_beta5 = 3.17e-02
# Hyperparams_test: L2_normalize_k6 = 1.24e-02
# Hyperparams_test: L2_normalize_gama6 = 1.16e-01
# Hyperparams_test: L2_normalize_beta6 = 2.77e-02
# Hyperparams_test: L2_normalize_w7 = 8.30e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6eb0cb4f5c5a> in <module>
#       5 imp.reload(cnn)
#       6 (params,params_init,g,g_d)=cnn.init_params(lays=8,imchin=1,dimch=4)
# ----> 7 params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=18,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
#       8 with open('cnn_p6.pkl', 'wb') as f: pickle.dump(params,f)
#       9 with open('cnn_p6.pkl', 'rb') as f: params2=pickle.load(f)
#
# ~/proj_py/cnn.py in hyperparams_test(params, params_init, g, g_d, nloop, lr0, klr, batch, batches, isupdate, isl2grad)
#     535                         L2=np.linalg.norm(v)/v.size
#     536                         print('Hyperparams_test: L2_normalize_%s = %.2e'%(k,L2))
# --> 537                 (lrendi,v1,v2)=train_and_valid(params,g,g_d,lri,klr,batch,batches,isplot=1,isl2grad=isl2grad)
#     538                 v1a.append(v1)
#     539                 v2a.append(v2)
#
# ~/proj_py/cnn.py in train_and_valid(params, g, g_d, lr0, klr, batch, batches, isplot, istime, ischeck, isl2grad)
#     499
#     500 def train_and_valid(params,g,g_d,lr0=2e-3,klr=0.9995,batch=20,batches=0,isplot=0,istime=0,ischeck=0,isl2grad=0):
# --> 501         (params,lrend)=batch_train(params,g,g_d,lr0,klr,batch,batches,isplot,istime,isl2grad=isl2grad)
#     502         (valid_per,correct)=valid(params,g)
#     503         (valid_per2,correct2)=valid_train(params,g)
#
# ~/proj_py/cnn.py in batch_train(params, g, g_d, lr0, klr, batch, batches, isplot, istime, isl2grad)
#     361 #               Xi=np.expand_dims(X[i],-1)
#     362 #               LABi=np.expand_dims(LAB[i],-1)
# --> 363                 grad=bp(X[i],LAB[i],params,g,g_d)
#     364                 lr=lr0*klr**i
#     365                 lra.append(lr)
#
# ~/proj_py/cnn.py in bp(X, LAB, params, g, g_d, e, isop)
#     210                         d_Ai_1=np.einsum('bmhwij,mcij->bchw',d_Zi_2col,ki_fl)
#     211                         d_Zi=np.pad(d_Zi,((0,0),(0,0),(0,Ci_1.shape[2]-d_Zi.shape[2]),(0,Ci_1.shape[3]-d_Zi.shape[3])))
# --> 212                         d_ki=np.einsum('bchwij,bmhw->bmcij',Ci_1,d_Zi)
#     213                         grad['d_k'+str(i)]=d_ki.mean(0)
#     214                         if isop!=0:
#
# ~/.local/lib/python3.8/site-packages/numpy/core/overrides.py in einsum(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/einsumfunc.py in einsum(out, optimize, *operands, **kwargs)
#    1357         if specified_out:
#    1358             kwargs['out'] = out
# -> 1359         return c_einsum(*operands, **kwargs)
#    1360
#    1361     # Check the kwargs to avoid a more cryptic error later, without having to
#
# KeyboardInterrupt:
