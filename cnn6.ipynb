# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=16,imchin=12,dimch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,batch=64)
with open('cnn_p6.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p6.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 16
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 0
# params k0.shape= (12, 1, 3, 3)
# params gama0.shape= (12, 1, 1)
# params beta0.shape= (12, 1, 1)
# params k1.shape= (16, 12, 3, 3)
# params gama1.shape= (16, 1, 1)
# params beta1.shape= (16, 1, 1)
# params k2.shape= (20, 16, 3, 3)
# params gama2.shape= (20, 1, 1)
# params beta2.shape= (20, 1, 1)
# params k3.shape= (24, 20, 3, 3)
# params gama3.shape= (24, 1, 1)
# params beta3.shape= (24, 1, 1)
# params k4.shape= (28, 24, 3, 3)
# params gama4.shape= (28, 1, 1)
# params beta4.shape= (28, 1, 1)
# params k5.shape= (32, 28, 3, 3)
# params gama5.shape= (32, 1, 1)
# params beta5.shape= (32, 1, 1)
# params k6.shape= (36, 32, 3, 3)
# ...

# %%
import cnn
import numpy as np
import pickle
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=16,imchin=12,dimch=4)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,batch=64)
with open('cnn_p6.pkl', 'wb') as f: pickle.dump(params,f)
with open('cnn_p6.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
cnn.show(params,g)
# Out:
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 8, 10, 12, 14, 10]
# init_params: ch= [1, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 16
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 0
# params k0.shape= (8, 1, 3, 3)
# params gama0.shape= (8, 1, 1)
# params beta0.shape= (8, 1, 1)
# params k1.shape= (16, 8, 3, 3)
# params gama1.shape= (16, 1, 1)
# params beta1.shape= (16, 1, 1)
# params k2.shape= (24, 16, 3, 3)
# params gama2.shape= (24, 1, 1)
# params beta2.shape= (24, 1, 1)
# params k3.shape= (32, 24, 3, 3)
# params gama3.shape= (32, 1, 1)
# params beta3.shape= (32, 1, 1)
# params k4.shape= (40, 32, 3, 3)
# params gama4.shape= (40, 1, 1)
# params beta4.shape= (40, 1, 1)
# params k5.shape= (48, 40, 3, 3)
# params gama5.shape= (48, 1, 1)
# params beta5.shape= (48, 1, 1)
# ...
