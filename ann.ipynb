# %%
import ann
import numpy as np
import imp
imp.reload(ann)
# Out:
# Training running ...
# params b0.shape= (784, 1)
# params b1.shape= (10, 1)
# params w1.shape= (10, 784)
# active function g[0] is: tanh
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: log_loss
# Batch training running ...
# iteration number = 0/500
# the spending time of 0/500 batch is 9.110689163208008 mS
# iteration number = 50/500
# the spending time of 50/500 batch is 14.671564102172852 mS
# iteration number = 100/500
# the spending time of 100/500 batch is 16.263723373413086 mS
# iteration number = 150/500
# the spending time of 150/500 batch is 15.878677368164062 mS
# iteration number = 200/500
# the spending time of 200/500 batch is 13.959407806396484 mS
# iteration number = 250/500
# the spending time of 250/500 batch is 16.75271987915039 mS
# iteration number = 300/500
# the spending time of 300/500 batch is 15.993356704711914 mS
# iteration number = 350/500
# the spending time of 350/500 batch is 15.931844711303711 mS
# ...

# %%
ann.show()
# Out:
# Real lab number is :	2
# Precdict number is :	2
