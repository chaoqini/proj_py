# %%
import ann
import numpy as np
import imp
imp.reload(ann)
n=np.random.randint(10000)
ann.show(n)
# Out:
# X shape: (1000, 50, 784, 1)
# LAB shape: (1000, 50, 1, 1)
# iteration number=: 0
# iteration number=: 1
# iteration number=: 2
# iteration number=: 3
# iteration number=: 4
# iteration number=: 5
# iteration number=: 6
# iteration number=: 7
# iteration number=: 8
# iteration number=: 9
# iteration number=: 10
# iteration number=: 11
# iteration number=: 12
# iteration number=: 13
# iteration number=: 14
# iteration number=: 15
# iteration number=: 16
# iteration number=: 17
# iteration number=: 18
# iteration number=: 19
# iteration number=: 20
# iteration number=: 21
# iteration number=: 22
# iteration number=: 23
# iteration number=: 24
# iteration number=: 25
# iteration number=: 26
# iteration number=: 27
# iteration number=: 28
# iteration number=: 29
# iteration number=: 30
# iteration number=: 31
# iteration number=: 32
# iteration number=: 33
# iteration number=: 34
# iteration number=: 35
# iteration number=: 36
# iteration number=: 37
# iteration number=: 38
# ...

# %%
import ann10
import numpy as np
import imp
imp.reload(ann10)
n=np.random.randint(10000)
ann10.show(n)
# Out:
# -- use derivative grade function
# valid percent is : 86.45%
# average loss is : 1.2944292199513705
# Real lab number is :	5
# Precdict number is :	5
