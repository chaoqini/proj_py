# %%
import ann
import numpy as np
import imp
imp.reload(ann)
# Out:
# iteration number=:0/500
# iteration number=:50/500
# iteration number=:100/500
# iteration number=:150/500
# iteration number=:200/500
# iteration number=:250/500
# iteration number=:300/500
# iteration number=:350/500
# iteration number=:400/500
# iteration number=:450/500
# iteration number=:499/500
# valid percent is : 89.13%
# Real lab number is :	1
# Precdict number is :	1
# <module 'ann' from '/home/qc/proj_py/ann.py'>

# %%
ann.show()
# Out:
# Real lab number is :	5
# Precdict number is :	3
