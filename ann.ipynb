# %%
import ann11
import numpy as np
import imp
imp.reload(ann11)
n=np.random.randint(10000)
ann11.show(n)
# Out:
# -- use derivative grade function
# valid percent is : 88.33%
# average loss is : 0.8393165563071938
# d_b1 derivative:
# [[ 0.01595423  0.19022385  0.12058804  0.01959249  0.06161035 -0.63847234
#    0.03007781  0.01454665  0.17661725  0.00926166]]
# d_b1 slope:
# [[ 0.01449691  0.43544132  0.14423794  0.01793395  0.0619208  -1.01109448
#    0.02813702  0.0131808   0.28744072  0.00830503]]
# Real lab number is :	4
# Precdict number is :	4

# %%
import ann10
import numpy as np
import imp
imp.reload(ann10)
n=np.random.randint(10000)
ann10.show(n)
# Out:
# -- use derivative grade function
# valid percent is : 86.45%
# average loss is : 1.2944292199513705
# Real lab number is :	5
# Precdict number is :	5
