# %%
import ann
import numpy as np
import pickle
import imp
imp.reload(ann)

(lays,imba,imchin,dimch,imh,imw,convk,km,minhw)=(4,2,2,1,28,28,3,2,28)
# (params,params_init,g)=ann.init_params(lays=3,imchin=2,dimch=1)
# def init_params(lays=lays,k=convk,imchin=imchin,dimch=dimch,imh=imh,imw=imw,ch=-1,func=None):
(params,params_init,g)=ann.init_params(lays=lays,k=convk,imchin=imchin,dimch=dimch,imh=imh,imw=imw)
# (lays,imba,imchin,dimch,imh,imw,convk,km,minhw)=(4,2,2,1,28,28,3,2,28)

ch=2
nn=2
lab=ann.mnist.train_lab[nn:nn+imba]
# x=mnist.train_img[0:imba]
# x=np.expand_dims(x,1)
x=np.random.randn(imba,1,imh,imw)*100
i=1 
ann.grad_check(x,lab,params,g)

# ann.grad_check2(x,lab,params,g,pname='Y'+str(i),dv=1e-3)
# ann.grad_check2(x,lab,params,g,pname='A'+str(i),dv=1e-3)
# ann.grad_check2(x,lab,params,g,pname='M'+str(i),dv=1e-5)
# ann.grad_check2(x,lab,params,g,pname='Z'+str(i),dv=1e-5)
# ann.grad_check2(x,lab,params,g,pname='ZdM'+str(i),dv=1e-5)
# yfp,op=fp(x,params,g,isop=1)
# ybp,d_=bp(x,lab,params,g,isop=1)
# print('"d_[ZdM%s]=\n'%i,d_['ZdM'+str(i)].squeeze())
# print('op[ZdM%s]=\n'%i,op['ZdM'+str(i)].squeeze())
# print('op[Z%s]=\n'%i,op['Z'+str(i)].squeeze())
print('check done')
# Out:
# init_params: ch= [1, 2, 3, 4, 10]
# init_params: ch= [1, 2, 3, 4, 10]
# slope: running k0.shape= (2, 1, 3, 3)
# slope: k0[1/18] slope = -2.911136589389684
# slope: k0[2/18] slope = -6.70670261584405
# slope: k0[3/18] slope = 7.388769890326329
# slope: k0[4/18] slope = -1.8376483573945277
# slope: k0[6/18] slope = -4.307124999769485
# slope: k0[9/18] slope = 5.9954412584772845
# slope: k0[12/18] slope = 10.624041867757228
# slope: running gama0.shape= (2, 1, 1)
# slope: gama0[1/2] slope = -11.949281678269584
# slope: gama0[2/2] slope = 11.949281675072141
# slope: running beta0.shape= (2, 1, 1)
# slope: beta0[1/2] slope = -9.33682035686445
# slope: beta0[2/2] slope = 4.910950951142468
# slope: running k1.shape= (3, 2, 3, 3)
# slope: k1[1/54] slope = -2.197244015178512
# slope: k1[2/54] slope = -2.901460458915039
# slope: k1[3/54] slope = -2.5076783224164956
# slope: k1[4/54] slope = -2.7157479177475348
# slope: k1[6/54] slope = 2.4008818641618745
# slope: k1[9/54] slope = 0.35676632492709354
# slope: k1[12/54] slope = 1.2254660358479441
# slope: running gama1.shape= (3, 1, 1)
# slope: gama1[1/3] slope = -2.8392896915363504
# slope: gama1[2/3] slope = 2.571424131048161
# slope: gama1[3/3] slope = 0.267865636160991
# slope: running beta1.shape= (3, 1, 1)
# slope: beta1[1/3] slope = -5.279603843177938
# slope: beta1[2/3] slope = 16.79597408710265
# slope: beta1[3/3] slope = 7.459242100438245
# slope: running k2.shape= (4, 3, 3, 3)
# slope: k2[1/108] slope = 2.643019032433358
# slope: k2[2/108] slope = -1.0951425956307048
# slope: k2[3/108] slope = 4.541853592243683
# slope: k2[4/108] slope = -2.513623321220848
# slope: k2[6/108] slope = 6.8224811990091885
# slope: k2[9/108] slope = -0.06009240323123776
# slope: k2[12/108] slope = 10.582396409475336
# slope: k2 running loop=100/108
# slope: running gama2.shape= (4, 1, 1)
# slope: gama2[1/4] slope = 3.12814981313636
# slope: gama2[2/4] slope = 25.10539580065085
# slope: gama2[3/4] slope = 11.849544286945955
# slope: gama2[4/4] slope = 20.040490428385738
# slope: running beta2.shape= (4, 1, 1)
# slope: beta2[1/4] slope = -20.289538318252198
# slope: beta2[2/4] slope = 21.14679384135343
# slope: beta2[3/4] slope = 13.704756837285002
# slope: beta2[4/4] slope = 13.973096046981935
# slope: running w3.shape= (10, 4, 28, 28)
# slope: w3[1/31360] slope = 0.0
# slope: w3[2/31360] slope = 0.0
# slope: w3[3/31360] slope = 0.0
# slope: w3[4/31360] slope = 0.0
# slope: w3[6/31360] slope = 0.0
# slope: w3[9/31360] slope = 0.0
# slope: w3[12/31360] slope = 0.0
# slope: w3 running loop=100/31360
# slope: w3 running loop=200/31360
# slope: w3 running loop=300/31360
# slope: w3 running loop=400/31360
# slope: w3 running loop=500/31360
# slope: w3 running loop=600/31360
# slope: w3 running loop=700/31360
# slope: w3 running loop=800/31360
# slope: w3 running loop=900/31360
# slope: w3 running loop=1000/31360
# slope: w3 running loop=1100/31360
# slope: w3 running loop=1200/31360
# slope: w3 running loop=1300/31360
# slope: w3 running loop=1400/31360
# slope: w3 running loop=1500/31360
# slope: w3 running loop=1600/31360
# slope: w3 running loop=1700/31360
# slope: w3 running loop=1800/31360
# slope: w3 running loop=1900/31360
# slope: w3 running loop=2000/31360
# slope: w3 running loop=2100/31360
# slope: w3 running loop=2200/31360
# slope: w3 running loop=2300/31360
# slope: w3 running loop=2400/31360
# slope: w3 running loop=2500/31360
# slope: w3 running loop=2600/31360
# slope: w3 running loop=2700/31360
# slope: w3 running loop=2800/31360
# slope: w3 running loop=2900/31360
# slope: w3 running loop=3000/31360
# slope: w3 running loop=3100/31360
# slope: w3 running loop=3200/31360
# slope: w3 running loop=3300/31360
# slope: w3 running loop=3400/31360
# slope: w3 running loop=3500/31360
# slope: w3 running loop=3600/31360
# slope: w3 running loop=3700/31360
# slope: w3 running loop=3800/31360
# slope: w3 running loop=3900/31360
# slope: w3 running loop=4000/31360
# slope: w3 running loop=4100/31360
# slope: w3 running loop=4200/31360
# slope: w3 running loop=4300/31360
# slope: w3 running loop=4400/31360
# slope: w3 running loop=4500/31360
# slope: w3 running loop=4600/31360
# slope: w3 running loop=4700/31360
# slope: w3 running loop=4800/31360
# slope: w3 running loop=4900/31360
# slope: w3 running loop=5000/31360
# slope: w3 running loop=5100/31360
# slope: w3 running loop=5200/31360
# slope: w3 running loop=5300/31360
# slope: w3 running loop=5400/31360
# slope: w3 running loop=5500/31360
# slope: w3 running loop=5600/31360
# slope: w3 running loop=5700/31360
# slope: w3 running loop=5800/31360
# slope: w3 running loop=5900/31360
# slope: w3 running loop=6000/31360
# slope: w3 running loop=6100/31360
# slope: w3 running loop=6200/31360
# slope: w3 running loop=6300/31360
# slope: w3 running loop=6400/31360
# slope: w3 running loop=6500/31360
# slope: w3 running loop=6600/31360
# slope: w3 running loop=6700/31360
# slope: w3 running loop=6800/31360
# slope: w3 running loop=6900/31360
# slope: w3 running loop=7000/31360
# slope: w3 running loop=7100/31360
# slope: w3 running loop=7200/31360
# slope: w3 running loop=7300/31360
# slope: w3 running loop=7400/31360
# slope: w3 running loop=7500/31360
# slope: w3 running loop=7600/31360
# slope: w3 running loop=7700/31360
# slope: w3 running loop=7800/31360
# slope: w3 running loop=7900/31360
# slope: w3 running loop=8000/31360
# slope: w3 running loop=8100/31360
# slope: w3 running loop=8200/31360
# slope: w3 running loop=8300/31360
# slope: w3 running loop=8400/31360
# slope: w3 running loop=8500/31360
# slope: w3 running loop=8600/31360
# slope: w3 running loop=8700/31360
# slope: w3 running loop=8800/31360
# slope: w3 running loop=8900/31360
# slope: w3 running loop=9000/31360
# slope: w3 running loop=9100/31360
# slope: w3 running loop=9200/31360
# slope: w3 running loop=9300/31360
# slope: w3 running loop=9400/31360
# slope: w3 running loop=9500/31360
# slope: w3 running loop=9600/31360
# slope: w3 running loop=9700/31360
# slope: w3 running loop=9800/31360
# slope: w3 running loop=9900/31360
# slope: w3 running loop=10000/31360
# slope: w3 running loop=10100/31360
# slope: w3 running loop=10200/31360
# slope: w3 running loop=10300/31360
# slope: w3 running loop=10400/31360
# slope: w3 running loop=10500/31360
# slope: w3 running loop=10600/31360
# slope: w3 running loop=10700/31360
# slope: w3 running loop=10800/31360
# slope: w3 running loop=10900/31360
# slope: w3 running loop=11000/31360
# slope: w3 running loop=11100/31360
# slope: w3 running loop=11200/31360
# slope: w3 running loop=11300/31360
# slope: w3 running loop=11400/31360
# slope: w3 running loop=11500/31360
# slope: w3 running loop=11600/31360
# slope: w3 running loop=11700/31360
# slope: w3 running loop=11800/31360
# slope: w3 running loop=11900/31360
# slope: w3 running loop=12000/31360
# slope: w3 running loop=12100/31360
# slope: w3 running loop=12200/31360
# slope: w3 running loop=12300/31360
# slope: w3 running loop=12400/31360
# slope: w3 running loop=12500/31360
# slope: w3 running loop=12600/31360
# slope: w3 running loop=12700/31360
# slope: w3 running loop=12800/31360
# slope: w3 running loop=12900/31360
# slope: w3 running loop=13000/31360
# slope: w3 running loop=13100/31360
# slope: w3 running loop=13200/31360
# slope: w3 running loop=13300/31360
# slope: w3 running loop=13400/31360
# slope: w3 running loop=13500/31360
# slope: w3 running loop=13600/31360
# slope: w3 running loop=13700/31360
# slope: w3 running loop=13800/31360
# slope: w3 running loop=13900/31360
# slope: w3 running loop=14000/31360
# slope: w3 running loop=14100/31360
# slope: w3 running loop=14200/31360
# slope: w3 running loop=14300/31360
# slope: w3 running loop=14400/31360
# slope: w3 running loop=14500/31360
# slope: w3 running loop=14600/31360
# slope: w3 running loop=14700/31360
# slope: w3 running loop=14800/31360
# slope: w3 running loop=14900/31360
# slope: w3 running loop=15000/31360
# slope: w3 running loop=15100/31360
# slope: w3 running loop=15200/31360
# slope: w3 running loop=15300/31360
# slope: w3 running loop=15400/31360
# slope: w3 running loop=15500/31360
# slope: w3 running loop=15600/31360
# slope: w3 running loop=15700/31360
# slope: w3 running loop=15800/31360
# slope: w3 running loop=15900/31360
# slope: w3 running loop=16000/31360
# slope: w3 running loop=16100/31360
# slope: w3 running loop=16200/31360
# slope: w3 running loop=16300/31360
# slope: w3 running loop=16400/31360
# slope: w3 running loop=16500/31360
# slope: w3 running loop=16600/31360
# slope: w3 running loop=16700/31360
# slope: w3 running loop=16800/31360
# slope: w3 running loop=16900/31360
# slope: w3 running loop=17000/31360
# slope: w3 running loop=17100/31360
# slope: w3 running loop=17200/31360
# slope: w3 running loop=17300/31360
# slope: w3 running loop=17400/31360
# slope: w3 running loop=17500/31360
# slope: w3 running loop=17600/31360
# slope: w3 running loop=17700/31360
# slope: w3 running loop=17800/31360
# slope: w3 running loop=17900/31360
# slope: w3 running loop=18000/31360
# slope: w3 running loop=18100/31360
# slope: w3 running loop=18200/31360
# slope: w3 running loop=18300/31360
# slope: w3 running loop=18400/31360
# slope: w3 running loop=18500/31360
# slope: w3 running loop=18600/31360
# slope: w3 running loop=18700/31360
# slope: w3 running loop=18800/31360
# slope: w3 running loop=18900/31360
# slope: w3 running loop=19000/31360
# slope: w3 running loop=19100/31360
# slope: w3 running loop=19200/31360
# slope: w3 running loop=19300/31360
# slope: w3 running loop=19400/31360
# slope: w3 running loop=19500/31360
# slope: w3 running loop=19600/31360
# slope: w3 running loop=19700/31360
# slope: w3 running loop=19800/31360
# slope: w3 running loop=19900/31360
# slope: w3 running loop=20000/31360
# slope: w3 running loop=20100/31360
# slope: w3 running loop=20200/31360
# slope: w3 running loop=20300/31360
# slope: w3 running loop=20400/31360
# slope: w3 running loop=20500/31360
# slope: w3 running loop=20600/31360
# slope: w3 running loop=20700/31360
# slope: w3 running loop=20800/31360
# slope: w3 running loop=20900/31360
# slope: w3 running loop=21000/31360
# slope: w3 running loop=21100/31360
# slope: w3 running loop=21200/31360
# slope: w3 running loop=21300/31360
# slope: w3 running loop=21400/31360
# slope: w3 running loop=21500/31360
# slope: w3 running loop=21600/31360
# slope: w3 running loop=21700/31360
# slope: w3 running loop=21800/31360
# slope: w3 running loop=21900/31360
# slope: w3 running loop=22000/31360
# slope: w3 running loop=22100/31360
# slope: w3 running loop=22200/31360
# slope: w3 running loop=22300/31360
# slope: w3 running loop=22400/31360
# slope: w3 running loop=22500/31360
# slope: w3 running loop=22600/31360
# slope: w3 running loop=22700/31360
# slope: w3 running loop=22800/31360
# slope: w3 running loop=22900/31360
# slope: w3 running loop=23000/31360
# slope: w3 running loop=23100/31360
# slope: w3 running loop=23200/31360
# slope: w3 running loop=23300/31360
# slope: w3 running loop=23400/31360
# slope: w3 running loop=23500/31360
# slope: w3 running loop=23600/31360
# slope: w3 running loop=23700/31360
# slope: w3 running loop=23800/31360
# slope: w3 running loop=23900/31360
# slope: w3 running loop=24000/31360
# slope: w3 running loop=24100/31360
# slope: w3 running loop=24200/31360
# slope: w3 running loop=24300/31360
# slope: w3 running loop=24400/31360
# slope: w3 running loop=24500/31360
# slope: w3 running loop=24600/31360
# slope: w3 running loop=24700/31360
# slope: w3 running loop=24800/31360
# slope: w3 running loop=24900/31360
# slope: w3 running loop=25000/31360
# slope: w3 running loop=25100/31360
# slope: w3 running loop=25200/31360
# slope: w3 running loop=25300/31360
# slope: w3 running loop=25400/31360
# slope: w3 running loop=25500/31360
# slope: w3 running loop=25600/31360
# slope: w3 running loop=25700/31360
# slope: w3 running loop=25800/31360
# slope: w3 running loop=25900/31360
# slope: w3 running loop=26000/31360
# slope: w3 running loop=26100/31360
# slope: w3 running loop=26200/31360
# slope: w3 running loop=26300/31360
# slope: w3 running loop=26400/31360
# slope: w3 running loop=26500/31360
# slope: w3 running loop=26600/31360
# slope: w3 running loop=26700/31360
# slope: w3 running loop=26800/31360
# slope: w3 running loop=26900/31360
# slope: w3 running loop=27000/31360
# slope: w3 running loop=27100/31360
# slope: w3 running loop=27200/31360
# slope: w3 running loop=27300/31360
# slope: w3 running loop=27400/31360
# slope: w3 running loop=27500/31360
# slope: w3 running loop=27600/31360
# slope: w3 running loop=27700/31360
# slope: w3 running loop=27800/31360
# slope: w3 running loop=27900/31360
# slope: w3 running loop=28000/31360
# slope: w3 running loop=28100/31360
# slope: w3 running loop=28200/31360
# slope: w3 running loop=28300/31360
# slope: w3 running loop=28400/31360
# slope: w3 running loop=28500/31360
# slope: w3 running loop=28600/31360
# slope: w3 running loop=28700/31360
# slope: w3 running loop=28800/31360
# slope: w3 running loop=28900/31360
# slope: w3 running loop=29000/31360
# slope: w3 running loop=29100/31360
# slope: w3 running loop=29200/31360
# slope: w3 running loop=29300/31360
# slope: w3 running loop=29400/31360
# slope: w3 running loop=29500/31360
# slope: w3 running loop=29600/31360
# slope: w3 running loop=29700/31360
# slope: w3 running loop=29800/31360
# slope: w3 running loop=29900/31360
# slope: w3 running loop=30000/31360
# slope: w3 running loop=30100/31360
# slope: w3 running loop=30200/31360
# slope: w3 running loop=30300/31360
# slope: w3 running loop=30400/31360
# slope: w3 running loop=30500/31360
# slope: w3 running loop=30600/31360
# slope: w3 running loop=30700/31360
# slope: w3 running loop=30800/31360
# slope: w3 running loop=30900/31360
# slope: w3 running loop=31000/31360
# slope: w3 running loop=31100/31360
# slope: w3 running loop=31200/31360
# slope: w3 running loop=31300/31360
# grad: d_w3.shape= (10, 4, 28, 28)
# slope: d_w3.shape= (10, 4, 28, 28)
# grad: d_gama2.shape= (4, 1, 1)
# slope: d_gama2.shape= (4, 1, 1)
# grad: d_beta2.shape= (4, 1, 1)
# slope: d_beta2.shape= (4, 1, 1)
# grad: d_k2.shape= (4, 3, 3, 3)
# slope: d_k2.shape= (4, 3, 3, 3)
# grad: d_gama1.shape= (3, 1, 1)
# slope: d_gama1.shape= (3, 1, 1)
# grad: d_beta1.shape= (3, 1, 1)
# slope: d_beta1.shape= (3, 1, 1)
# grad: d_k1.shape= (3, 2, 3, 3)
# slope: d_k1.shape= (3, 2, 3, 3)
# grad: d_gama0.shape= (2, 1, 1)
# slope: d_gama0.shape= (2, 1, 1)
# grad: d_beta0.shape= (2, 1, 1)
# slope: d_beta0.shape= (2, 1, 1)
# grad: d_k0.shape= (2, 1, 3, 3)
# slope: d_k0.shape= (2, 1, 3, 3)
# === grad_check :
# grad[d_gama2].shape= (4, 1, 1)
# slope[d_gama2].shape= (4, 1, 1)
# grad[d_gama2]=
#  [ 3.12814981 25.1053958  11.84954429 20.04049043]
# slope[d_gama2]=
#  [ 3.12814981 25.1053958  11.84954429 20.04049043]
# === grad_check :
# grad[d_beta2].shape= (4, 1, 1)
# slope[d_beta2].shape= (4, 1, 1)
# grad[d_beta2]=
#  [-20.28953832  21.14679384  13.70475684  13.97309605]
# slope[d_beta2]=
#  [-20.28953832  21.14679384  13.70475684  13.97309605]
# === grad_check :
# grad[d_k2].shape= (4, 3, 3, 3)
# slope[d_k2].shape= (4, 3, 3, 3)
# grad[d_k2]=
#  [[[[  2.64301903  -1.0951426    4.54185359]
#    [ -2.51362332   5.16448271   6.8224812 ]
#    [ -0.62068816   0.17133368  -0.0600924 ]]
#
#   [[ -1.85830548  -4.09549149  10.58239641]
#    [  6.35894599   6.24524914  -0.80266915]
#    [ -0.37749597  -6.09174881  -0.40991466]]
#
#   [[ -6.98799621   2.58925166   8.98714759]
#    [  4.38750686   7.35327629  -2.77688863]
#    [ -4.23844789  -3.31692292  11.44929524]]]
#
#
#  [[[  6.57057176  -3.00175752   3.53581007]
#    [ -0.65146871   5.81609039   4.13288351]
#    [  1.24209768   3.28445302   2.23310624]]
#
#   [[  1.23400588  -2.8440815    0.76127072]
#    [ -0.91921786   1.26056369  -4.95152775]
#    [ -1.97493869  -5.08683845   0.84167352]]
#
#   [[ -0.15555251   3.71084247   5.12183041]
#    [  6.79630696   5.20723609  -0.10600643]
#    [ -2.06188385  -0.04604409   1.45792268]]]
#
#
#  [[[ -1.95590675   3.09822897  -0.3381245 ]
#    [  3.15606725  -1.3829995    6.90516009]
#    [ -7.7102674    2.24036363  -3.39530956]]
#
#   [[ -1.40754892  -3.45686473  -0.47187251]
#    [ -0.34486344   3.37334794  -0.69756987]
#    [ -2.18070764  -2.2936857   -4.76837443]]
#
#   [[  0.81445491   0.09098424   7.00492731]
#    [ -1.82269398   2.92599931   1.58749031]
#    [  1.288263    -0.27602518  -4.16863352]]]
#
#
#  [[[  4.27194328   1.14877886  -0.7895006 ]
#    [ -2.14517851   1.11540958  10.89514298]
#    [  1.73950111   1.08391241  -1.16440603]]
#
#   [[  1.70822174  -0.90038123  -1.31104371]
#    [-10.88101353   7.1264873   -2.91765027]
#    [  7.13364873   0.9738181   -4.78413348]]
#
#   [[  1.61869953   4.28010027   5.55029802]
#    [ -5.84923308   3.14271075   2.07843031]
#    [ 10.04320862   0.07955792  -0.38533211]]]]
# slope[d_k2]=
#  [[[[  2.64301903  -1.0951426    4.54185359]
#    [ -2.51362332   5.16448271   6.8224812 ]
#    [ -0.62068816   0.17133368  -0.0600924 ]]
#
#   [[ -1.85830548  -4.09549149  10.58239641]
#    [  6.35894599   6.24524914  -0.80266915]
#    [ -0.37749597  -6.09174881  -0.40991466]]
#
#   [[ -6.98799621   2.58925166   8.98714759]
#    [  4.38750686   7.35327629  -2.77688863]
#    [ -4.23844789  -3.31692292  11.44929524]]]
#
#
#  [[[  6.57057176  -3.00175753   3.53581008]
#    [ -0.65146871   5.81609039   4.13288351]
#    [  1.24209768   3.28445301   2.23310624]]
#
#   [[  1.23400588  -2.8440815    0.76127072]
#    [ -0.91921786   1.26056369  -4.95152775]
#    [ -1.97493869  -5.08683845   0.84167353]]
#
#   [[ -0.15555251   3.71084247   5.12183041]
#    [  6.79630696   5.20723609  -0.10600643]
#    [ -2.06188385  -0.04604409   1.45792267]]]
#
#
#  [[[ -1.95590675   3.09822897  -0.3381245 ]
#    [  3.15606725  -1.3829995    6.90516009]
#    [ -7.71026739   2.24036363  -3.39530957]]
#
#   [[ -1.40754892  -3.45686473  -0.47187251]
#    [ -0.34486344   3.37334794  -0.69756987]
#    [ -2.18070764  -2.2936857   -4.76837443]]
#
#   [[  0.81445491   0.09098424   7.00492731]
#    [ -1.82269398   2.92599931   1.58749031]
#    [  1.288263    -0.27602517  -4.16863352]]]
#
#
#  [[[  4.27194328   1.14877886  -0.7895006 ]
#    [ -2.14517851   1.11540958  10.89514298]
#    [  1.73950111   1.08391241  -1.16440604]]
#
#   [[  1.70822174  -0.90038123  -1.3110437 ]
#    [-10.88101353   7.1264873   -2.91765027]
#    [  7.13364873   0.9738181   -4.78413348]]
#
#   [[  1.61869953   4.28010028   5.55029802]
#    [ -5.84923308   3.14271075   2.07843031]
#    [ 10.04320862   0.07955792  -0.38533211]]]]
# === grad_check :
# grad[d_gama1].shape= (3, 1, 1)
# slope[d_gama1].shape= (3, 1, 1)
# grad[d_gama1]=
#  [-2.83928969  2.57142413  0.26786563]
# slope[d_gama1]=
#  [-2.83928969  2.57142413  0.26786564]
# === grad_check :
# grad[d_beta1].shape= (3, 1, 1)
# slope[d_beta1].shape= (3, 1, 1)
# grad[d_beta1]=
#  [-5.27960384 16.79597408  7.4592421 ]
# slope[d_beta1]=
#  [-5.27960384 16.79597409  7.4592421 ]
# === grad_check :
# grad[d_k1].shape= (3, 2, 3, 3)
# slope[d_k1].shape= (3, 2, 3, 3)
# grad[d_k1]=
#  [[[[ -2.19724402  -2.90146046  -2.50767832]
#    [ -2.71574792   0.14064877   2.40088186]
#    [ -3.23299762  -0.38066331   0.35676632]]
#
#   [[  0.20185264  -5.12710044   1.22546603]
#    [  0.13028876   3.9693421   -2.41564133]
#    [ -3.39051744   1.69319467  -7.37522233]]]
#
#
#  [[[ -0.84489966   5.21373107   2.1366335 ]
#    [ -2.29701489   1.02280389   3.40413669]
#    [  0.60611464   6.81726097   0.81335984]]
#
#   [[ -1.46003849   1.29337257  -3.58139908]
#    [ -3.87690084  -0.96264377   4.33823134]
#    [  4.63184428   4.81827842  -0.05010136]]]
#
#
#  [[[-12.21141164   5.17727782  -7.33810379]
#    [  4.18404077   8.87958835  -0.11914958]
#    [  5.36086214 -13.16331502  -8.48524602]]
#
#   [[ -1.14839556   3.46577135  -2.12152304]
#    [ -1.84943882  12.71866061  -8.05512695]
#    [ 11.97525897  -2.88160153  -1.46701002]]]]
# slope[d_k1]=
#  [[[[ -2.19724402  -2.90146046  -2.50767832]
#    [ -2.71574792   0.14064877   2.40088186]
#    [ -3.23299762  -0.38066331   0.35676632]]
#
#   [[  0.20185265  -5.12710044   1.22546604]
#    [  0.13028876   3.9693421   -2.41564134]
#    [ -3.39051744   1.69319467  -7.37522233]]]
#
#
#  [[[ -0.84489966   5.21373107   2.1366335 ]
#    [ -2.2970149    1.02280389   3.40413669]
#    [  0.60611464   6.81726098   0.81335984]]
#
#   [[ -1.46003849   1.29337257  -3.58139908]
#    [ -3.87690084  -0.96264377   4.33823134]
#    [  4.63184429   4.81827842  -0.05010136]]]
#
#
#  [[[-12.21141165   5.17727782  -7.33810379]
#    [  4.18404077   8.87958834  -0.11914958]
#    [  5.36086214 -13.16331502  -8.48524602]]
#
#   [[ -1.14839556   3.46577136  -2.12152305]
#    [ -1.84943882  12.7186606   -8.05512696]
#    [ 11.97525898  -2.88160153  -1.46701002]]]]
# === grad_check :
# grad[d_gama0].shape= (2, 1, 1)
# slope[d_gama0].shape= (2, 1, 1)
# grad[d_gama0]=
#  [-11.94928168  11.94928168]
# slope[d_gama0]=
#  [-11.94928168  11.94928168]
# === grad_check :
# grad[d_beta0].shape= (2, 1, 1)
# slope[d_beta0].shape= (2, 1, 1)
# grad[d_beta0]=
#  [-9.33682036  4.91095095]
# slope[d_beta0]=
#  [-9.33682036  4.91095095]
# === grad_check :
# grad[d_k0].shape= (2, 1, 3, 3)
# slope[d_k0].shape= (2, 1, 3, 3)
# grad[d_k0]=
#  [[[ -2.9111366   -6.70670262   7.3887699 ]
#   [ -1.83764836 -11.3200993   -4.307125  ]
#   [ -3.03403071  21.63450007   5.99544126]]
#
#  [[ -3.3644971    0.10143868  10.62404187]
#   [-17.77271024  -9.42103002  -1.00625617]
#   [  7.74468075   2.45984212  -2.68377635]]]
# slope[d_k0]=
#  [[[ -2.91113659  -6.70670262   7.38876989]
#   [ -1.83764836 -11.3200993   -4.307125  ]
#   [ -3.03403071  21.63450006   5.99544126]]
#
#  [[ -3.36449711   0.10143868  10.62404187]
#   [-17.77271024  -9.42103002  -1.00625617]
#   [  7.74468075   2.45984212  -2.68377635]]]
# grad_check: abs_error=
#  {'d_w3': 2.3396398575908746e-08, 'd_gama2': 2.1729065416745775e-09, 'd_beta2': 4.809665797581306e-09, 'd_k2': 1.558986474065558e-08, 'd_gama1': 3.978056186492681e-09, 'd_beta1': 6.475961378016169e-09, 'd_k1': 1.975892349105054e-08, 'd_gama0': 4.296015523256751e-09, 'd_beta0': 2.406437064178614e-09, 'd_k0': 1.5138789551517326e-08}
# grad_check: ratio_error=
#  {'d_w3': 3.549192374169097e-10, 'd_gama2': 3.159978257601332e-11, 'd_beta2': 6.823985401896696e-11, 'd_k2': 1.7619803410510926e-10, 'd_gama1': 5.179771196514446e-10, 'd_beta1': 1.6934006600384125e-10, 'd_k1': 2.681428125638352e-10, 'd_gama0': 1.2710980418784753e-10, 'd_beta0': 1.1405368256174104e-10, 'd_k0': 2.041763043770448e-10}
# check done
