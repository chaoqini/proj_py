# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=2)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=2,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (3, 3)
# params gama0.shape= (1, 1)
# params beta0.shape= (1, 1)
# params w1.shape= (28, 28, 10)
# params gama1.shape= (1, 1)
# params beta1.shape= (1, 1)
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/2
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 4.25e-01
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.12e-05
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 91.62%
# Valid_train percent is : 90.64%
# ============================================================
# hyperparams_test runing iteration = 2/2
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 4.32e-01
# Hyperparams_test: L2_normalize_gama0 = 6.07e-01
# Hyperparams_test: L2_normalize_beta0 = 3.07e-01
# Hyperparams_test: L2_normalize_w1 = 5.72e-04
# Hyperparams_test: L2_normalize_gama1 = 1.89e+00
# Hyperparams_test: L2_normalize_beta1 = 9.40e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 92.09%
# No handles with labels found to put in legend.
# Valid_train percent is : 91.39%
# Real lab number is :	[[6]]
# Precdict number is :	6

# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
# (params,params_init,g,g_d)=cnn.init_params(lays=3)
# params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=2,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
# cnn.show(params,g)
# Out:
# /home/qc/.local/lib/python3.8/site-packages/numpy/core/_methods.py:235: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f2eeb6faffa6> in <module>
#       2 import numpy as np
#       3 import imp
# ----> 4 imp.reload(cnn)
#       5 # (params,params_init,g,g_d)=cnn.init_params(lays=3)
#       6 # params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=2,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
#
# /opt/anaconda/lib/python3.8/imp.py in reload(module)
#     312
#     313     """
# --> 314     return importlib.reload(module)
#     315
#     316
#
# /opt/anaconda/lib/python3.8/importlib/__init__.py in reload(module)
#     167         if spec is None:
#     168             raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169         _bootstrap._exec(spec, module)
#     170         # The module may have replaced itself in sys.modules!
#     171         return sys.modules[name]
#
# /opt/anaconda/lib/python3.8/importlib/_bootstrap.py in _exec(spec, module)
#
# /opt/anaconda/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /opt/anaconda/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/proj_py/cnn.py in <module>
#     525 #x=mnist.train_img[0:2]
#     526 x=np.random.randn(2,4,4)
# --> 527 lab=mnist.train_lab[0:2]
#     528 grad_check(x,lab,params,g,g_d,dv=1e-5)
#     529 #def grad_check(x,lab,params,g,g_d,dv=1e-5):
#
# ~/proj_py/cnn.py in grad_check(x, lab, params, g, g_d, dv)
#     278 def grad_check(x,lab,params,g,g_d,dv=1e-5):
#     279         y2=slope(x,lab,params,g,dv)
# --> 280         y1=bp(x,lab,params,g,g_d)
#     281         (abs_error,ratio_error)=({},{})
#     282         for (k,v) in y1.items():
#
# ~/proj_py/cnn.py in bp(X, LAB, params, g, g_d, e)
#     217                 vi=vi.reshape(vi.shape+(1,1))
#     218                 dXi_Zi=(mmE-Imm-XX)/(mmE.shape[1]*mmE.shape[2]*(vi+e)**0.5)
# --> 219                 d_Zi=np.einsum('mklij,mij->mkln',dXi_Zi,d_Xi)
#     220 #               tt[str(i)+'_4']=(time.time()-tb)*1e3
#     221 #               tt2.append((time.time()-tb)*1e3)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/overrides.py in einsum(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/einsumfunc.py in einsum(out, optimize, *operands, **kwargs)
#    1357         if specified_out:
#    1358             kwargs['out'] = out
# -> 1359         return c_einsum(*operands, **kwargs)
#    1360
#    1361     # Check the kwargs to avoid a more cryptic error later, without having to
#
# ValueError: einstein sum subscripts string included output subscript 'n' which never appeared in an input
