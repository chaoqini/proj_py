# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=3)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=2,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 3
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (3, 3)
# params gama0.shape= (1, 1)
# params beta0.shape= (1, 1)
# params k1.shape= (3, 3)
# params gama1.shape= (1, 1)
# params beta1.shape= (1, 1)
# params w2.shape= (28, 28, 10)
# params gama2.shape= (1, 1)
# params beta2.shape= (1, 1)
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/2
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 4.25e-01
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 2.60e-01
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_w2 = 1.12e-05
# Hyperparams_test: L2_normalize_gama2 = 1.00e+00
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 91.65%
# Valid_train percent is : 90.56%
# ============================================================
# hyperparams_test runing iteration = 2/2
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 4.38e-01
# Hyperparams_test: L2_normalize_gama0 = 5.38e-01
# Hyperparams_test: L2_normalize_beta0 = 3.46e-01
# Hyperparams_test: L2_normalize_k1 = 2.71e-01
# Hyperparams_test: L2_normalize_gama1 = 5.84e-01
# Hyperparams_test: L2_normalize_beta1 = 3.29e-01
# Hyperparams_test: L2_normalize_w2 = 7.95e-04
# Hyperparams_test: L2_normalize_gama2 = 1.89e+00
# Hyperparams_test: L2_normalize_beta2 = 9.84e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 92.34%
# No handles with labels found to put in legend.
# Valid_train percent is : 91.35%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-88d8df539919> in <module>
#       5 (params,params_init,g,g_d)=cnn.init_params(lays=3)
#       6 params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=2,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
# ----> 7 cnn.show(params,g)
#
# ~/proj_py/cnn.py in show(params, g, n)
#     477 #       x=np.expand_dims(x,0)
#     478 #       lab=mnist.test_lab[n].squeeze()
# --> 479         y=fp(x,params,g)
#     480         y=np.argmax(y)
#     481         print('Real lab number is :\t%s'%lab)
#
# ~/proj_py/cnn.py in fp(X, params, g, isop, e)
#     162                 else:
#     163                         ki=params['k'+str(i)]
# --> 164                         coli=im2col(Ai_1,ki.shape[1])
#     165 #                       print('coli=\n',coli)
#     166 #                       Zi=coli_1@(ki.reshape(-1,1))
#
# ~/proj_py/cnn.py in im2col(im, k)
#      78 #       assert(im.ndim==4 and im.shape[-1]==1)
#      79         p=int(k/2)
# ---> 80         (ba,h,w)=im.shape
#      81         imp=np.pad(im,((0,0),(p,p),(p,p)))
#      82         (ba,hp,wp)=imp.shape
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import cnn
import numpy as np
import imp
imp.reload(cnn)
(params,params_init,g,g_d)=cnn.init_params(lays=2)
params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
cnn.show(params,g)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params k0.shape= (3, 3)
# params gama0.shape= (1, 1)
# params beta0.shape= (1, 1)
# params w1.shape= (28, 28, 10)
# params gama1.shape= (1, 1)
# params beta1.shape= (1, 1)
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 4.25e-01
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.12e-05
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 91.62%
# Valid_train percent is : 90.64%
# ============================================================
# hyperparams_test runing iteration = 2/9
# hyperparams_test runing: lri = 1.354e-03
# Hyperparams_test: L2_normalize_k0 = 4.32e-01
# Hyperparams_test: L2_normalize_gama0 = 6.07e-01
# Hyperparams_test: L2_normalize_beta0 = 3.07e-01
# Hyperparams_test: L2_normalize_w1 = 5.72e-04
# Hyperparams_test: L2_normalize_gama1 = 1.89e+00
# Hyperparams_test: L2_normalize_beta1 = 7.38e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 92.09%
# Valid_train percent is : 91.39%
# ============================================================
# hyperparams_test runing iteration = 3/9
# hyperparams_test runing: lri = 9.166e-04
# Hyperparams_test: L2_normalize_k0 = 4.36e-01
# Hyperparams_test: L2_normalize_gama0 = 6.04e-01
# Hyperparams_test: L2_normalize_beta0 = 3.12e-01
# Hyperparams_test: L2_normalize_w1 = 7.60e-04
# Hyperparams_test: L2_normalize_gama1 = 2.52e+00
# Hyperparams_test: L2_normalize_beta1 = 9.14e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 92.70%
# Valid_train percent is : 92.04%
# ============================================================
# hyperparams_test runing iteration = 4/9
# hyperparams_test runing: lri = 6.206e-04
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 6.02e-01
# Hyperparams_test: L2_normalize_beta0 = 3.15e-01
# Hyperparams_test: L2_normalize_w1 = 8.53e-04
# Hyperparams_test: L2_normalize_gama1 = 2.91e+00
# Hyperparams_test: L2_normalize_beta1 = 1.38e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 92.93%
# Valid_train percent is : 92.41%
# ============================================================
# hyperparams_test runing iteration = 5/9
# hyperparams_test runing: lri = 4.201e-04
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 6.01e-01
# Hyperparams_test: L2_normalize_beta0 = 3.16e-01
# Hyperparams_test: L2_normalize_w1 = 9.00e-04
# Hyperparams_test: L2_normalize_gama1 = 3.11e+00
# Hyperparams_test: L2_normalize_beta1 = 5.03e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 93.08%
# Valid_train percent is : 92.65%
# ============================================================
# hyperparams_test runing iteration = 6/9
# hyperparams_test runing: lri = 2.844e-04
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 6.00e-01
# Hyperparams_test: L2_normalize_beta0 = 3.18e-01
# Hyperparams_test: L2_normalize_w1 = 9.26e-04
# Hyperparams_test: L2_normalize_gama1 = 3.24e+00
# Hyperparams_test: L2_normalize_beta1 = 2.69e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 93.11%
# Valid_train percent is : 92.80%
# ============================================================
# hyperparams_test runing iteration = 7/9
# hyperparams_test runing: lri = 1.925e-04
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 5.99e-01
# Hyperparams_test: L2_normalize_beta0 = 3.18e-01
# Hyperparams_test: L2_normalize_w1 = 9.40e-04
# Hyperparams_test: L2_normalize_gama1 = 3.31e+00
# Hyperparams_test: L2_normalize_beta1 = 4.89e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 93.10%
# Valid_train percent is : 92.88%
# ============================================================
# hyperparams_test runing iteration = 8/9
# hyperparams_test runing: lri = 1.303e-04
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 5.99e-01
# Hyperparams_test: L2_normalize_beta0 = 3.19e-01
# Hyperparams_test: L2_normalize_w1 = 9.49e-04
# Hyperparams_test: L2_normalize_gama1 = 3.36e+00
# Hyperparams_test: L2_normalize_beta1 = 6.21e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 93.10%
# Valid_train percent is : 92.95%
# ============================================================
# hyperparams_test runing iteration = 9/9
# hyperparams_test runing: lri = 8.825e-05
# Hyperparams_test: L2_normalize_k0 = 4.37e-01
# Hyperparams_test: L2_normalize_gama0 = 5.98e-01
# Hyperparams_test: L2_normalize_beta0 = 3.19e-01
# Hyperparams_test: L2_normalize_w1 = 9.54e-04
# Hyperparams_test: L2_normalize_gama1 = 3.40e+00
# Hyperparams_test: L2_normalize_beta1 = 5.41e-11
# Train input X.shape=(781, 64, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# Training iteration number = 78/781
# Training iteration number = 156/781
# Training iteration number = 234/781
# Training iteration number = 312/781
# Training iteration number = 390/781
# Training iteration number = 468/781
# Training iteration number = 546/781
# Training iteration number = 624/781
# Training iteration number = 702/781
# Training iteration number = 780/781
# X.shape= (100, 100, 28, 28)
# Valid percent is : 93.10%
# No handles with labels found to put in legend.
# Valid_train percent is : 92.94%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e0023f1ac764> in <module>
#       5 (params,params_init,g,g_d)=cnn.init_params(lays=2)
#       6 params=cnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
# ----> 7 cnn.show(params,g)
#
# ~/proj_py/cnn.py in show(params, g, n)
#     473 def show(params,g,n=-1):
#     474         if n==-1: n=np.random.randint(mnist.test_num)
# --> 475         x=mnist.test_img[n]
#     476         lab=mnist.test_lab[n]
#     477         x=np.expand_dims(x,0)
#
# ~/proj_py/cnn.py in fp(X, params, g, isop, e)
#     162                 else:
#     163                         ki=params['k'+str(i)]
# --> 164                         coli=im2col(Ai_1,ki.shape[1])
#     165 #                       print('coli=\n',coli)
#     166 #                       Zi=coli_1@(ki.reshape(-1,1))
#
# ~/proj_py/cnn.py in im2col(im, k)
#      78 #       assert(im.ndim==4 and im.shape[-1]==1)
#      79         p=int(k/2)
# ---> 80         (ba,h,w)=im.shape
#      81         imp=np.pad(im,((0,0),(p,p),(p,p)))
#      82         (ba,hp,wp)=imp.shape
#
# ValueError: too many values to unpack (expected 3)
