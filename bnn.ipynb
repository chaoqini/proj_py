# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=2,nnode=256)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 32
# heyperparams_test: isupdate = 1
# params w0.shape= (256, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params w1.shape= (10, 256)
# params beta1.shape= ()
# params gama1.shape= ()
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ...
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_w0 = 2.23e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_w1 = 1.99e-05
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# ...

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=2,nnode=128)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=32,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 2
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 32
# heyperparams_test: isupdate = 1
# params w0.shape= (128, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params w1.shape= (10, 128)
# params beta1.shape= ()
# params gama1.shape= ()
# active function g[0] is: relu
# active function g[1] is: softmax
# active function g[2] is: cross_entropy
# ...
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_w0 = 3.15e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# Hyperparams_test: L2_normalize_w1 = 2.74e-05
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_gama1 = 1.00e+00
# Train input X.shape=(1562, 32, 784, 1), LAB.shape=(1562, 32, 1, 1)
# Training bath running ...
# Training iteration number = 0/1562
# ...

# %%
# (params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=2,nnode=256)
bnn.show(params,g)
# Out:
# Real lab number is :	8
# Precdict number is :	8

# %%
import bnn
import numpy as np
import imp
imp.reload(bnn)
(params,params_init,g,g_d,l2_grad)=bnn.bnn.init_params(lays=3,nnode=128)
bnn.hyperparams_test(params,params_init,g,g_d,nloop=9,lr0=2e-3,klr=0.9995,batch=64,isupdate=1,isl2grad=1)
# Out:
# heyperparams_test: ...
# heyperparams_test: layers = 3
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 1
# params b0.shape= (128, 1)
# params w0.shape= (128, 784)
# params beta0.shape= ()
# params gama0.shape= ()
# params b1.shape= (128, 1)
# params w1.shape= (128, 128)
# params beta1.shape= ()
# params gama1.shape= ()
# params b2.shape= (10, 1)
# params w2.shape= (10, 128)
# params beta2.shape= ()
# params gama2.shape= ()
# active function g[0] is: relu
# active function g[1] is: relu
# active function g[2] is: softmax
# active function g[3] is: cross_entropy
# ...
# hyperparams_test runing iteration = 1/9
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_b0 = 0.00e+00
# Hyperparams_test: L2_normalize_w0 = 3.15e-06
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_gama0 = 1.00e+00
# ...
