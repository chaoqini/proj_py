# %%
import ann
import numpy as np
import pickle
import imp
imp.reload(ann)
(params,params_init,g)=ann.init_params(lays=4,imchin=2,dimch=0)
params=ann.hyperparams_test(params,params_init,g,nloop=8,batch=64,isl2grad=1)
with open('ann_p3.pkl', 'wb') as f: pickle.dump(params,f)
with open('ann_p3.pkl', 'rb') as f: params2=pickle.load(f)
for k,v in params2.items(): print('%s.shape='%k,v.shape)
ann.show(params,g)
# Out:
# init_params: ch= [1, 2, 3, 4, 10]
# init_params: ch= [1, 2, 2, 2, 10]
# heyperparams_test: ...
# heyperparams_test: layers = 4
# heyperparams_test: learning rate lr0 = 0.002
# heyperparams_test: learning rate klr = 0.9995
# heyperparams_test: batch = 64
# heyperparams_test: isupdate = 0
# params k0.shape= (2, 1, 3, 3)
# params gama0.shape= (2, 1, 1)
# params beta0.shape= (2, 1, 1)
# params k1.shape= (2, 2, 3, 3)
# params gama1.shape= (2, 1, 1)
# params beta1.shape= (2, 1, 1)
# params k2.shape= (2, 2, 3, 3)
# params gama2.shape= (2, 1, 1)
# params beta2.shape= (2, 1, 1)
# params w3.shape= (10, 2, 28, 28)
# active function g[0] is: Relu
# active function g[1] is: Relu
# active function g[2] is: Relu
# active function g[3] is: softmax
# active function g[4] is: cross_entropy
# ============================================================
# hyperparams_test runing iteration = 1/8
# hyperparams_test runing: lri = 2.000e-03
# Hyperparams_test: L2_normalize_k0 = 2.39e-01
# Hyperparams_test: L2_normalize_gama0 = 7.07e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 1.66e-01
# Hyperparams_test: L2_normalize_gama1 = 7.07e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 1.54e-01
# Hyperparams_test: L2_normalize_gama2 = 7.07e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 7.99e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# 0 bp detal time dt1= 7.47s
# 0 bp detal time dt2= 0.05s
# 1 bp detal time dt1= 7.54s
# 1 bp detal time dt2= 0.05s
# 2 bp detal time dt1= 7.33s
# 2 bp detal time dt2= 0.05s
# 3 bp detal time dt1= 7.51s
# 3 bp detal time dt2= 0.05s
# 4 bp detal time dt1= 7.49s
# 4 bp detal time dt2= 0.05s
# 5 bp detal time dt1= 7.51s
# 5 bp detal time dt2= 0.05s
# 6 bp detal time dt1= 7.46s
# 6 bp detal time dt2= 0.05s
# 7 bp detal time dt1= 7.43s
# 7 bp detal time dt2= 0.05s
# 8 bp detal time dt1= 7.41s
# 8 bp detal time dt2= 0.05s
# 9 bp detal time dt1= 7.53s
# 9 bp detal time dt2= 0.05s
# 10 bp detal time dt1= 7.53s
# 10 bp detal time dt2= 0.05s
# 11 bp detal time dt1= 7.32s
# 11 bp detal time dt2= 0.05s
# 12 bp detal time dt1= 7.50s
# 12 bp detal time dt2= 0.05s
# 13 bp detal time dt1= 7.32s
# 13 bp detal time dt2= 0.05s
# 14 bp detal time dt1= 7.57s
# 14 bp detal time dt2= 0.05s
# 15 bp detal time dt1= 7.40s
# 15 bp detal time dt2= 0.05s
# 16 bp detal time dt1= 7.32s
# 16 bp detal time dt2= 0.05s
# 17 bp detal time dt1= 7.39s
# 17 bp detal time dt2= 0.05s
# 18 bp detal time dt1= 7.51s
# 18 bp detal time dt2= 0.05s
# 19 bp detal time dt1= 7.46s
# 19 bp detal time dt2= 0.05s
# 20 bp detal time dt1= 7.36s
# 20 bp detal time dt2= 0.05s
# 21 bp detal time dt1= 7.42s
# 21 bp detal time dt2= 0.05s
# 22 bp detal time dt1= 7.46s
# 22 bp detal time dt2= 0.05s
# 23 bp detal time dt1= 7.46s
# 23 bp detal time dt2= 0.05s
# 24 bp detal time dt1= 7.31s
# 24 bp detal time dt2= 0.05s
# 25 bp detal time dt1= 7.51s
# 25 bp detal time dt2= 0.05s
# 26 bp detal time dt1= 7.40s
# 26 bp detal time dt2= 0.05s
# 27 bp detal time dt1= 7.49s
# 27 bp detal time dt2= 0.05s
# 28 bp detal time dt1= 7.34s
# 28 bp detal time dt2= 0.04s
# 29 bp detal time dt1= 7.54s
# 29 bp detal time dt2= 0.04s
# 30 bp detal time dt1= 7.84s
# 30 bp detal time dt2= 0.05s
# 31 bp detal time dt1= 8.37s
# 31 bp detal time dt2= 0.06s
# 32 bp detal time dt1= 8.51s
# 32 bp detal time dt2= 0.05s
# 33 bp detal time dt1= 7.88s
# 33 bp detal time dt2= 0.05s
# 34 bp detal time dt1= 7.78s
# 34 bp detal time dt2= 0.05s
# 35 bp detal time dt1= 7.91s
# 35 bp detal time dt2= 0.04s
# 36 bp detal time dt1= 7.90s
# 36 bp detal time dt2= 0.04s
# 37 bp detal time dt1= 8.06s
# 37 bp detal time dt2= 0.04s
# 38 bp detal time dt1= 8.07s
# 38 bp detal time dt2= 0.05s
# 39 bp detal time dt1= 7.82s
# 39 bp detal time dt2= 0.05s
# 40 bp detal time dt1= 7.96s
# 40 bp detal time dt2= 0.06s
# 41 bp detal time dt1= 7.81s
# 41 bp detal time dt2= 0.05s
# 42 bp detal time dt1= 8.30s
# 42 bp detal time dt2= 0.05s
# 43 bp detal time dt1= 7.90s
# 43 bp detal time dt2= 0.05s
# 44 bp detal time dt1= 7.76s
# 44 bp detal time dt2= 0.05s
# 45 bp detal time dt1= 7.91s
# 45 bp detal time dt2= 0.05s
# 46 bp detal time dt1= 7.97s
# 46 bp detal time dt2= 0.05s
# 47 bp detal time dt1= 8.18s
# 47 bp detal time dt2= 0.05s
# 48 bp detal time dt1= 6.66s
# 48 bp detal time dt2= 0.06s
# 49 bp detal time dt1= 6.36s
# 49 bp detal time dt2= 0.05s
# 50 bp detal time dt1= 5.18s
# 50 bp detal time dt2= 0.05s
# 51 bp detal time dt1= 5.01s
# 51 bp detal time dt2= 0.04s
# 52 bp detal time dt1= 4.44s
# 52 bp detal time dt2= 0.05s
# 53 bp detal time dt1= 4.53s
# 53 bp detal time dt2= 0.04s
# 54 bp detal time dt1= 4.11s
# 54 bp detal time dt2= 0.04s
# 55 bp detal time dt1= 4.11s
# 55 bp detal time dt2= 0.04s
# 56 bp detal time dt1= 4.11s
# 56 bp detal time dt2= 0.04s
# 57 bp detal time dt1= 4.13s
# 57 bp detal time dt2= 0.04s
# 58 bp detal time dt1= 4.11s
# 58 bp detal time dt2= 0.04s
# 59 bp detal time dt1= 4.11s
# 59 bp detal time dt2= 0.04s
# 60 bp detal time dt1= 4.11s
# 60 bp detal time dt2= 0.04s
# 61 bp detal time dt1= 4.12s
# 61 bp detal time dt2= 0.04s
# 62 bp detal time dt1= 4.12s
# 62 bp detal time dt2= 0.04s
# 63 bp detal time dt1= 4.11s
# 63 bp detal time dt2= 0.04s
# 64 bp detal time dt1= 4.11s
# 64 bp detal time dt2= 0.04s
# 65 bp detal time dt1= 4.11s
# 65 bp detal time dt2= 0.04s
# 66 bp detal time dt1= 4.11s
# 66 bp detal time dt2= 0.04s
# 67 bp detal time dt1= 4.11s
# 67 bp detal time dt2= 0.04s
# 68 bp detal time dt1= 4.11s
# 68 bp detal time dt2= 0.04s
# 69 bp detal time dt1= 4.11s
# 69 bp detal time dt2= 0.04s
# 70 bp detal time dt1= 4.11s
# 70 bp detal time dt2= 0.04s
# 71 bp detal time dt1= 4.11s
# 71 bp detal time dt2= 0.04s
# 72 bp detal time dt1= 4.12s
# 72 bp detal time dt2= 0.04s
# 73 bp detal time dt1= 4.11s
# 73 bp detal time dt2= 0.04s
# 74 bp detal time dt1= 4.11s
# 74 bp detal time dt2= 0.04s
# 75 bp detal time dt1= 4.12s
# 75 bp detal time dt2= 0.04s
# 76 bp detal time dt1= 4.12s
# 76 bp detal time dt2= 0.04s
# 77 bp detal time dt1= 4.11s
# 77 bp detal time dt2= 0.04s
# 78 bp detal time dt1= 4.12s
# 78 bp detal time dt2= 0.04s
# 79 bp detal time dt1= 4.12s
# 79 bp detal time dt2= 0.04s
# 80 bp detal time dt1= 4.12s
# 80 bp detal time dt2= 0.04s
# 81 bp detal time dt1= 4.12s
# 81 bp detal time dt2= 0.04s
# 82 bp detal time dt1= 4.11s
# 82 bp detal time dt2= 0.04s
# 83 bp detal time dt1= 4.12s
# 83 bp detal time dt2= 0.04s
# 84 bp detal time dt1= 4.11s
# 84 bp detal time dt2= 0.04s
# 85 bp detal time dt1= 4.11s
# 85 bp detal time dt2= 0.04s
# 86 bp detal time dt1= 4.12s
# 86 bp detal time dt2= 0.04s
# 87 bp detal time dt1= 4.11s
# 87 bp detal time dt2= 0.04s
# 88 bp detal time dt1= 4.12s
# 88 bp detal time dt2= 0.04s
# 89 bp detal time dt1= 4.11s
# 89 bp detal time dt2= 0.04s
# 90 bp detal time dt1= 4.11s
# 90 bp detal time dt2= 0.04s
# 91 bp detal time dt1= 4.12s
# 91 bp detal time dt2= 0.04s
# 92 bp detal time dt1= 4.15s
# 92 bp detal time dt2= 0.04s
# 93 bp detal time dt1= 4.12s
# 93 bp detal time dt2= 0.04s
# 94 bp detal time dt1= 4.12s
# 94 bp detal time dt2= 0.04s
# 95 bp detal time dt1= 4.12s
# 95 bp detal time dt2= 0.04s
# 96 bp detal time dt1= 4.11s
# 96 bp detal time dt2= 0.04s
# 97 bp detal time dt1= 4.11s
# 97 bp detal time dt2= 0.04s
# 98 bp detal time dt1= 4.11s
# 98 bp detal time dt2= 0.04s
# 99 bp detal time dt1= 4.11s
# 99 bp detal time dt2= 0.04s
# 100 bp detal time dt1= 4.11s
# 100 bp detal time dt2= 0.04s
# 101 bp detal time dt1= 4.11s
# 101 bp detal time dt2= 0.04s
# 102 bp detal time dt1= 4.11s
# 102 bp detal time dt2= 0.04s
# 103 bp detal time dt1= 4.11s
# 103 bp detal time dt2= 0.04s
# 104 bp detal time dt1= 4.12s
# 104 bp detal time dt2= 0.04s
# 105 bp detal time dt1= 4.12s
# 105 bp detal time dt2= 0.04s
# 106 bp detal time dt1= 4.12s
# 106 bp detal time dt2= 0.04s
# 107 bp detal time dt1= 4.12s
# 107 bp detal time dt2= 0.04s
# 108 bp detal time dt1= 4.12s
# 108 bp detal time dt2= 0.04s
# 109 bp detal time dt1= 4.12s
# 109 bp detal time dt2= 0.04s
# 110 bp detal time dt1= 4.12s
# 110 bp detal time dt2= 0.04s
# 111 bp detal time dt1= 4.12s
# 111 bp detal time dt2= 0.04s
# 112 bp detal time dt1= 4.12s
# 112 bp detal time dt2= 0.04s
# 113 bp detal time dt1= 4.11s
# 113 bp detal time dt2= 0.04s
# 114 bp detal time dt1= 4.12s
# 114 bp detal time dt2= 0.04s
# 115 bp detal time dt1= 4.14s
# 115 bp detal time dt2= 0.04s
# 116 bp detal time dt1= 4.12s
# 116 bp detal time dt2= 0.04s
# 117 bp detal time dt1= 4.11s
# 117 bp detal time dt2= 0.04s
# 118 bp detal time dt1= 4.12s
# 118 bp detal time dt2= 0.04s
# 119 bp detal time dt1= 4.12s
# 119 bp detal time dt2= 0.04s
# 120 bp detal time dt1= 4.11s
# 120 bp detal time dt2= 0.04s
# 121 bp detal time dt1= 4.11s
# 121 bp detal time dt2= 0.04s
# 122 bp detal time dt1= 4.12s
# 122 bp detal time dt2= 0.04s
# 123 bp detal time dt1= 4.12s
# 123 bp detal time dt2= 0.04s
# 124 bp detal time dt1= 4.11s
# 124 bp detal time dt2= 0.04s
# 125 bp detal time dt1= 4.11s
# 125 bp detal time dt2= 0.04s
# 126 bp detal time dt1= 4.12s
# 126 bp detal time dt2= 0.04s
# 127 bp detal time dt1= 4.12s
# 127 bp detal time dt2= 0.04s
# 128 bp detal time dt1= 4.12s
# 128 bp detal time dt2= 0.04s
# 129 bp detal time dt1= 4.11s
# 129 bp detal time dt2= 0.04s
# 130 bp detal time dt1= 4.11s
# 130 bp detal time dt2= 0.04s
# 131 bp detal time dt1= 4.11s
# 131 bp detal time dt2= 0.04s
# 132 bp detal time dt1= 4.11s
# 132 bp detal time dt2= 0.04s
# 133 bp detal time dt1= 4.11s
# 133 bp detal time dt2= 0.04s
# 134 bp detal time dt1= 4.11s
# 134 bp detal time dt2= 0.04s
# 135 bp detal time dt1= 4.11s
# 135 bp detal time dt2= 0.04s
# 136 bp detal time dt1= 4.12s
# 136 bp detal time dt2= 0.04s
# 137 bp detal time dt1= 4.11s
# 137 bp detal time dt2= 0.04s
# 138 bp detal time dt1= 4.11s
# 138 bp detal time dt2= 0.04s
# 139 bp detal time dt1= 4.11s
# 139 bp detal time dt2= 0.04s
# 140 bp detal time dt1= 4.11s
# 140 bp detal time dt2= 0.04s
# 141 bp detal time dt1= 4.14s
# 141 bp detal time dt2= 0.04s
# 142 bp detal time dt1= 4.12s
# 142 bp detal time dt2= 0.04s
# 143 bp detal time dt1= 4.12s
# 143 bp detal time dt2= 0.04s
# 144 bp detal time dt1= 4.14s
# 144 bp detal time dt2= 0.04s
# 145 bp detal time dt1= 4.13s
# 145 bp detal time dt2= 0.04s
# 146 bp detal time dt1= 4.11s
# 146 bp detal time dt2= 0.04s
# 147 bp detal time dt1= 4.13s
# 147 bp detal time dt2= 0.04s
# 148 bp detal time dt1= 4.12s
# 148 bp detal time dt2= 0.04s
# 149 bp detal time dt1= 4.13s
# 149 bp detal time dt2= 0.04s
# 150 bp detal time dt1= 4.12s
# 150 bp detal time dt2= 0.04s
# 151 bp detal time dt1= 4.12s
# 151 bp detal time dt2= 0.04s
# 152 bp detal time dt1= 4.12s
# 152 bp detal time dt2= 0.04s
# 153 bp detal time dt1= 4.12s
# 153 bp detal time dt2= 0.04s
# 154 bp detal time dt1= 4.12s
# 154 bp detal time dt2= 0.04s
# 155 bp detal time dt1= 4.12s
# 155 bp detal time dt2= 0.04s
# 156 bp detal time dt1= 4.12s
# 156 bp detal time dt2= 0.04s
# 157 bp detal time dt1= 4.12s
# 157 bp detal time dt2= 0.04s
# 158 bp detal time dt1= 4.12s
# 158 bp detal time dt2= 0.04s
# 159 bp detal time dt1= 4.12s
# 159 bp detal time dt2= 0.04s
# 160 bp detal time dt1= 4.12s
# 160 bp detal time dt2= 0.04s
# 161 bp detal time dt1= 4.12s
# 161 bp detal time dt2= 0.04s
# 162 bp detal time dt1= 4.12s
# 162 bp detal time dt2= 0.04s
# 163 bp detal time dt1= 4.12s
# 163 bp detal time dt2= 0.04s
# 164 bp detal time dt1= 4.12s
# 164 bp detal time dt2= 0.04s
# 165 bp detal time dt1= 4.12s
# 165 bp detal time dt2= 0.04s
# 166 bp detal time dt1= 4.12s
# 166 bp detal time dt2= 0.04s
# 167 bp detal time dt1= 4.12s
# 167 bp detal time dt2= 0.04s
# 168 bp detal time dt1= 4.12s
# 168 bp detal time dt2= 0.04s
# 169 bp detal time dt1= 4.12s
# 169 bp detal time dt2= 0.04s
# 170 bp detal time dt1= 4.12s
# 170 bp detal time dt2= 0.04s
# 171 bp detal time dt1= 4.12s
# 171 bp detal time dt2= 0.04s
# 172 bp detal time dt1= 4.13s
# 172 bp detal time dt2= 0.04s
# 173 bp detal time dt1= 4.13s
# 173 bp detal time dt2= 0.04s
# 174 bp detal time dt1= 4.12s
# 174 bp detal time dt2= 0.04s
# 175 bp detal time dt1= 4.12s
# 175 bp detal time dt2= 0.04s
# 176 bp detal time dt1= 4.12s
# 176 bp detal time dt2= 0.04s
# 177 bp detal time dt1= 4.12s
# 177 bp detal time dt2= 0.04s
# 178 bp detal time dt1= 4.12s
# 178 bp detal time dt2= 0.04s
# 179 bp detal time dt1= 4.12s
# 179 bp detal time dt2= 0.04s
# 180 bp detal time dt1= 4.12s
# 180 bp detal time dt2= 0.04s
# 181 bp detal time dt1= 4.12s
# 181 bp detal time dt2= 0.04s
# 182 bp detal time dt1= 4.12s
# 182 bp detal time dt2= 0.04s
# 183 bp detal time dt1= 4.12s
# 183 bp detal time dt2= 0.04s
# 184 bp detal time dt1= 4.12s
# 184 bp detal time dt2= 0.04s
# 185 bp detal time dt1= 4.12s
# 185 bp detal time dt2= 0.04s
# 186 bp detal time dt1= 4.12s
# 186 bp detal time dt2= 0.04s
# 187 bp detal time dt1= 4.12s
# 187 bp detal time dt2= 0.04s
# 188 bp detal time dt1= 4.12s
# 188 bp detal time dt2= 0.04s
# 189 bp detal time dt1= 4.12s
# 189 bp detal time dt2= 0.04s
# 190 bp detal time dt1= 4.12s
# 190 bp detal time dt2= 0.04s
# 191 bp detal time dt1= 4.12s
# 191 bp detal time dt2= 0.04s
# 192 bp detal time dt1= 4.12s
# 192 bp detal time dt2= 0.04s
# 193 bp detal time dt1= 4.12s
# 193 bp detal time dt2= 0.04s
# 194 bp detal time dt1= 4.12s
# 194 bp detal time dt2= 0.04s
# 195 bp detal time dt1= 4.12s
# 195 bp detal time dt2= 0.04s
# 196 bp detal time dt1= 4.12s
# 196 bp detal time dt2= 0.04s
# 197 bp detal time dt1= 4.12s
# 197 bp detal time dt2= 0.04s
# 198 bp detal time dt1= 4.12s
# 198 bp detal time dt2= 0.04s
# 199 bp detal time dt1= 4.12s
# 199 bp detal time dt2= 0.04s
# 200 bp detal time dt1= 4.12s
# 200 bp detal time dt2= 0.04s
# 201 bp detal time dt1= 4.13s
# 201 bp detal time dt2= 0.04s
# 202 bp detal time dt1= 4.12s
# 202 bp detal time dt2= 0.04s
# 203 bp detal time dt1= 4.12s
# 203 bp detal time dt2= 0.04s
# 204 bp detal time dt1= 4.12s
# 204 bp detal time dt2= 0.04s
# 205 bp detal time dt1= 4.12s
# 205 bp detal time dt2= 0.04s
# 206 bp detal time dt1= 4.12s
# 206 bp detal time dt2= 0.04s
# 207 bp detal time dt1= 4.12s
# 207 bp detal time dt2= 0.04s
# 208 bp detal time dt1= 4.12s
# 208 bp detal time dt2= 0.04s
# 209 bp detal time dt1= 4.12s
# 209 bp detal time dt2= 0.04s
# 210 bp detal time dt1= 4.12s
# 210 bp detal time dt2= 0.04s
# 211 bp detal time dt1= 4.12s
# 211 bp detal time dt2= 0.04s
# 212 bp detal time dt1= 4.12s
# 212 bp detal time dt2= 0.04s
# 213 bp detal time dt1= 4.12s
# 213 bp detal time dt2= 0.04s
# 214 bp detal time dt1= 4.12s
# 214 bp detal time dt2= 0.04s
# 215 bp detal time dt1= 4.12s
# 215 bp detal time dt2= 0.04s
# 216 bp detal time dt1= 4.12s
# 216 bp detal time dt2= 0.04s
# 217 bp detal time dt1= 4.13s
# 217 bp detal time dt2= 0.04s
# 218 bp detal time dt1= 4.12s
# 218 bp detal time dt2= 0.04s
# 219 bp detal time dt1= 4.13s
# 219 bp detal time dt2= 0.04s
# 220 bp detal time dt1= 4.13s
# 220 bp detal time dt2= 0.04s
# 221 bp detal time dt1= 4.12s
# 221 bp detal time dt2= 0.04s
# 222 bp detal time dt1= 4.12s
# 222 bp detal time dt2= 0.04s
# 223 bp detal time dt1= 4.12s
# 223 bp detal time dt2= 0.04s
# 224 bp detal time dt1= 4.12s
# 224 bp detal time dt2= 0.04s
# 225 bp detal time dt1= 4.12s
# 225 bp detal time dt2= 0.04s
# 226 bp detal time dt1= 4.12s
# 226 bp detal time dt2= 0.04s
# 227 bp detal time dt1= 4.12s
# 227 bp detal time dt2= 0.04s
# 228 bp detal time dt1= 4.12s
# 228 bp detal time dt2= 0.04s
# 229 bp detal time dt1= 4.12s
# 229 bp detal time dt2= 0.04s
# 230 bp detal time dt1= 4.13s
# 230 bp detal time dt2= 0.04s
# 231 bp detal time dt1= 4.13s
# 231 bp detal time dt2= 0.04s
# 232 bp detal time dt1= 4.12s
# 232 bp detal time dt2= 0.04s
# 233 bp detal time dt1= 4.12s
# 233 bp detal time dt2= 0.04s
# 234 bp detal time dt1= 4.12s
# 234 bp detal time dt2= 0.04s
# 235 bp detal time dt1= 4.12s
# 235 bp detal time dt2= 0.04s
# 236 bp detal time dt1= 4.12s
# 236 bp detal time dt2= 0.04s
# 237 bp detal time dt1= 4.12s
# 237 bp detal time dt2= 0.04s
# 238 bp detal time dt1= 4.12s
# 238 bp detal time dt2= 0.04s
# 239 bp detal time dt1= 4.15s
# 239 bp detal time dt2= 0.04s
# 240 bp detal time dt1= 4.12s
# 240 bp detal time dt2= 0.04s
# 241 bp detal time dt1= 4.12s
# 241 bp detal time dt2= 0.04s
# 242 bp detal time dt1= 4.12s
# 242 bp detal time dt2= 0.04s
# 243 bp detal time dt1= 4.12s
# 243 bp detal time dt2= 0.04s
# 244 bp detal time dt1= 4.12s
# 244 bp detal time dt2= 0.04s
# 245 bp detal time dt1= 4.12s
# 245 bp detal time dt2= 0.04s
# 246 bp detal time dt1= 4.12s
# 246 bp detal time dt2= 0.04s
# 247 bp detal time dt1= 4.12s
# 247 bp detal time dt2= 0.04s
# 248 bp detal time dt1= 4.12s
# 248 bp detal time dt2= 0.04s
# 249 bp detal time dt1= 4.12s
# 249 bp detal time dt2= 0.04s
# 250 bp detal time dt1= 4.12s
# 250 bp detal time dt2= 0.04s
# 251 bp detal time dt1= 4.12s
# 251 bp detal time dt2= 0.04s
# 252 bp detal time dt1= 4.12s
# 252 bp detal time dt2= 0.04s
# 253 bp detal time dt1= 4.12s
# 253 bp detal time dt2= 0.04s
# 254 bp detal time dt1= 4.12s
# 254 bp detal time dt2= 0.04s
# 255 bp detal time dt1= 4.12s
# 255 bp detal time dt2= 0.04s
# 256 bp detal time dt1= 4.12s
# 256 bp detal time dt2= 0.04s
# 257 bp detal time dt1= 4.12s
# 257 bp detal time dt2= 0.04s
# 258 bp detal time dt1= 4.12s
# 258 bp detal time dt2= 0.04s
# 259 bp detal time dt1= 4.14s
# 259 bp detal time dt2= 0.04s
# 260 bp detal time dt1= 4.13s
# 260 bp detal time dt2= 0.04s
# 261 bp detal time dt1= 4.12s
# 261 bp detal time dt2= 0.04s
# 262 bp detal time dt1= 4.12s
# 262 bp detal time dt2= 0.04s
# 263 bp detal time dt1= 4.12s
# 263 bp detal time dt2= 0.04s
# 264 bp detal time dt1= 4.12s
# 264 bp detal time dt2= 0.04s
# 265 bp detal time dt1= 4.12s
# 265 bp detal time dt2= 0.04s
# 266 bp detal time dt1= 4.12s
# 266 bp detal time dt2= 0.04s
# 267 bp detal time dt1= 4.12s
# 267 bp detal time dt2= 0.04s
# 268 bp detal time dt1= 4.12s
# 268 bp detal time dt2= 0.04s
# 269 bp detal time dt1= 4.12s
# 269 bp detal time dt2= 0.04s
# 270 bp detal time dt1= 4.12s
# 270 bp detal time dt2= 0.04s
# 271 bp detal time dt1= 4.12s
# 271 bp detal time dt2= 0.04s
# 272 bp detal time dt1= 4.12s
# 272 bp detal time dt2= 0.04s
# 273 bp detal time dt1= 4.12s
# 273 bp detal time dt2= 0.04s
# 274 bp detal time dt1= 4.12s
# 274 bp detal time dt2= 0.04s
# 275 bp detal time dt1= 4.12s
# 275 bp detal time dt2= 0.04s
# 276 bp detal time dt1= 4.12s
# 276 bp detal time dt2= 0.04s
# 277 bp detal time dt1= 4.12s
# 277 bp detal time dt2= 0.04s
# 278 bp detal time dt1= 4.12s
# 278 bp detal time dt2= 0.04s
# 279 bp detal time dt1= 4.12s
# 279 bp detal time dt2= 0.04s
# 280 bp detal time dt1= 4.12s
# 280 bp detal time dt2= 0.04s
# 281 bp detal time dt1= 4.12s
# 281 bp detal time dt2= 0.04s
# 282 bp detal time dt1= 4.12s
# 282 bp detal time dt2= 0.04s
# 283 bp detal time dt1= 4.12s
# 283 bp detal time dt2= 0.04s
# 284 bp detal time dt1= 4.12s
# 284 bp detal time dt2= 0.04s
# 285 bp detal time dt1= 4.12s
# 285 bp detal time dt2= 0.04s
# 286 bp detal time dt1= 4.12s
# 286 bp detal time dt2= 0.04s
# 287 bp detal time dt1= 4.12s
# 287 bp detal time dt2= 0.04s
# 288 bp detal time dt1= 4.14s
# 288 bp detal time dt2= 0.04s
# 289 bp detal time dt1= 4.14s
# 289 bp detal time dt2= 0.04s
# 290 bp detal time dt1= 4.14s
# 290 bp detal time dt2= 0.04s
# 291 bp detal time dt1= 4.12s
# 291 bp detal time dt2= 0.04s
# 292 bp detal time dt1= 4.13s
# 292 bp detal time dt2= 0.04s
# 293 bp detal time dt1= 4.12s
# 293 bp detal time dt2= 0.04s
# 294 bp detal time dt1= 4.12s
# 294 bp detal time dt2= 0.04s
# 295 bp detal time dt1= 4.12s
# 295 bp detal time dt2= 0.04s
# 296 bp detal time dt1= 4.12s
# 296 bp detal time dt2= 0.04s
# 297 bp detal time dt1= 4.12s
# 297 bp detal time dt2= 0.04s
# 298 bp detal time dt1= 4.12s
# 298 bp detal time dt2= 0.04s
# 299 bp detal time dt1= 4.12s
# 299 bp detal time dt2= 0.04s
# 300 bp detal time dt1= 4.12s
# 300 bp detal time dt2= 0.04s
# 301 bp detal time dt1= 4.12s
# 301 bp detal time dt2= 0.04s
# 302 bp detal time dt1= 4.12s
# 302 bp detal time dt2= 0.04s
# 303 bp detal time dt1= 4.12s
# 303 bp detal time dt2= 0.04s
# 304 bp detal time dt1= 4.12s
# 304 bp detal time dt2= 0.04s
# 305 bp detal time dt1= 4.12s
# 305 bp detal time dt2= 0.04s
# 306 bp detal time dt1= 4.12s
# 306 bp detal time dt2= 0.04s
# 307 bp detal time dt1= 4.12s
# 307 bp detal time dt2= 0.04s
# 308 bp detal time dt1= 4.12s
# 308 bp detal time dt2= 0.04s
# 309 bp detal time dt1= 4.13s
# 309 bp detal time dt2= 0.04s
# 310 bp detal time dt1= 4.12s
# 310 bp detal time dt2= 0.04s
# 311 bp detal time dt1= 4.13s
# 311 bp detal time dt2= 0.04s
# 312 bp detal time dt1= 4.12s
# 312 bp detal time dt2= 0.04s
# 313 bp detal time dt1= 4.12s
# 313 bp detal time dt2= 0.04s
# 314 bp detal time dt1= 4.12s
# 314 bp detal time dt2= 0.04s
# 315 bp detal time dt1= 4.12s
# 315 bp detal time dt2= 0.04s
# 316 bp detal time dt1= 4.12s
# 316 bp detal time dt2= 0.04s
# 317 bp detal time dt1= 4.15s
# 317 bp detal time dt2= 0.04s
# 318 bp detal time dt1= 4.12s
# 318 bp detal time dt2= 0.04s
# 319 bp detal time dt1= 4.12s
# 319 bp detal time dt2= 0.04s
# 320 bp detal time dt1= 4.12s
# 320 bp detal time dt2= 0.04s
# 321 bp detal time dt1= 4.12s
# 321 bp detal time dt2= 0.04s
# 322 bp detal time dt1= 4.12s
# 322 bp detal time dt2= 0.04s
# 323 bp detal time dt1= 4.12s
# 323 bp detal time dt2= 0.04s
# 324 bp detal time dt1= 4.12s
# 324 bp detal time dt2= 0.04s
# 325 bp detal time dt1= 4.12s
# 325 bp detal time dt2= 0.04s
# 326 bp detal time dt1= 4.12s
# 326 bp detal time dt2= 0.04s
# 327 bp detal time dt1= 4.12s
# 327 bp detal time dt2= 0.04s
# 328 bp detal time dt1= 4.12s
# 328 bp detal time dt2= 0.04s
# 329 bp detal time dt1= 4.12s
# 329 bp detal time dt2= 0.04s
# 330 bp detal time dt1= 4.12s
# 330 bp detal time dt2= 0.04s
# 331 bp detal time dt1= 4.12s
# 331 bp detal time dt2= 0.04s
# 332 bp detal time dt1= 4.12s
# 332 bp detal time dt2= 0.04s
# 333 bp detal time dt1= 4.12s
# 333 bp detal time dt2= 0.04s
# 334 bp detal time dt1= 4.12s
# 334 bp detal time dt2= 0.04s
# 335 bp detal time dt1= 4.13s
# 335 bp detal time dt2= 0.04s
# 336 bp detal time dt1= 4.13s
# 336 bp detal time dt2= 0.04s
# 337 bp detal time dt1= 4.13s
# 337 bp detal time dt2= 0.04s
# 338 bp detal time dt1= 4.12s
# 338 bp detal time dt2= 0.04s
# 339 bp detal time dt1= 4.12s
# 339 bp detal time dt2= 0.04s
# 340 bp detal time dt1= 4.12s
# 340 bp detal time dt2= 0.04s
# 341 bp detal time dt1= 4.12s
# 341 bp detal time dt2= 0.04s
# 342 bp detal time dt1= 4.12s
# 342 bp detal time dt2= 0.04s
# 343 bp detal time dt1= 4.13s
# 343 bp detal time dt2= 0.04s
# 344 bp detal time dt1= 4.12s
# 344 bp detal time dt2= 0.04s
# 345 bp detal time dt1= 4.12s
# 345 bp detal time dt2= 0.04s
# 346 bp detal time dt1= 4.15s
# 346 bp detal time dt2= 0.04s
# 347 bp detal time dt1= 4.13s
# 347 bp detal time dt2= 0.04s
# 348 bp detal time dt1= 4.14s
# 348 bp detal time dt2= 0.04s
# 349 bp detal time dt1= 4.12s
# 349 bp detal time dt2= 0.04s
# 350 bp detal time dt1= 4.12s
# 350 bp detal time dt2= 0.04s
# 351 bp detal time dt1= 4.12s
# 351 bp detal time dt2= 0.04s
# 352 bp detal time dt1= 4.12s
# 352 bp detal time dt2= 0.04s
# 353 bp detal time dt1= 4.12s
# 353 bp detal time dt2= 0.04s
# 354 bp detal time dt1= 4.12s
# 354 bp detal time dt2= 0.04s
# 355 bp detal time dt1= 4.12s
# 355 bp detal time dt2= 0.04s
# 356 bp detal time dt1= 4.12s
# 356 bp detal time dt2= 0.04s
# 357 bp detal time dt1= 4.12s
# 357 bp detal time dt2= 0.04s
# 358 bp detal time dt1= 4.13s
# 358 bp detal time dt2= 0.04s
# 359 bp detal time dt1= 4.12s
# 359 bp detal time dt2= 0.04s
# 360 bp detal time dt1= 4.12s
# 360 bp detal time dt2= 0.04s
# 361 bp detal time dt1= 4.14s
# 361 bp detal time dt2= 0.04s
# 362 bp detal time dt1= 4.16s
# 362 bp detal time dt2= 0.04s
# 363 bp detal time dt1= 4.14s
# 363 bp detal time dt2= 0.04s
# 364 bp detal time dt1= 4.13s
# 364 bp detal time dt2= 0.04s
# 365 bp detal time dt1= 4.13s
# 365 bp detal time dt2= 0.04s
# 366 bp detal time dt1= 4.15s
# 366 bp detal time dt2= 0.04s
# 367 bp detal time dt1= 4.13s
# 367 bp detal time dt2= 0.04s
# 368 bp detal time dt1= 4.13s
# 368 bp detal time dt2= 0.04s
# 369 bp detal time dt1= 4.13s
# 369 bp detal time dt2= 0.04s
# 370 bp detal time dt1= 4.13s
# 370 bp detal time dt2= 0.04s
# 371 bp detal time dt1= 4.14s
# 371 bp detal time dt2= 0.04s
# 372 bp detal time dt1= 4.13s
# 372 bp detal time dt2= 0.04s
# 373 bp detal time dt1= 4.12s
# 373 bp detal time dt2= 0.04s
# 374 bp detal time dt1= 4.16s
# 374 bp detal time dt2= 0.04s
# 375 bp detal time dt1= 4.15s
# 375 bp detal time dt2= 0.04s
# 376 bp detal time dt1= 4.13s
# 376 bp detal time dt2= 0.04s
# 377 bp detal time dt1= 4.12s
# 377 bp detal time dt2= 0.04s
# 378 bp detal time dt1= 4.13s
# 378 bp detal time dt2= 0.04s
# 379 bp detal time dt1= 4.13s
# 379 bp detal time dt2= 0.04s
# 380 bp detal time dt1= 4.13s
# 380 bp detal time dt2= 0.04s
# 381 bp detal time dt1= 4.14s
# 381 bp detal time dt2= 0.04s
# 382 bp detal time dt1= 4.13s
# 382 bp detal time dt2= 0.04s
# 383 bp detal time dt1= 4.13s
# 383 bp detal time dt2= 0.04s
# 384 bp detal time dt1= 4.12s
# 384 bp detal time dt2= 0.04s
# 385 bp detal time dt1= 4.12s
# 385 bp detal time dt2= 0.04s
# 386 bp detal time dt1= 4.16s
# 386 bp detal time dt2= 0.04s
# 387 bp detal time dt1= 4.18s
# 387 bp detal time dt2= 0.04s
# 388 bp detal time dt1= 4.14s
# 388 bp detal time dt2= 0.04s
# 389 bp detal time dt1= 4.16s
# 389 bp detal time dt2= 0.04s
# Training iteration number = 390/781
# 390 bp detal time dt1= 4.12s
# 390 bp detal time dt2= 0.04s
# 391 bp detal time dt1= 4.12s
# 391 bp detal time dt2= 0.04s
# 392 bp detal time dt1= 4.12s
# 392 bp detal time dt2= 0.04s
# 393 bp detal time dt1= 4.13s
# 393 bp detal time dt2= 0.04s
# 394 bp detal time dt1= 4.12s
# 394 bp detal time dt2= 0.04s
# 395 bp detal time dt1= 4.12s
# 395 bp detal time dt2= 0.04s
# 396 bp detal time dt1= 4.13s
# 396 bp detal time dt2= 0.04s
# 397 bp detal time dt1= 4.13s
# 397 bp detal time dt2= 0.04s
# 398 bp detal time dt1= 4.13s
# 398 bp detal time dt2= 0.04s
# 399 bp detal time dt1= 4.12s
# 399 bp detal time dt2= 0.04s
# 400 bp detal time dt1= 4.13s
# 400 bp detal time dt2= 0.04s
# 401 bp detal time dt1= 4.14s
# 401 bp detal time dt2= 0.04s
# 402 bp detal time dt1= 4.13s
# 402 bp detal time dt2= 0.04s
# 403 bp detal time dt1= 4.13s
# 403 bp detal time dt2= 0.04s
# 404 bp detal time dt1= 4.13s
# 404 bp detal time dt2= 0.04s
# 405 bp detal time dt1= 4.13s
# 405 bp detal time dt2= 0.04s
# 406 bp detal time dt1= 4.13s
# 406 bp detal time dt2= 0.04s
# 407 bp detal time dt1= 4.13s
# 407 bp detal time dt2= 0.04s
# 408 bp detal time dt1= 4.12s
# 408 bp detal time dt2= 0.04s
# 409 bp detal time dt1= 4.13s
# 409 bp detal time dt2= 0.04s
# 410 bp detal time dt1= 4.13s
# 410 bp detal time dt2= 0.04s
# 411 bp detal time dt1= 4.13s
# 411 bp detal time dt2= 0.04s
# 412 bp detal time dt1= 4.12s
# 412 bp detal time dt2= 0.04s
# 413 bp detal time dt1= 4.12s
# 413 bp detal time dt2= 0.04s
# 414 bp detal time dt1= 4.12s
# 414 bp detal time dt2= 0.04s
# 415 bp detal time dt1= 4.12s
# 415 bp detal time dt2= 0.04s
# 416 bp detal time dt1= 4.13s
# 416 bp detal time dt2= 0.04s
# 417 bp detal time dt1= 4.13s
# 417 bp detal time dt2= 0.04s
# 418 bp detal time dt1= 4.14s
# 418 bp detal time dt2= 0.04s
# 419 bp detal time dt1= 4.13s
# 419 bp detal time dt2= 0.04s
# 420 bp detal time dt1= 4.12s
# 420 bp detal time dt2= 0.04s
# 421 bp detal time dt1= 4.12s
# 421 bp detal time dt2= 0.04s
# 422 bp detal time dt1= 4.12s
# 422 bp detal time dt2= 0.04s
# 423 bp detal time dt1= 4.12s
# 423 bp detal time dt2= 0.04s
# 424 bp detal time dt1= 4.13s
# 424 bp detal time dt2= 0.04s
# 425 bp detal time dt1= 4.13s
# 425 bp detal time dt2= 0.04s
# 426 bp detal time dt1= 4.13s
# 426 bp detal time dt2= 0.04s
# 427 bp detal time dt1= 4.13s
# 427 bp detal time dt2= 0.04s
# 428 bp detal time dt1= 4.13s
# 428 bp detal time dt2= 0.04s
# 429 bp detal time dt1= 4.13s
# 429 bp detal time dt2= 0.04s
# 430 bp detal time dt1= 4.13s
# 430 bp detal time dt2= 0.04s
# 431 bp detal time dt1= 4.13s
# 431 bp detal time dt2= 0.04s
# 432 bp detal time dt1= 4.14s
# 432 bp detal time dt2= 0.04s
# 433 bp detal time dt1= 4.13s
# 433 bp detal time dt2= 0.04s
# 434 bp detal time dt1= 4.12s
# 434 bp detal time dt2= 0.04s
# 435 bp detal time dt1= 4.12s
# 435 bp detal time dt2= 0.04s
# 436 bp detal time dt1= 4.14s
# 436 bp detal time dt2= 0.04s
# 437 bp detal time dt1= 4.13s
# 437 bp detal time dt2= 0.04s
# 438 bp detal time dt1= 4.12s
# 438 bp detal time dt2= 0.04s
# 439 bp detal time dt1= 4.13s
# 439 bp detal time dt2= 0.04s
# 440 bp detal time dt1= 4.13s
# 440 bp detal time dt2= 0.04s
# 441 bp detal time dt1= 4.13s
# 441 bp detal time dt2= 0.04s
# 442 bp detal time dt1= 4.12s
# 442 bp detal time dt2= 0.04s
# 443 bp detal time dt1= 4.13s
# 443 bp detal time dt2= 0.04s
# 444 bp detal time dt1= 4.13s
# 444 bp detal time dt2= 0.04s
# 445 bp detal time dt1= 4.12s
# 445 bp detal time dt2= 0.04s
# 446 bp detal time dt1= 4.12s
# 446 bp detal time dt2= 0.04s
# 447 bp detal time dt1= 4.12s
# 447 bp detal time dt2= 0.04s
# 448 bp detal time dt1= 4.15s
# 448 bp detal time dt2= 0.04s
# 449 bp detal time dt1= 4.14s
# 449 bp detal time dt2= 0.04s
# 450 bp detal time dt1= 4.13s
# 450 bp detal time dt2= 0.04s
# 451 bp detal time dt1= 4.14s
# 451 bp detal time dt2= 0.04s
# 452 bp detal time dt1= 4.13s
# 452 bp detal time dt2= 0.04s
# 453 bp detal time dt1= 4.13s
# 453 bp detal time dt2= 0.04s
# 454 bp detal time dt1= 4.14s
# 454 bp detal time dt2= 0.04s
# 455 bp detal time dt1= 4.14s
# 455 bp detal time dt2= 0.04s
# 456 bp detal time dt1= 4.13s
# 456 bp detal time dt2= 0.04s
# 457 bp detal time dt1= 4.13s
# 457 bp detal time dt2= 0.04s
# 458 bp detal time dt1= 4.12s
# 458 bp detal time dt2= 0.04s
# 459 bp detal time dt1= 4.12s
# 459 bp detal time dt2= 0.04s
# 460 bp detal time dt1= 4.13s
# 460 bp detal time dt2= 0.04s
# 461 bp detal time dt1= 4.15s
# 461 bp detal time dt2= 0.04s
# 462 bp detal time dt1= 4.13s
# 462 bp detal time dt2= 0.04s
# 463 bp detal time dt1= 4.12s
# 463 bp detal time dt2= 0.04s
# 464 bp detal time dt1= 4.13s
# 464 bp detal time dt2= 0.04s
# 465 bp detal time dt1= 4.12s
# 465 bp detal time dt2= 0.04s
# 466 bp detal time dt1= 4.12s
# 466 bp detal time dt2= 0.04s
# 467 bp detal time dt1= 4.16s
# 467 bp detal time dt2= 0.04s
# 468 bp detal time dt1= 4.16s
# 468 bp detal time dt2= 0.04s
# 469 bp detal time dt1= 4.15s
# 469 bp detal time dt2= 0.04s
# 470 bp detal time dt1= 4.13s
# 470 bp detal time dt2= 0.04s
# 471 bp detal time dt1= 4.13s
# 471 bp detal time dt2= 0.04s
# 472 bp detal time dt1= 4.17s
# 472 bp detal time dt2= 0.04s
# 473 bp detal time dt1= 4.13s
# 473 bp detal time dt2= 0.04s
# 474 bp detal time dt1= 4.12s
# 474 bp detal time dt2= 0.04s
# 475 bp detal time dt1= 4.13s
# 475 bp detal time dt2= 0.04s
# 476 bp detal time dt1= 4.12s
# 476 bp detal time dt2= 0.04s
# 477 bp detal time dt1= 4.14s
# 477 bp detal time dt2= 0.04s
# 478 bp detal time dt1= 4.13s
# 478 bp detal time dt2= 0.04s
# 479 bp detal time dt1= 4.13s
# 479 bp detal time dt2= 0.04s
# 480 bp detal time dt1= 4.13s
# 480 bp detal time dt2= 0.04s
# 481 bp detal time dt1= 4.14s
# 481 bp detal time dt2= 0.04s
# 482 bp detal time dt1= 4.14s
# 482 bp detal time dt2= 0.04s
# 483 bp detal time dt1= 4.13s
# 483 bp detal time dt2= 0.04s
# 484 bp detal time dt1= 4.14s
# 484 bp detal time dt2= 0.04s
# 485 bp detal time dt1= 4.13s
# 485 bp detal time dt2= 0.04s
# 486 bp detal time dt1= 4.14s
# 486 bp detal time dt2= 0.04s
# 487 bp detal time dt1= 4.12s
# 487 bp detal time dt2= 0.04s
# 488 bp detal time dt1= 4.12s
# 488 bp detal time dt2= 0.04s
# 489 bp detal time dt1= 4.12s
# 489 bp detal time dt2= 0.04s
# 490 bp detal time dt1= 4.14s
# 490 bp detal time dt2= 0.04s
# 491 bp detal time dt1= 4.12s
# 491 bp detal time dt2= 0.04s
# 492 bp detal time dt1= 4.12s
# 492 bp detal time dt2= 0.04s
# 493 bp detal time dt1= 4.13s
# 493 bp detal time dt2= 0.04s
# 494 bp detal time dt1= 4.12s
# 494 bp detal time dt2= 0.04s
# 495 bp detal time dt1= 4.12s
# 495 bp detal time dt2= 0.04s
# 496 bp detal time dt1= 4.13s
# 496 bp detal time dt2= 0.04s
# 497 bp detal time dt1= 4.12s
# 497 bp detal time dt2= 0.04s
# 498 bp detal time dt1= 4.13s
# 498 bp detal time dt2= 0.04s
# 499 bp detal time dt1= 4.13s
# 499 bp detal time dt2= 0.04s
# 500 bp detal time dt1= 4.13s
# 500 bp detal time dt2= 0.04s
# 501 bp detal time dt1= 4.13s
# 501 bp detal time dt2= 0.04s
# 502 bp detal time dt1= 4.13s
# 502 bp detal time dt2= 0.04s
# 503 bp detal time dt1= 4.13s
# 503 bp detal time dt2= 0.04s
# 504 bp detal time dt1= 4.13s
# 504 bp detal time dt2= 0.04s
# 505 bp detal time dt1= 4.15s
# 505 bp detal time dt2= 0.04s
# 506 bp detal time dt1= 4.15s
# 506 bp detal time dt2= 0.04s
# 507 bp detal time dt1= 4.13s
# 507 bp detal time dt2= 0.04s
# 508 bp detal time dt1= 4.14s
# 508 bp detal time dt2= 0.04s
# 509 bp detal time dt1= 4.12s
# 509 bp detal time dt2= 0.04s
# 510 bp detal time dt1= 4.12s
# 510 bp detal time dt2= 0.04s
# 511 bp detal time dt1= 4.14s
# 511 bp detal time dt2= 0.04s
# 512 bp detal time dt1= 4.12s
# 512 bp detal time dt2= 0.04s
# 513 bp detal time dt1= 4.15s
# 513 bp detal time dt2= 0.04s
# 514 bp detal time dt1= 4.14s
# 514 bp detal time dt2= 0.04s
# 515 bp detal time dt1= 4.12s
# 515 bp detal time dt2= 0.04s
# 516 bp detal time dt1= 4.14s
# 516 bp detal time dt2= 0.04s
# 517 bp detal time dt1= 4.13s
# 517 bp detal time dt2= 0.04s
# 518 bp detal time dt1= 4.14s
# 518 bp detal time dt2= 0.04s
# 519 bp detal time dt1= 4.12s
# 519 bp detal time dt2= 0.04s
# 520 bp detal time dt1= 4.12s
# 520 bp detal time dt2= 0.04s
# 521 bp detal time dt1= 4.12s
# 521 bp detal time dt2= 0.04s
# 522 bp detal time dt1= 4.12s
# 522 bp detal time dt2= 0.04s
# 523 bp detal time dt1= 4.13s
# 523 bp detal time dt2= 0.04s
# 524 bp detal time dt1= 4.12s
# 524 bp detal time dt2= 0.04s
# 525 bp detal time dt1= 4.14s
# 525 bp detal time dt2= 0.04s
# 526 bp detal time dt1= 4.13s
# 526 bp detal time dt2= 0.04s
# 527 bp detal time dt1= 4.12s
# 527 bp detal time dt2= 0.04s
# 528 bp detal time dt1= 4.12s
# 528 bp detal time dt2= 0.04s
# 529 bp detal time dt1= 4.12s
# 529 bp detal time dt2= 0.04s
# 530 bp detal time dt1= 4.12s
# 530 bp detal time dt2= 0.04s
# 531 bp detal time dt1= 4.14s
# 531 bp detal time dt2= 0.04s
# 532 bp detal time dt1= 4.12s
# 532 bp detal time dt2= 0.04s
# 533 bp detal time dt1= 4.13s
# 533 bp detal time dt2= 0.04s
# 534 bp detal time dt1= 4.15s
# 534 bp detal time dt2= 0.04s
# 535 bp detal time dt1= 4.13s
# 535 bp detal time dt2= 0.04s
# 536 bp detal time dt1= 4.15s
# 536 bp detal time dt2= 0.04s
# 537 bp detal time dt1= 4.14s
# 537 bp detal time dt2= 0.04s
# 538 bp detal time dt1= 4.13s
# 538 bp detal time dt2= 0.04s
# 539 bp detal time dt1= 4.13s
# 539 bp detal time dt2= 0.04s
# 540 bp detal time dt1= 4.14s
# 540 bp detal time dt2= 0.04s
# 541 bp detal time dt1= 4.15s
# 541 bp detal time dt2= 0.04s
# 542 bp detal time dt1= 4.14s
# 542 bp detal time dt2= 0.04s
# 543 bp detal time dt1= 4.13s
# 543 bp detal time dt2= 0.04s
# 544 bp detal time dt1= 4.12s
# 544 bp detal time dt2= 0.04s
# 545 bp detal time dt1= 4.12s
# 545 bp detal time dt2= 0.04s
# 546 bp detal time dt1= 4.15s
# 546 bp detal time dt2= 0.04s
# 547 bp detal time dt1= 4.14s
# 547 bp detal time dt2= 0.04s
# 548 bp detal time dt1= 4.14s
# 548 bp detal time dt2= 0.04s
# 549 bp detal time dt1= 4.14s
# 549 bp detal time dt2= 0.04s
# 550 bp detal time dt1= 4.14s
# 550 bp detal time dt2= 0.04s
# 551 bp detal time dt1= 4.13s
# 551 bp detal time dt2= 0.04s
# 552 bp detal time dt1= 4.12s
# 552 bp detal time dt2= 0.04s
# 553 bp detal time dt1= 4.12s
# 553 bp detal time dt2= 0.04s
# 554 bp detal time dt1= 4.13s
# 554 bp detal time dt2= 0.04s
# 555 bp detal time dt1= 4.13s
# 555 bp detal time dt2= 0.04s
# 556 bp detal time dt1= 4.13s
# 556 bp detal time dt2= 0.04s
# 557 bp detal time dt1= 4.13s
# 557 bp detal time dt2= 0.04s
# 558 bp detal time dt1= 4.13s
# 558 bp detal time dt2= 0.04s
# 559 bp detal time dt1= 4.13s
# 559 bp detal time dt2= 0.04s
# 560 bp detal time dt1= 4.14s
# 560 bp detal time dt2= 0.04s
# 561 bp detal time dt1= 4.14s
# 561 bp detal time dt2= 0.04s
# 562 bp detal time dt1= 4.13s
# 562 bp detal time dt2= 0.04s
# 563 bp detal time dt1= 4.14s
# 563 bp detal time dt2= 0.04s
# 564 bp detal time dt1= 4.13s
# 564 bp detal time dt2= 0.04s
# 565 bp detal time dt1= 4.12s
# 565 bp detal time dt2= 0.04s
# 566 bp detal time dt1= 4.13s
# 566 bp detal time dt2= 0.04s
# 567 bp detal time dt1= 4.13s
# 567 bp detal time dt2= 0.04s
# 568 bp detal time dt1= 4.13s
# 568 bp detal time dt2= 0.04s
# 569 bp detal time dt1= 4.13s
# 569 bp detal time dt2= 0.04s
# 570 bp detal time dt1= 4.14s
# 570 bp detal time dt2= 0.04s
# 571 bp detal time dt1= 4.17s
# 571 bp detal time dt2= 0.04s
# 572 bp detal time dt1= 4.13s
# 572 bp detal time dt2= 0.04s
# 573 bp detal time dt1= 4.13s
# 573 bp detal time dt2= 0.04s
# 574 bp detal time dt1= 4.14s
# 574 bp detal time dt2= 0.04s
# 575 bp detal time dt1= 4.14s
# 575 bp detal time dt2= 0.04s
# 576 bp detal time dt1= 4.15s
# 576 bp detal time dt2= 0.04s
# 577 bp detal time dt1= 4.14s
# 577 bp detal time dt2= 0.04s
# 578 bp detal time dt1= 4.13s
# 578 bp detal time dt2= 0.04s
# 579 bp detal time dt1= 4.12s
# 579 bp detal time dt2= 0.04s
# 580 bp detal time dt1= 4.17s
# 580 bp detal time dt2= 0.04s
# 581 bp detal time dt1= 4.14s
# 581 bp detal time dt2= 0.04s
# 582 bp detal time dt1= 4.13s
# 582 bp detal time dt2= 0.04s
# 583 bp detal time dt1= 4.13s
# 583 bp detal time dt2= 0.04s
# 584 bp detal time dt1= 4.15s
# 584 bp detal time dt2= 0.04s
# 585 bp detal time dt1= 4.16s
# 585 bp detal time dt2= 0.04s
# 586 bp detal time dt1= 4.15s
# 586 bp detal time dt2= 0.04s
# 587 bp detal time dt1= 4.12s
# 587 bp detal time dt2= 0.04s
# 588 bp detal time dt1= 4.12s
# 588 bp detal time dt2= 0.04s
# 589 bp detal time dt1= 4.14s
# 589 bp detal time dt2= 0.04s
# 590 bp detal time dt1= 4.16s
# 590 bp detal time dt2= 0.04s
# 591 bp detal time dt1= 4.15s
# 591 bp detal time dt2= 0.04s
# 592 bp detal time dt1= 4.14s
# 592 bp detal time dt2= 0.04s
# 593 bp detal time dt1= 4.14s
# 593 bp detal time dt2= 0.04s
# 594 bp detal time dt1= 4.15s
# 594 bp detal time dt2= 0.04s
# 595 bp detal time dt1= 4.13s
# 595 bp detal time dt2= 0.04s
# 596 bp detal time dt1= 4.12s
# 596 bp detal time dt2= 0.04s
# 597 bp detal time dt1= 4.13s
# 597 bp detal time dt2= 0.04s
# 598 bp detal time dt1= 4.13s
# 598 bp detal time dt2= 0.04s
# 599 bp detal time dt1= 4.13s
# 599 bp detal time dt2= 0.04s
# 600 bp detal time dt1= 4.13s
# 600 bp detal time dt2= 0.04s
# 601 bp detal time dt1= 4.12s
# 601 bp detal time dt2= 0.04s
# 602 bp detal time dt1= 4.13s
# 602 bp detal time dt2= 0.04s
# 603 bp detal time dt1= 4.19s
# 603 bp detal time dt2= 0.04s
# 604 bp detal time dt1= 4.13s
# 604 bp detal time dt2= 0.04s
# 605 bp detal time dt1= 4.14s
# 605 bp detal time dt2= 0.04s
# 606 bp detal time dt1= 4.12s
# 606 bp detal time dt2= 0.04s
# 607 bp detal time dt1= 4.12s
# 607 bp detal time dt2= 0.04s
# 608 bp detal time dt1= 4.12s
# 608 bp detal time dt2= 0.04s
# 609 bp detal time dt1= 4.13s
# 609 bp detal time dt2= 0.04s
# 610 bp detal time dt1= 4.15s
# 610 bp detal time dt2= 0.04s
# 611 bp detal time dt1= 4.16s
# 611 bp detal time dt2= 0.04s
# 612 bp detal time dt1= 4.16s
# 612 bp detal time dt2= 0.04s
# 613 bp detal time dt1= 4.14s
# 613 bp detal time dt2= 0.04s
# 614 bp detal time dt1= 4.13s
# 614 bp detal time dt2= 0.04s
# 615 bp detal time dt1= 4.15s
# 615 bp detal time dt2= 0.04s
# 616 bp detal time dt1= 4.13s
# 616 bp detal time dt2= 0.04s
# 617 bp detal time dt1= 4.13s
# 617 bp detal time dt2= 0.04s
# 618 bp detal time dt1= 4.13s
# 618 bp detal time dt2= 0.04s
# 619 bp detal time dt1= 4.14s
# 619 bp detal time dt2= 0.04s
# 620 bp detal time dt1= 4.14s
# 620 bp detal time dt2= 0.04s
# 621 bp detal time dt1= 4.14s
# 621 bp detal time dt2= 0.04s
# 622 bp detal time dt1= 4.14s
# 622 bp detal time dt2= 0.04s
# 623 bp detal time dt1= 4.13s
# 623 bp detal time dt2= 0.04s
# 624 bp detal time dt1= 4.13s
# 624 bp detal time dt2= 0.04s
# 625 bp detal time dt1= 4.17s
# 625 bp detal time dt2= 0.04s
# 626 bp detal time dt1= 4.14s
# 626 bp detal time dt2= 0.04s
# 627 bp detal time dt1= 4.14s
# 627 bp detal time dt2= 0.04s
# 628 bp detal time dt1= 4.13s
# 628 bp detal time dt2= 0.04s
# 629 bp detal time dt1= 4.13s
# 629 bp detal time dt2= 0.04s
# 630 bp detal time dt1= 4.13s
# 630 bp detal time dt2= 0.04s
# 631 bp detal time dt1= 4.13s
# 631 bp detal time dt2= 0.04s
# 632 bp detal time dt1= 4.14s
# 632 bp detal time dt2= 0.04s
# 633 bp detal time dt1= 4.17s
# 633 bp detal time dt2= 0.04s
# 634 bp detal time dt1= 4.14s
# 634 bp detal time dt2= 0.04s
# 635 bp detal time dt1= 4.16s
# 635 bp detal time dt2= 0.04s
# 636 bp detal time dt1= 4.16s
# 636 bp detal time dt2= 0.04s
# 637 bp detal time dt1= 4.15s
# 637 bp detal time dt2= 0.04s
# 638 bp detal time dt1= 4.15s
# 638 bp detal time dt2= 0.04s
# 639 bp detal time dt1= 4.16s
# 639 bp detal time dt2= 0.04s
# 640 bp detal time dt1= 4.13s
# 640 bp detal time dt2= 0.04s
# 641 bp detal time dt1= 4.13s
# 641 bp detal time dt2= 0.04s
# 642 bp detal time dt1= 4.13s
# 642 bp detal time dt2= 0.04s
# 643 bp detal time dt1= 4.13s
# 643 bp detal time dt2= 0.04s
# 644 bp detal time dt1= 4.15s
# 644 bp detal time dt2= 0.04s
# 645 bp detal time dt1= 4.13s
# 645 bp detal time dt2= 0.04s
# 646 bp detal time dt1= 4.13s
# 646 bp detal time dt2= 0.04s
# 647 bp detal time dt1= 4.13s
# 647 bp detal time dt2= 0.04s
# 648 bp detal time dt1= 4.13s
# 648 bp detal time dt2= 0.04s
# 649 bp detal time dt1= 4.15s
# 649 bp detal time dt2= 0.04s
# 650 bp detal time dt1= 4.14s
# 650 bp detal time dt2= 0.04s
# 651 bp detal time dt1= 4.14s
# 651 bp detal time dt2= 0.04s
# 652 bp detal time dt1= 4.14s
# 652 bp detal time dt2= 0.04s
# 653 bp detal time dt1= 4.13s
# 653 bp detal time dt2= 0.04s
# 654 bp detal time dt1= 4.13s
# 654 bp detal time dt2= 0.04s
# 655 bp detal time dt1= 4.14s
# 655 bp detal time dt2= 0.04s
# 656 bp detal time dt1= 4.13s
# 656 bp detal time dt2= 0.04s
# 657 bp detal time dt1= 4.13s
# 657 bp detal time dt2= 0.04s
# 658 bp detal time dt1= 4.13s
# 658 bp detal time dt2= 0.04s
# 659 bp detal time dt1= 4.14s
# 659 bp detal time dt2= 0.04s
# 660 bp detal time dt1= 4.13s
# 660 bp detal time dt2= 0.04s
# 661 bp detal time dt1= 4.13s
# 661 bp detal time dt2= 0.04s
# 662 bp detal time dt1= 4.14s
# 662 bp detal time dt2= 0.04s
# 663 bp detal time dt1= 4.15s
# 663 bp detal time dt2= 0.04s
# 664 bp detal time dt1= 4.15s
# 664 bp detal time dt2= 0.04s
# 665 bp detal time dt1= 4.13s
# 665 bp detal time dt2= 0.04s
# 666 bp detal time dt1= 4.16s
# 666 bp detal time dt2= 0.04s
# 667 bp detal time dt1= 4.13s
# 667 bp detal time dt2= 0.04s
# 668 bp detal time dt1= 4.13s
# 668 bp detal time dt2= 0.04s
# 669 bp detal time dt1= 4.14s
# 669 bp detal time dt2= 0.04s
# 670 bp detal time dt1= 4.14s
# 670 bp detal time dt2= 0.04s
# 671 bp detal time dt1= 4.13s
# 671 bp detal time dt2= 0.04s
# 672 bp detal time dt1= 4.13s
# 672 bp detal time dt2= 0.04s
# 673 bp detal time dt1= 4.13s
# 673 bp detal time dt2= 0.04s
# 674 bp detal time dt1= 4.13s
# 674 bp detal time dt2= 0.04s
# 675 bp detal time dt1= 4.13s
# 675 bp detal time dt2= 0.04s
# 676 bp detal time dt1= 4.13s
# 676 bp detal time dt2= 0.04s
# 677 bp detal time dt1= 4.13s
# 677 bp detal time dt2= 0.04s
# 678 bp detal time dt1= 4.14s
# 678 bp detal time dt2= 0.04s
# 679 bp detal time dt1= 4.13s
# 679 bp detal time dt2= 0.04s
# 680 bp detal time dt1= 4.13s
# 680 bp detal time dt2= 0.04s
# 681 bp detal time dt1= 4.15s
# 681 bp detal time dt2= 0.04s
# 682 bp detal time dt1= 4.13s
# 682 bp detal time dt2= 0.04s
# 683 bp detal time dt1= 4.14s
# 683 bp detal time dt2= 0.04s
# 684 bp detal time dt1= 4.14s
# 684 bp detal time dt2= 0.04s
# 685 bp detal time dt1= 4.15s
# 685 bp detal time dt2= 0.04s
# 686 bp detal time dt1= 4.13s
# 686 bp detal time dt2= 0.04s
# 687 bp detal time dt1= 4.13s
# 687 bp detal time dt2= 0.04s
# 688 bp detal time dt1= 4.14s
# 688 bp detal time dt2= 0.04s
# 689 bp detal time dt1= 4.13s
# 689 bp detal time dt2= 0.04s
# 690 bp detal time dt1= 4.13s
# 690 bp detal time dt2= 0.04s
# 691 bp detal time dt1= 4.14s
# 691 bp detal time dt2= 0.04s
# 692 bp detal time dt1= 4.13s
# 692 bp detal time dt2= 0.04s
# 693 bp detal time dt1= 4.13s
# 693 bp detal time dt2= 0.04s
# 694 bp detal time dt1= 4.13s
# 694 bp detal time dt2= 0.04s
# 695 bp detal time dt1= 4.13s
# 695 bp detal time dt2= 0.04s
# 696 bp detal time dt1= 4.13s
# 696 bp detal time dt2= 0.04s
# 697 bp detal time dt1= 4.13s
# 697 bp detal time dt2= 0.04s
# 698 bp detal time dt1= 4.13s
# 698 bp detal time dt2= 0.04s
# 699 bp detal time dt1= 4.13s
# 699 bp detal time dt2= 0.04s
# 700 bp detal time dt1= 4.13s
# 700 bp detal time dt2= 0.04s
# 701 bp detal time dt1= 4.13s
# 701 bp detal time dt2= 0.04s
# 702 bp detal time dt1= 4.13s
# 702 bp detal time dt2= 0.04s
# 703 bp detal time dt1= 4.13s
# 703 bp detal time dt2= 0.04s
# 704 bp detal time dt1= 4.13s
# 704 bp detal time dt2= 0.04s
# 705 bp detal time dt1= 4.16s
# 705 bp detal time dt2= 0.04s
# 706 bp detal time dt1= 4.15s
# 706 bp detal time dt2= 0.04s
# 707 bp detal time dt1= 4.14s
# 707 bp detal time dt2= 0.04s
# 708 bp detal time dt1= 4.13s
# 708 bp detal time dt2= 0.04s
# 709 bp detal time dt1= 4.13s
# 709 bp detal time dt2= 0.04s
# 710 bp detal time dt1= 4.13s
# 710 bp detal time dt2= 0.04s
# 711 bp detal time dt1= 4.13s
# 711 bp detal time dt2= 0.04s
# 712 bp detal time dt1= 4.13s
# 712 bp detal time dt2= 0.04s
# 713 bp detal time dt1= 4.13s
# 713 bp detal time dt2= 0.04s
# 714 bp detal time dt1= 4.13s
# 714 bp detal time dt2= 0.04s
# 715 bp detal time dt1= 4.13s
# 715 bp detal time dt2= 0.04s
# 716 bp detal time dt1= 4.13s
# 716 bp detal time dt2= 0.04s
# 717 bp detal time dt1= 4.13s
# 717 bp detal time dt2= 0.04s
# 718 bp detal time dt1= 4.13s
# 718 bp detal time dt2= 0.04s
# 719 bp detal time dt1= 4.13s
# 719 bp detal time dt2= 0.04s
# 720 bp detal time dt1= 4.15s
# 720 bp detal time dt2= 0.04s
# 721 bp detal time dt1= 4.13s
# 721 bp detal time dt2= 0.04s
# 722 bp detal time dt1= 4.13s
# 722 bp detal time dt2= 0.04s
# 723 bp detal time dt1= 4.15s
# 723 bp detal time dt2= 0.04s
# 724 bp detal time dt1= 4.13s
# 724 bp detal time dt2= 0.04s
# 725 bp detal time dt1= 4.13s
# 725 bp detal time dt2= 0.04s
# 726 bp detal time dt1= 4.12s
# 726 bp detal time dt2= 0.04s
# 727 bp detal time dt1= 4.13s
# 727 bp detal time dt2= 0.04s
# 728 bp detal time dt1= 4.13s
# 728 bp detal time dt2= 0.04s
# 729 bp detal time dt1= 4.13s
# 729 bp detal time dt2= 0.04s
# 730 bp detal time dt1= 4.13s
# 730 bp detal time dt2= 0.04s
# 731 bp detal time dt1= 4.15s
# 731 bp detal time dt2= 0.04s
# 732 bp detal time dt1= 4.14s
# 732 bp detal time dt2= 0.04s
# 733 bp detal time dt1= 4.13s
# 733 bp detal time dt2= 0.04s
# 734 bp detal time dt1= 4.13s
# 734 bp detal time dt2= 0.04s
# 735 bp detal time dt1= 4.14s
# 735 bp detal time dt2= 0.04s
# 736 bp detal time dt1= 4.13s
# 736 bp detal time dt2= 0.04s
# 737 bp detal time dt1= 4.13s
# 737 bp detal time dt2= 0.04s
# 738 bp detal time dt1= 4.14s
# 738 bp detal time dt2= 0.04s
# 739 bp detal time dt1= 4.13s
# 739 bp detal time dt2= 0.04s
# 740 bp detal time dt1= 4.13s
# 740 bp detal time dt2= 0.04s
# 741 bp detal time dt1= 4.13s
# 741 bp detal time dt2= 0.04s
# 742 bp detal time dt1= 4.14s
# 742 bp detal time dt2= 0.04s
# 743 bp detal time dt1= 4.13s
# 743 bp detal time dt2= 0.04s
# 744 bp detal time dt1= 4.14s
# 744 bp detal time dt2= 0.04s
# 745 bp detal time dt1= 4.13s
# 745 bp detal time dt2= 0.04s
# 746 bp detal time dt1= 4.13s
# 746 bp detal time dt2= 0.04s
# 747 bp detal time dt1= 4.13s
# 747 bp detal time dt2= 0.04s
# 748 bp detal time dt1= 4.14s
# 748 bp detal time dt2= 0.04s
# 749 bp detal time dt1= 4.15s
# 749 bp detal time dt2= 0.04s
# 750 bp detal time dt1= 4.13s
# 750 bp detal time dt2= 0.04s
# 751 bp detal time dt1= 4.13s
# 751 bp detal time dt2= 0.04s
# 752 bp detal time dt1= 4.14s
# 752 bp detal time dt2= 0.04s
# 753 bp detal time dt1= 4.14s
# 753 bp detal time dt2= 0.04s
# 754 bp detal time dt1= 4.14s
# 754 bp detal time dt2= 0.04s
# 755 bp detal time dt1= 4.14s
# 755 bp detal time dt2= 0.04s
# 756 bp detal time dt1= 4.14s
# 756 bp detal time dt2= 0.04s
# 757 bp detal time dt1= 4.14s
# 757 bp detal time dt2= 0.04s
# 758 bp detal time dt1= 4.13s
# 758 bp detal time dt2= 0.04s
# 759 bp detal time dt1= 4.13s
# 759 bp detal time dt2= 0.04s
# 760 bp detal time dt1= 4.13s
# 760 bp detal time dt2= 0.04s
# 761 bp detal time dt1= 4.13s
# 761 bp detal time dt2= 0.04s
# 762 bp detal time dt1= 4.13s
# 762 bp detal time dt2= 0.04s
# 763 bp detal time dt1= 4.13s
# 763 bp detal time dt2= 0.04s
# 764 bp detal time dt1= 4.13s
# 764 bp detal time dt2= 0.04s
# 765 bp detal time dt1= 4.13s
# 765 bp detal time dt2= 0.04s
# 766 bp detal time dt1= 4.13s
# 766 bp detal time dt2= 0.04s
# 767 bp detal time dt1= 4.14s
# 767 bp detal time dt2= 0.04s
# 768 bp detal time dt1= 4.13s
# 768 bp detal time dt2= 0.04s
# 769 bp detal time dt1= 4.13s
# 769 bp detal time dt2= 0.04s
# 770 bp detal time dt1= 4.13s
# 770 bp detal time dt2= 0.04s
# 771 bp detal time dt1= 4.14s
# 771 bp detal time dt2= 0.04s
# 772 bp detal time dt1= 4.13s
# 772 bp detal time dt2= 0.04s
# 773 bp detal time dt1= 4.13s
# 773 bp detal time dt2= 0.04s
# 774 bp detal time dt1= 4.13s
# 774 bp detal time dt2= 0.04s
# 775 bp detal time dt1= 4.13s
# 775 bp detal time dt2= 0.04s
# 776 bp detal time dt1= 4.13s
# 776 bp detal time dt2= 0.04s
# 777 bp detal time dt1= 4.15s
# 777 bp detal time dt2= 0.04s
# 778 bp detal time dt1= 4.15s
# 778 bp detal time dt2= 0.04s
# 779 bp detal time dt1= 4.14s
# 779 bp detal time dt2= 0.04s
# Training iteration number = 780/781
# 780 bp detal time dt1= 4.15s
# 780 bp detal time dt2= 0.04s
# 780 bp detal time dt3= 0.00s
# X.shape= (100, 100, 1, 28, 28)
# Valid percent is : 68.90%
# Valid_train percent is : 66.85%
# ============================================================
# hyperparams_test runing iteration = 2/8
# hyperparams_test runing: lri = 1.750e-03
# Hyperparams_test: L2_normalize_k0 = 2.39e-01
# Hyperparams_test: L2_normalize_gama0 = 7.07e-01
# Hyperparams_test: L2_normalize_beta0 = 0.00e+00
# Hyperparams_test: L2_normalize_k1 = 1.66e-01
# Hyperparams_test: L2_normalize_gama1 = 7.07e-01
# Hyperparams_test: L2_normalize_beta1 = 0.00e+00
# Hyperparams_test: L2_normalize_k2 = 1.54e-01
# Hyperparams_test: L2_normalize_gama2 = 7.07e-01
# Hyperparams_test: L2_normalize_beta2 = 0.00e+00
# Hyperparams_test: L2_normalize_w3 = 7.99e-03
# Train input X.shape=(781, 64, 1, 28, 28), LAB.shape=(781, 64, 1, 1)
# Training bath running ...
# Training iteration number = 0/781
# 0 bp detal time dt1= 4.22s
# 0 bp detal time dt2= 0.03s
# 1 bp detal time dt1= 4.16s
# 1 bp detal time dt2= 0.03s
# 2 bp detal time dt1= 4.18s
# 2 bp detal time dt2= 0.04s
# 3 bp detal time dt1= 4.17s
# 3 bp detal time dt2= 0.04s
# 4 bp detal time dt1= 4.19s
# 4 bp detal time dt2= 0.04s
# 5 bp detal time dt1= 4.19s
# 5 bp detal time dt2= 0.04s
# 6 bp detal time dt1= 4.17s
# 6 bp detal time dt2= 0.03s
# 7 bp detal time dt1= 4.18s
# 7 bp detal time dt2= 0.03s
# 8 bp detal time dt1= 4.18s
# 8 bp detal time dt2= 0.04s
# 9 bp detal time dt1= 4.16s
# ...
# 131 bp detal time dt1= 4.13s
# 131 bp detal time dt2= 0.04s
# 132 bp detal time dt1= 4.14s
# 132 bp detal time dt2= 0.04s
# 133 bp detal time dt1= 4.13s
# 133 bp detal time dt2= 0.03s
# 134 bp detal time dt1= 4.14s
# 134 bp detal time dt2= 0.03s
# 135 bp detal time dt1= 4.12s
# 135 bp detal time dt2= 0.03s
# 136 bp detal time dt1= 4.13s
# 136 bp detal time dt2= 0.03s
# 137 bp detal time dt1= 4.13s
# 137 bp detal time dt2= 0.04s
# 138 bp detal time dt1= 4.81s
# 138 bp detal time dt2= 0.05s
# 139 bp detal time dt1= 5.66s
# 139 bp detal time dt2= 0.04s
# 140 bp detal time dt1= 5.93s
# 140 bp detal time dt2= 0.05s
# 141 bp detal time dt1= 6.22s
# 141 bp detal time dt2= 0.04s
# 142 bp detal time dt1= 5.70s
# 142 bp detal time dt2= 0.05s
# 143 bp detal time dt1= 6.95s
# 143 bp detal time dt2= 0.05s
# 144 bp detal time dt1= 6.06s
# 144 bp detal time dt2= 0.04s
# 145 bp detal time dt1= 5.71s
# 145 bp detal time dt2= 0.04s
# 146 bp detal time dt1= 5.58s
# 146 bp detal time dt2= 0.04s
# 147 bp detal time dt1= 5.68s
# 147 bp detal time dt2= 0.04s
# 148 bp detal time dt1= 5.66s
# 148 bp detal time dt2= 0.04s
# 149 bp detal time dt1= 5.50s
# 149 bp detal time dt2= 0.04s
# 150 bp detal time dt1= 5.69s
# 150 bp detal time dt2= 0.04s
# 151 bp detal time dt1= 5.63s
# 151 bp detal time dt2= 0.04s
# 152 bp detal time dt1= 5.48s
# 152 bp detal time dt2= 0.03s
# 153 bp detal time dt1= 5.63s
# 153 bp detal time dt2= 0.04s
# 154 bp detal time dt1= 5.60s
# 154 bp detal time dt2= 0.04s
# 155 bp detal time dt1= 5.48s
# 155 bp detal time dt2= 0.03s
# 156 bp detal time dt1= 5.68s
# 156 bp detal time dt2= 0.04s
# 157 bp detal time dt1= 5.61s
# 157 bp detal time dt2= 0.04s
# 158 bp detal time dt1= 5.47s
# 158 bp detal time dt2= 0.03s
# 159 bp detal time dt1= 5.66s
# 159 bp detal time dt2= 0.04s
# 160 bp detal time dt1= 5.58s
# 160 bp detal time dt2= 0.04s
# 161 bp detal time dt1= 5.46s
# 161 bp detal time dt2= 0.04s
# 162 bp detal time dt1= 5.66s
# 162 bp detal time dt2= 0.04s
# 163 bp detal time dt1= 5.61s
# 163 bp detal time dt2= 0.04s
# 164 bp detal time dt1= 5.49s
# 164 bp detal time dt2= 0.03s
# 165 bp detal time dt1= 5.76s
# 165 bp detal time dt2= 0.04s
# 166 bp detal time dt1= 5.85s
# 166 bp detal time dt2= 0.04s
# 167 bp detal time dt1= 6.16s
# 167 bp detal time dt2= 0.05s
# 168 bp detal time dt1= 6.29s
# 168 bp detal time dt2= 0.04s
# 169 bp detal time dt1= 5.88s
# 169 bp detal time dt2= 0.04s
# 170 bp detal time dt1= 7.79s
# 170 bp detal time dt2= 0.04s
# 171 bp detal time dt1= 5.94s
# 171 bp detal time dt2= 0.04s
# 172 bp detal time dt1= 5.70s
# 172 bp detal time dt2= 0.04s
# 173 bp detal time dt1= 5.64s
# 173 bp detal time dt2= 0.03s
# 174 bp detal time dt1= 5.74s
# 174 bp detal time dt2= 0.04s
# 175 bp detal time dt1= 5.74s
# 175 bp detal time dt2= 0.04s
# 176 bp detal time dt1= 5.93s
# 176 bp detal time dt2= 0.04s
# 177 bp detal time dt1= 5.98s
# 177 bp detal time dt2= 0.04s
# 178 bp detal time dt1= 6.01s
# 178 bp detal time dt2= 0.04s
# 179 bp detal time dt1= 5.78s
# 179 bp detal time dt2= 0.04s
# 180 bp detal time dt1= 5.95s
# 180 bp detal time dt2= 0.04s
# 181 bp detal time dt1= 5.98s
# 181 bp detal time dt2= 0.04s
# 182 bp detal time dt1= 5.79s
# 182 bp detal time dt2= 0.04s
# 183 bp detal time dt1= 5.94s
# 183 bp detal time dt2= 0.04s
# 184 bp detal time dt1= 5.91s
# 184 bp detal time dt2= 0.04s
# 185 bp detal time dt1= 5.74s
# 185 bp detal time dt2= 0.04s
# 186 bp detal time dt1= 5.95s
# 186 bp detal time dt2= 0.04s
# 187 bp detal time dt1= 6.04s
# 187 bp detal time dt2= 0.04s
# 188 bp detal time dt1= 5.94s
# 188 bp detal time dt2= 0.04s
# 189 bp detal time dt1= 6.12s
# 189 bp detal time dt2= 0.04s
# 190 bp detal time dt1= 6.04s
# 190 bp detal time dt2= 0.04s
# 191 bp detal time dt1= 6.00s
# 191 bp detal time dt2= 0.04s
# 192 bp detal time dt1= 6.19s
# 192 bp detal time dt2= 0.04s
# 193 bp detal time dt1= 6.14s
# 193 bp detal time dt2= 0.04s
# 194 bp detal time dt1= 6.33s
# 194 bp detal time dt2= 0.04s
# 195 bp detal time dt1= 7.58s
# 195 bp detal time dt2= 0.04s
# 196 bp detal time dt1= 6.24s
# 196 bp detal time dt2= 0.04s
# 197 bp detal time dt1= 7.60s
# 197 bp detal time dt2= 0.04s
# 198 bp detal time dt1= 6.11s
# 198 bp detal time dt2= 0.04s
# 199 bp detal time dt1= 6.04s
# 199 bp detal time dt2= 0.04s
# 200 bp detal time dt1= 6.04s
# 200 bp detal time dt2= 0.04s
# 201 bp detal time dt1= 5.99s
# 201 bp detal time dt2= 0.04s
# 202 bp detal time dt1= 6.01s
# 202 bp detal time dt2= 0.04s
# 203 bp detal time dt1= 5.89s
# 203 bp detal time dt2= 0.04s
# 204 bp detal time dt1= 6.08s
# 204 bp detal time dt2= 0.04s
# 205 bp detal time dt1= 6.04s
# 205 bp detal time dt2= 0.04s
# 206 bp detal time dt1= 5.84s
# 206 bp detal time dt2= 0.04s
# 207 bp detal time dt1= 6.02s
# 207 bp detal time dt2= 0.04s
# 208 bp detal time dt1= 5.96s
# 208 bp detal time dt2= 0.04s
# 209 bp detal time dt1= 5.83s
# 209 bp detal time dt2= 0.04s
# 210 bp detal time dt1= 6.04s
# 210 bp detal time dt2= 0.04s
# 211 bp detal time dt1= 5.97s
# 211 bp detal time dt2= 0.04s
# 212 bp detal time dt1= 5.61s
# 212 bp detal time dt2= 0.04s
# 213 bp detal time dt1= 5.69s
# 213 bp detal time dt2= 0.04s
# 214 bp detal time dt1= 5.66s
# 214 bp detal time dt2= 0.04s
# 215 bp detal time dt1= 5.50s
# 215 bp detal time dt2= 0.03s
# 216 bp detal time dt1= 5.70s
# 216 bp detal time dt2= 0.04s
# 217 bp detal time dt1= 5.66s
# 217 bp detal time dt2= 0.04s
# 218 bp detal time dt1= 5.51s
# 218 bp detal time dt2= 0.04s
# 219 bp detal time dt1= 5.69s
# 219 bp detal time dt2= 0.04s
# 220 bp detal time dt1= 5.64s
# 220 bp detal time dt2= 0.04s
# 221 bp detal time dt1= 5.52s
# 221 bp detal time dt2= 0.04s
# 222 bp detal time dt1= 5.69s
# 222 bp detal time dt2= 0.04s
# 223 bp detal time dt1= 5.64s
# 223 bp detal time dt2= 0.04s
# 224 bp detal time dt1= 5.51s
# 224 bp detal time dt2= 0.04s
# 225 bp detal time dt1= 5.67s
# 225 bp detal time dt2= 0.04s
# 226 bp detal time dt1= 5.65s
# 226 bp detal time dt2= 0.04s
# 227 bp detal time dt1= 5.48s
# 227 bp detal time dt2= 0.03s
# 228 bp detal time dt1= 5.64s
# 228 bp detal time dt2= 0.04s
# 229 bp detal time dt1= 5.62s
# 229 bp detal time dt2= 0.04s
# 230 bp detal time dt1= 5.45s
# 230 bp detal time dt2= 0.03s
# 231 bp detal time dt1= 5.65s
# 231 bp detal time dt2= 0.04s
# 232 bp detal time dt1= 5.60s
# 232 bp detal time dt2= 0.04s
# 233 bp detal time dt1= 5.46s
# 233 bp detal time dt2= 0.03s
# 234 bp detal time dt1= 5.66s
# 234 bp detal time dt2= 0.04s
# 235 bp detal time dt1= 5.60s
# 235 bp detal time dt2= 0.04s
# 236 bp detal time dt1= 5.45s
# 236 bp detal time dt2= 0.04s
# 237 bp detal time dt1= 5.61s
# 237 bp detal time dt2= 0.04s
# 238 bp detal time dt1= 5.60s
# 238 bp detal time dt2= 0.04s
# 239 bp detal time dt1= 5.45s
# 239 bp detal time dt2= 0.03s
# 240 bp detal time dt1= 5.61s
# 240 bp detal time dt2= 0.04s
# 241 bp detal time dt1= 5.61s
# 241 bp detal time dt2= 0.04s
# 242 bp detal time dt1= 5.46s
# 242 bp detal time dt2= 0.04s
# 243 bp detal time dt1= 5.62s
# 243 bp detal time dt2= 0.04s
# 244 bp detal time dt1= 5.57s
# 244 bp detal time dt2= 0.04s
# 245 bp detal time dt1= 5.45s
# 245 bp detal time dt2= 0.04s
# 246 bp detal time dt1= 5.63s
# 246 bp detal time dt2= 0.04s
# 247 bp detal time dt1= 5.61s
# 247 bp detal time dt2= 0.04s
# 248 bp detal time dt1= 5.46s
# 248 bp detal time dt2= 0.03s
# 249 bp detal time dt1= 5.65s
# 249 bp detal time dt2= 0.04s
# 250 bp detal time dt1= 5.59s
# 250 bp detal time dt2= 0.04s
# 251 bp detal time dt1= 5.45s
# 251 bp detal time dt2= 0.04s
# 252 bp detal time dt1= 5.63s
# 252 bp detal time dt2= 0.04s
# 253 bp detal time dt1= 5.61s
# 253 bp detal time dt2= 0.04s
# 254 bp detal time dt1= 5.47s
# 254 bp detal time dt2= 0.03s
# 255 bp detal time dt1= 5.63s
# 255 bp detal time dt2= 0.04s
# 256 bp detal time dt1= 5.62s
# 256 bp detal time dt2= 0.04s
# 257 bp detal time dt1= 5.45s
# 257 bp detal time dt2= 0.03s
# 258 bp detal time dt1= 5.64s
# 258 bp detal time dt2= 0.04s
# 259 bp detal time dt1= 5.58s
# 259 bp detal time dt2= 0.04s
# 260 bp detal time dt1= 5.50s
# 260 bp detal time dt2= 0.03s
# 261 bp detal time dt1= 5.63s
# 261 bp detal time dt2= 0.04s
# 262 bp detal time dt1= 5.60s
# 262 bp detal time dt2= 0.04s
# 263 bp detal time dt1= 5.45s
# 263 bp detal time dt2= 0.04s
# 264 bp detal time dt1= 5.64s
# 264 bp detal time dt2= 0.04s
# 265 bp detal time dt1= 5.59s
# 265 bp detal time dt2= 0.04s
# 266 bp detal time dt1= 5.45s
# 266 bp detal time dt2= 0.03s
# 267 bp detal time dt1= 5.65s
# 267 bp detal time dt2= 0.04s
# 268 bp detal time dt1= 5.58s
# 268 bp detal time dt2= 0.04s
# 269 bp detal time dt1= 5.45s
# 269 bp detal time dt2= 0.04s
# 270 bp detal time dt1= 5.64s
# 270 bp detal time dt2= 0.04s
# 271 bp detal time dt1= 5.62s
# 271 bp detal time dt2= 0.04s
# 272 bp detal time dt1= 5.46s
# 272 bp detal time dt2= 0.03s
# 273 bp detal time dt1= 5.66s
# 273 bp detal time dt2= 0.04s
# 274 bp detal time dt1= 5.60s
# 274 bp detal time dt2= 0.04s
# 275 bp detal time dt1= 5.46s
# 275 bp detal time dt2= 0.04s
# 276 bp detal time dt1= 5.62s
# 276 bp detal time dt2= 0.04s
# 277 bp detal time dt1= 5.60s
# 277 bp detal time dt2= 0.04s
# 278 bp detal time dt1= 5.49s
# 278 bp detal time dt2= 0.03s
# 279 bp detal time dt1= 5.65s
# 279 bp detal time dt2= 0.04s
# 280 bp detal time dt1= 5.61s
# 280 bp detal time dt2= 0.04s
# 281 bp detal time dt1= 5.46s
# 281 bp detal time dt2= 0.03s
# 282 bp detal time dt1= 5.64s
# 282 bp detal time dt2= 0.04s
# 283 bp detal time dt1= 5.58s
# 283 bp detal time dt2= 0.04s
# 284 bp detal time dt1= 5.46s
# 284 bp detal time dt2= 0.03s
# 285 bp detal time dt1= 5.64s
# 285 bp detal time dt2= 0.04s
# 286 bp detal time dt1= 5.58s
# 286 bp detal time dt2= 0.04s
# 287 bp detal time dt1= 5.44s
# 287 bp detal time dt2= 0.03s
# 288 bp detal time dt1= 5.63s
# 288 bp detal time dt2= 0.04s
# 289 bp detal time dt1= 5.58s
# 289 bp detal time dt2= 0.04s
# 290 bp detal time dt1= 5.45s
# 290 bp detal time dt2= 0.03s
# 291 bp detal time dt1= 5.62s
# 291 bp detal time dt2= 0.04s
# 292 bp detal time dt1= 5.58s
# 292 bp detal time dt2= 0.04s
# 293 bp detal time dt1= 5.45s
# 293 bp detal time dt2= 0.03s
# 294 bp detal time dt1= 5.62s
# 294 bp detal time dt2= 0.04s
# 295 bp detal time dt1= 5.60s
# 295 bp detal time dt2= 0.04s
# 296 bp detal time dt1= 5.46s
# 296 bp detal time dt2= 0.03s
# 297 bp detal time dt1= 5.62s
# 297 bp detal time dt2= 0.04s
# 298 bp detal time dt1= 5.59s
# 298 bp detal time dt2= 0.04s
# 299 bp detal time dt1= 5.45s
# 299 bp detal time dt2= 0.04s
# 300 bp detal time dt1= 5.64s
# 300 bp detal time dt2= 0.04s
# 301 bp detal time dt1= 5.61s
# 301 bp detal time dt2= 0.04s
# 302 bp detal time dt1= 5.46s
# 302 bp detal time dt2= 0.04s
# 303 bp detal time dt1= 5.63s
# 303 bp detal time dt2= 0.04s
# 304 bp detal time dt1= 5.57s
# 304 bp detal time dt2= 0.04s
# 305 bp detal time dt1= 5.44s
# 305 bp detal time dt2= 0.03s
# 306 bp detal time dt1= 5.69s
# 306 bp detal time dt2= 0.04s
# 307 bp detal time dt1= 5.61s
# 307 bp detal time dt2= 0.04s
# 308 bp detal time dt1= 5.45s
# 308 bp detal time dt2= 0.03s
# 309 bp detal time dt1= 5.65s
# 309 bp detal time dt2= 0.04s
# 310 bp detal time dt1= 5.57s
# 310 bp detal time dt2= 0.04s
# 311 bp detal time dt1= 5.45s
# 311 bp detal time dt2= 0.03s
# 312 bp detal time dt1= 5.61s
# 312 bp detal time dt2= 0.04s
# 313 bp detal time dt1= 5.60s
# 313 bp detal time dt2= 0.04s
# 314 bp detal time dt1= 5.45s
# 314 bp detal time dt2= 0.03s
# 315 bp detal time dt1= 5.59s
# 315 bp detal time dt2= 0.04s
# 316 bp detal time dt1= 5.59s
# 316 bp detal time dt2= 0.04s
# 317 bp detal time dt1= 5.46s
# 317 bp detal time dt2= 0.03s
# 318 bp detal time dt1= 5.61s
# 318 bp detal time dt2= 0.04s
# 319 bp detal time dt1= 5.61s
# 319 bp detal time dt2= 0.04s
# 320 bp detal time dt1= 5.45s
# 320 bp detal time dt2= 0.03s
# 321 bp detal time dt1= 5.65s
# 321 bp detal time dt2= 0.04s
# 322 bp detal time dt1= 5.59s
# 322 bp detal time dt2= 0.04s
# 323 bp detal time dt1= 5.46s
# 323 bp detal time dt2= 0.04s
# 324 bp detal time dt1= 5.61s
# 324 bp detal time dt2= 0.04s
# 325 bp detal time dt1= 5.59s
# 325 bp detal time dt2= 0.04s
# 326 bp detal time dt1= 5.44s
# 326 bp detal time dt2= 0.03s
# 327 bp detal time dt1= 5.63s
# 327 bp detal time dt2= 0.04s
# 328 bp detal time dt1= 5.60s
# 328 bp detal time dt2= 0.04s
# 329 bp detal time dt1= 5.44s
# 329 bp detal time dt2= 0.03s
# 330 bp detal time dt1= 5.64s
# 330 bp detal time dt2= 0.04s
# 331 bp detal time dt1= 5.62s
# 331 bp detal time dt2= 0.04s
# 332 bp detal time dt1= 5.45s
# 332 bp detal time dt2= 0.04s
# 333 bp detal time dt1= 5.64s
# 333 bp detal time dt2= 0.04s
# 334 bp detal time dt1= 5.62s
# 334 bp detal time dt2= 0.04s
# 335 bp detal time dt1= 5.45s
# 335 bp detal time dt2= 0.03s
# 336 bp detal time dt1= 5.63s
# 336 bp detal time dt2= 0.04s
# 337 bp detal time dt1= 5.58s
# 337 bp detal time dt2= 0.04s
# 338 bp detal time dt1= 5.45s
# 338 bp detal time dt2= 0.03s
# 339 bp detal time dt1= 5.65s
# 339 bp detal time dt2= 0.04s
# 340 bp detal time dt1= 5.61s
# 340 bp detal time dt2= 0.04s
# 341 bp detal time dt1= 5.46s
# 341 bp detal time dt2= 0.03s
# 342 bp detal time dt1= 5.63s
# 342 bp detal time dt2= 0.04s
# 343 bp detal time dt1= 5.63s
# 343 bp detal time dt2= 0.04s
# 344 bp detal time dt1= 5.44s
# 344 bp detal time dt2= 0.03s
# 345 bp detal time dt1= 5.62s
# 345 bp detal time dt2= 0.04s
# 346 bp detal time dt1= 5.59s
# 346 bp detal time dt2= 0.04s
# 347 bp detal time dt1= 5.45s
# 347 bp detal time dt2= 0.03s
# 348 bp detal time dt1= 5.64s
# 348 bp detal time dt2= 0.04s
# 349 bp detal time dt1= 5.62s
# 349 bp detal time dt2= 0.04s
# 350 bp detal time dt1= 5.44s
# 350 bp detal time dt2= 0.03s
# 351 bp detal time dt1= 5.63s
# 351 bp detal time dt2= 0.04s
# 352 bp detal time dt1= 5.60s
# 352 bp detal time dt2= 0.04s
# 353 bp detal time dt1= 5.45s
# 353 bp detal time dt2= 0.04s
# 354 bp detal time dt1= 5.64s
# 354 bp detal time dt2= 0.04s
# 355 bp detal time dt1= 5.61s
# 355 bp detal time dt2= 0.04s
# 356 bp detal time dt1= 5.46s
# 356 bp detal time dt2= 0.03s
# 357 bp detal time dt1= 5.61s
# 357 bp detal time dt2= 0.04s
# 358 bp detal time dt1= 5.68s
# 358 bp detal time dt2= 0.04s
# 359 bp detal time dt1= 5.49s
# 359 bp detal time dt2= 0.04s
# 360 bp detal time dt1= 5.63s
# 360 bp detal time dt2= 0.04s
# 361 bp detal time dt1= 5.65s
# 361 bp detal time dt2= 0.04s
# 362 bp detal time dt1= 5.63s
# 362 bp detal time dt2= 0.04s
# 363 bp detal time dt1= 5.81s
# 363 bp detal time dt2= 0.04s
# 364 bp detal time dt1= 5.69s
# 364 bp detal time dt2= 0.04s
# 365 bp detal time dt1= 5.63s
# 365 bp detal time dt2= 0.03s
# 366 bp detal time dt1= 5.82s
# 366 bp detal time dt2= 0.04s
# 367 bp detal time dt1= 6.14s
# 367 bp detal time dt2= 0.05s
# 368 bp detal time dt1= 6.04s
# 368 bp detal time dt2= 0.04s
# 369 bp detal time dt1= 6.16s
# 369 bp detal time dt2= 0.04s
# 370 bp detal time dt1= 5.84s
# 370 bp detal time dt2= 0.04s
# 371 bp detal time dt1= 5.93s
# 371 bp detal time dt2= 0.04s
# 372 bp detal time dt1= 5.77s
# 372 bp detal time dt2= 0.04s
# 373 bp detal time dt1= 5.60s
# 373 bp detal time dt2= 0.04s
# 374 bp detal time dt1= 5.45s
# 374 bp detal time dt2= 0.04s
# 375 bp detal time dt1= 5.63s
# 375 bp detal time dt2= 0.04s
# 376 bp detal time dt1= 5.60s
# 376 bp detal time dt2= 0.04s
# 377 bp detal time dt1= 5.46s
# 377 bp detal time dt2= 0.04s
# 378 bp detal time dt1= 5.61s
# 378 bp detal time dt2= 0.04s
# 379 bp detal time dt1= 5.60s
# 379 bp detal time dt2= 0.04s
# 380 bp detal time dt1= 5.45s
# 380 bp detal time dt2= 0.03s
# 381 bp detal time dt1= 5.64s
# 381 bp detal time dt2= 0.04s
# 382 bp detal time dt1= 5.58s
# 382 bp detal time dt2= 0.04s
# 383 bp detal time dt1= 5.45s
# 383 bp detal time dt2= 0.04s
# 384 bp detal time dt1= 5.63s
# 384 bp detal time dt2= 0.04s
# 385 bp detal time dt1= 5.59s
# 385 bp detal time dt2= 0.04s
# 386 bp detal time dt1= 5.45s
# 386 bp detal time dt2= 0.03s
# 387 bp detal time dt1= 5.64s
# 387 bp detal time dt2= 0.04s
# 388 bp detal time dt1= 5.60s
# 388 bp detal time dt2= 0.04s
# 389 bp detal time dt1= 5.44s
# 389 bp detal time dt2= 0.04s
# Training iteration number = 390/781
# 390 bp detal time dt1= 5.64s
# 390 bp detal time dt2= 0.04s
# 391 bp detal time dt1= 5.57s
# 391 bp detal time dt2= 0.04s
# 392 bp detal time dt1= 5.46s
# 392 bp detal time dt2= 0.03s
# 393 bp detal time dt1= 5.63s
# 393 bp detal time dt2= 0.04s
# 394 bp detal time dt1= 5.57s
# 394 bp detal time dt2= 0.04s
# 395 bp detal time dt1= 5.46s
# 395 bp detal time dt2= 0.03s
# 396 bp detal time dt1= 5.61s
# 396 bp detal time dt2= 0.04s
# 397 bp detal time dt1= 5.58s
# 397 bp detal time dt2= 0.04s
# 398 bp detal time dt1= 5.46s
# 398 bp detal time dt2= 0.04s
# 399 bp detal time dt1= 5.63s
# 399 bp detal time dt2= 0.04s
# 400 bp detal time dt1= 5.59s
# 400 bp detal time dt2= 0.04s
# 401 bp detal time dt1= 5.44s
# 401 bp detal time dt2= 0.03s
# 402 bp detal time dt1= 5.64s
# 402 bp detal time dt2= 0.04s
# 403 bp detal time dt1= 5.60s
# 403 bp detal time dt2= 0.04s
# 404 bp detal time dt1= 5.45s
# 404 bp detal time dt2= 0.03s
# 405 bp detal time dt1= 5.62s
# 405 bp detal time dt2= 0.04s
